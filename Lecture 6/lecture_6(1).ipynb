# %% [markdown]
# # Lecture 6: Theory of Locality-Sensitive Hashing
#
# ## Overview
#
# Locality Sensitive Hashing (LSH) is a Nearest Neighbor Search algorithm that primarily targets large dataset with high dimensions. The existing algorithm takes long processing time when searching for nearest neighbors in high dimensional datasets. This issue often occurs in recommender system applications, data mining applications, etc. Linear search can be useful when dealing with low dimensional datasets. However, it is inefficient when dealing with high dimensional datasets. In order to improve the speed and accuracy, a particular type of hash function was designed to project two similar datasets to one hash value.
#
# There are some challenges existing in the current LSH algorithm. For example, when we apply the LSH algorithm for applications such as finding similarities between different documents, we have to rebuild hash tables every time while adding a document. This process is very costly and inefficient. Our objective is to improve the efficiency and accuracy of LSH.
#
# In this project, we propose a LSH-based algorithm to improve hashing techniques and compression performance. The improved LSH will be applied to the image retrieval application. The improvement process includes feature extraction, result comparison and evaluation, which will be explained in details in the rest of this report.
#
# We will compare the results from our approach with different parameters. The final outcome will be evaluated based on accuracy with multiple different parameters.
#
# # LSH Algorithm Improvement By Applying Bitmap Indexing

# %%
import argparse
import sys
from os import listdir
from os.path import isfile, join
from typing import Dict, List, Optional, Tuple
import imagehash
from PIL import Image
import os, os.path
import cv2
from collections import Counter
import scipy as sp
import numpy as np # Import numpy library 
from skimage.feature import hog # Import Hog model to extract features
from sklearn.metrics import confusion_matrix # Import confusion matrix to evaluate the performance
import pandas as pd
from pyspark.ml.linalg import Vectors
from pyspark.sql.functions import col
from pyspark.conf import SparkConf
from pyspark.ml.feature import BucketedRandomProjectionLSH
from pyspark.sql import SparkSession
from sklearn.model_selection import train_test_split

# %%
imgs = []
y = []
file_size = []
k = 0
path = "./data/101_ObjectCategories" # Give the dataset path here

# %% [markdown]
# ##  Data Preprocessing:
# 1. Load the images using cv2
# 2. Image resize
# 3. Feature extraction: BGR to Gray conversion
# 4. Feature extraction: Histogram of Oriented Gradients(HOG)

# %%
folder = os.listdir(path) # from the given path get the file names such as accordion, airplanes etc..
for file in folder: # for every file name in the given path go inseide that directory and get the images
    subpath = os.path.join(path,file)  # Join the name of these files to the previous path 
    
    files = os.listdir(subpath) # Take these image names to a list called files
    j = 0
    for i in range(np.size(files)): # now we shall loop through these number of files
        
        im = cv2.imread(subpath+'/'+files[0+j]) # Read the images from this subpath
        
        imgs.append(im) # append all the read images to a list called imgs
        y.append(k) # generate a labe to every file and append it to labels list

        j += 1
        if (j == (np.size(files))):
            file_size.append(j)
   
    k += 1
     
y = np.array(y).tolist()
ix = []
for index, item in enumerate(imgs):
    if (np.size(item) == 1):
        ix.append(index)
        del imgs[index]
        
for index, item in enumerate(y):
    for v in range(np.size(ix)):
        if (index == ix[v]):
            del y[index]
        
y = np.array(y).astype(np.float64) 

# Function to convert an image from color to grayscale
def resize_(image):
    u = cv2.resize(image,(256,256))
    return u

def rgb2gray(rgb):
    gray = cv2.cvtColor(rgb, cv2.COLOR_BGR2GRAY)
    return gray

def fd_hog(image): # 特征描述符就是通过提取图像的有用信息，并且丢弃无关信息来简化图像的表示，HOG特征描述符可以将3通道的彩色图像转换成一定长度的特征向量
    fd = hog(image, orientations=8, pixels_per_cell=(64, 64),block_norm ='L2', cells_per_block=(2, 2))
    return fd

# %%
a=[]
import progressbar
with progressbar.ProgressBar(max_value=len(imgs)) as bar:
    i=1
    for img in imgs:
        b=resize_(img)
        c=rgb2gray(b)   
        d=fd_hog(c)
        a.append(d)
        bar.update(i)
        i+=1
df = pd.DataFrame(a)
df['lable'] = y
id_ = np.arange(1,len(df)+1,1)
df['id'] = id_
X = df.values

# init spark
spark = SparkSession.builder \
 .master("local") \
 .appName("Image Retrieval") \
 .config("spark.some.config.option", "some-value") \
 .getOrCreate()
# Out:
# 100% (9176 of 9176) |####################| Elapsed Time: 0:02:41 Time:  0:02:41

# %%
print("HOG diamension: ")
len(a[0])
# Out:
# HOG diamension:
# 288

# %%
# print the hog vectors
a[0]
# Out:
# array([0.0150423 , 0.00702026, 0.02142409, 0.00513724, 0.03626991,
#        0.00412899, 0.00851918, 0.00341131, 0.3910884 , 0.11769633,
#        0.05951159, 0.0338695 , 0.05744279, 0.03126868, 0.07697637,
#        0.18629866, 0.13693709, 0.09183842, 0.06311768, 0.04393364,
#        0.08685511, 0.05885088, 0.08278085, 0.09256898, 0.45369873,
#        0.40324878, 0.33785404, 0.22942793, 0.24095177, 0.15504705,
#        0.21395993, 0.24244829, 0.25443706, 0.07657171, 0.03871747,
#        0.02203506, 0.03737153, 0.020343  , 0.05007983, 0.1212035 ,
#        0.44146027, 0.19044215, 0.11511823, 0.06033758, 0.05521417,
#        0.05508732, 0.0997878 , 0.24385815, 0.29517052, 0.26234844,
#        0.21980347, 0.14926284, 0.15676011, 0.1008716 , 0.13919956,
#        0.15773372, 0.29398333, 0.15013317, 0.13212652, 0.11454095,
#        0.11917495, 0.0850342 , 0.14977189, 0.30966194, 0.44515194,
#        0.1920347 , 0.11608089, 0.06084214, 0.05567589, 0.05554798,
#        0.10062226, 0.24589739, 0.17177813, 0.03998121, 0.01170008,
#        0.00593656, 0.02462157, 0.01358481, 0.0498447 , 0.18295833,
#        0.29644174, 0.15138864, 0.13323141, 0.11549879, 0.12017154,
#        0.08574529, 0.15102434, 0.31225145, 0.31342391, 0.16014263,
#        0.06194313, 0.03491608, 0.07339488, 0.0904988 , 0.17618241,
#        0.38136572, 0.11345854, 0.07609227, 0.05229584, 0.036401  ,
#        0.07196337, 0.0487606 , 0.06858766, 0.07669757, 0.37590983,
#        0.33410978, 0.27992729, 0.19009137, 0.1996394 , 0.12846346,
#        0.17727544, 0.20087933, 0.25175042, 0.18948389, 0.16507314,
#        0.11080695, 0.16770323, 0.14991975, 0.20582534, 0.25452424,
#        0.08752294, 0.06396611, 0.06500663, 0.14974673, 0.24576113,
#        0.17239245, 0.16029773, 0.11310656, 0.31709621, 0.28183606,
#        0.23613078, 0.1603503 , 0.16840447, 0.10836449, 0.1495395 ,
#        0.16945041, 0.31582083, 0.16128528, 0.14194107, 0.12304921,
#        0.12802744, 0.09135066, 0.16089716, 0.33266406, 0.07382939,
#        0.05395818, 0.0548359 , 0.12631785, 0.20731015, 0.14542049,
#        0.13521807, 0.09541027, 0.16192612, 0.09394561, 0.10354693,
#        0.15419733, 0.23293304, 0.16249312, 0.16969397, 0.16491538,
#        0.2758396 , 0.14086742, 0.12397208, 0.10747184, 0.11181985,
#        0.07978616, 0.14052843, 0.29055056, 0.29164154, 0.14901302,
#        0.0576382 , 0.03248948, 0.06829407, 0.0842093 , 0.16393806,
#        0.35486152, 0.14142713, 0.0820526 , 0.09043844, 0.13467677,
#        0.20344495, 0.14192236, 0.14821162, 0.14403797, 0.24002197,
#        0.13992258, 0.11713536, 0.12291604, 0.13842105, 0.17489181,
#        0.29837009, 0.27537315, 0.25241012, 0.18998042, 0.1655057 ,
#        0.11109731, 0.16814269, 0.1503126 , 0.20636469, 0.25519121,
#        0.08775229, 0.06413373, 0.06517697, 0.15013913, 0.24640513,
#        0.1728442 , 0.16071778, 0.11340294, 0.20029151, 0.21222048,
#        0.18247277, 0.33001914, 0.33258217, 0.0738093 , 0.0840583 ,
#        0.09740809, 0.21483035, 0.18192916, 0.09255868, 0.16636256,
#        0.21055959, 0.05022047, 0.0510417 , 0.09523649, 0.09852695,
#        0.07200839, 0.07317973, 0.16857397, 0.27665999, 0.19406687,
#        0.18045151, 0.12732712, 0.21609399, 0.1253725 , 0.13818567,
#        0.20577975, 0.31085429, 0.21685067, 0.22646036, 0.22008322,
#        0.24120829, 0.20426733, 0.1039235 , 0.18678938, 0.23641314,
#        0.05638679, 0.05730885, 0.1069301 , 0.21980933, 0.11165492,
#        0.10540807, 0.17425523, 0.22602641, 0.07581244, 0.10809555,
#        0.17595848, 0.16501273, 0.09573639, 0.10552073, 0.15713662,
#        0.23737318, 0.16559055, 0.17292865, 0.16805897, 0.28005009,
#        0.16325727, 0.13666985, 0.14341457, 0.16150533, 0.20405826,
#        0.34812885, 0.32129673, 0.16784982, 0.08526143, 0.08049124,
#        0.133064  , 0.17259728, 0.05789156, 0.08254344, 0.13436463,
#        0.13563127, 0.14265165, 0.0970934 , 0.24024775, 0.26610779,
#        0.13779198, 0.13589369, 0.13263861])

# %% [markdown]
# ## Split the data into training and testing datasets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
Train = map(lambda x: (int(x[-1]),int(x[-2]),Vectors.dense(x[:-2])), X_train)
Train_df = spark.createDataFrame(Train,schema=['id','label',"features"])
Test = map(lambda x: (int(x[-1]),int(x[-2]),Vectors.dense(x[:-2])), X_test)
Test_df = spark.createDataFrame(Test,schema=['id','label',"features"])

# %% [markdown]
# ## Set Function BucketedRandomProjectionLSH

# %%
brp = BucketedRandomProjectionLSH(inputCol="features", outputCol="hashes", 
                                      bucketLength=0.002,numHashTables=5)
# LSH模型的使用中最关键的还是要看setBucketLength和setNumHashTables两个参数的设置。因为这两个参数决定了模型的计算效果和性能。
model = brp.fit(Train_df)
transformedModel = model.transform(Train_df)

# %% [markdown]
# ## Print the hashes
# A column represents a hash label. In one colum(one table), vectors will be hash into the same bucket if they have the same hash value.

# %%
transformedModel.select("hashes").collect()
# Out:
# [Row(hashes=[DenseVector([-4.0]), DenseVector([43.0]), DenseVector([13.0]), DenseVector([-187.0]), DenseVector([-50.0])]),
#  Row(hashes=[DenseVector([35.0]), DenseVector([52.0]), DenseVector([48.0]), DenseVector([-61.0]), DenseVector([55.0])]),
#  Row(hashes=[DenseVector([5.0]), DenseVector([81.0]), DenseVector([41.0]), DenseVector([-136.0]), DenseVector([-35.0])]),
#  Row(hashes=[DenseVector([4.0]), DenseVector([66.0]), DenseVector([77.0]), DenseVector([-112.0]), DenseVector([15.0])]),
#  Row(hashes=[DenseVector([9.0]), DenseVector([-1.0]), DenseVector([-37.0]), DenseVector([-92.0]), DenseVector([-68.0])]),
#  Row(hashes=[DenseVector([-68.0]), DenseVector([10.0]), DenseVector([19.0]), DenseVector([-78.0]), DenseVector([-45.0])]),
#  Row(hashes=[DenseVector([-126.0]), DenseVector([34.0]), DenseVector([-22.0]), DenseVector([-143.0]), DenseVector([-24.0])]),
#  Row(hashes=[DenseVector([-124.0]), DenseVector([-4.0]), DenseVector([-17.0]), DenseVector([-37.0]), DenseVector([-63.0])]),
#  Row(hashes=[DenseVector([-29.0]), DenseVector([71.0]), DenseVector([-1.0]), DenseVector([-112.0]), DenseVector([26.0])]),
#  Row(hashes=[DenseVector([73.0]), DenseVector([151.0]), DenseVector([49.0]), DenseVector([-34.0]), DenseVector([-49.0])]),
#  Row(hashes=[DenseVector([-13.0]), DenseVector([80.0]), DenseVector([-31.0]), DenseVector([-90.0]), DenseVector([60.0])]),
#  Row(hashes=[DenseVector([-14.0]), DenseVector([-4.0]), DenseVector([19.0]), DenseVector([-58.0]), DenseVector([-123.0])]),
#  Row(hashes=[DenseVector([-60.0]), DenseVector([47.0]), DenseVector([12.0]), DenseVector([-114.0]), DenseVector([13.0])]),
#  Row(hashes=[DenseVector([-59.0]), DenseVector([159.0]), DenseVector([75.0]), DenseVector([-174.0]), DenseVector([29.0])]),
#  Row(hashes=[DenseVector([-8.0]), DenseVector([65.0]), DenseVector([5.0]), DenseVector([-105.0]), DenseVector([11.0])]),
#  Row(hashes=[DenseVector([-126.0]), DenseVector([-21.0]), DenseVector([-65.0]), DenseVector([-58.0]), DenseVector([-66.0])]),
#  Row(hashes=[DenseVector([6.0]), DenseVector([93.0]), DenseVector([71.0]), DenseVector([-98.0]), DenseVector([18.0])]),
#  Row(hashes=[DenseVector([-108.0]), DenseVector([39.0]), DenseVector([33.0]), DenseVector([-170.0]), DenseVector([34.0])]),
#  Row(hashes=[DenseVector([-102.0]), DenseVector([34.0]), DenseVector([-37.0]), DenseVector([-3.0]), DenseVector([25.0])]),
#  Row(hashes=[DenseVector([-26.0]), DenseVector([-15.0]), DenseVector([55.0]), DenseVector([-105.0]), DenseVector([-83.0])]),
#  Row(hashes=[DenseVector([-53.0]), DenseVector([57.0]), DenseVector([7.0]), DenseVector([-132.0]), DenseVector([34.0])]),
#  Row(hashes=[DenseVector([-103.0]), DenseVector([157.0]), DenseVector([17.0]), DenseVector([-20.0]), DenseVector([-35.0])]),
#  Row(hashes=[DenseVector([-44.0]), DenseVector([63.0]), DenseVector([76.0]), DenseVector([-93.0]), DenseVector([30.0])]),
#  Row(hashes=[DenseVector([-4.0]), DenseVector([71.0]), DenseVector([-22.0]), DenseVector([-104.0]), DenseVector([89.0])]),
#  Row(hashes=[DenseVector([-52.0]), DenseVector([59.0]), DenseVector([-5.0]), DenseVector([-96.0]), DenseVector([-30.0])]),
#  Row(hashes=[DenseVector([-23.0]), DenseVector([18.0]), DenseVector([-33.0]), DenseVector([-48.0]), DenseVector([28.0])]),
#  Row(hashes=[DenseVector([-61.0]), DenseVector([76.0]), DenseVector([-12.0]), DenseVector([-51.0]), DenseVector([-2.0])]),
#  Row(hashes=[DenseVector([-37.0]), DenseVector([65.0]), DenseVector([-39.0]), DenseVector([-121.0]), DenseVector([5.0])]),
#  Row(hashes=[DenseVector([-38.0]), DenseVector([66.0]), DenseVector([21.0]), DenseVector([-110.0]), DenseVector([17.0])]),
#  Row(hashes=[DenseVector([-69.0]), DenseVector([31.0]), DenseVector([26.0]), DenseVector([-94.0]), DenseVector([-35.0])]),
#  Row(hashes=[DenseVector([-14.0]), DenseVector([44.0]), DenseVector([69.0]), DenseVector([-129.0]), DenseVector([-67.0])]),
#  Row(hashes=[DenseVector([-5.0]), DenseVector([62.0]), DenseVector([6.0]), DenseVector([-116.0]), DenseVector([-15.0])]),
#  Row(hashes=[DenseVector([-80.0]), DenseVector([19.0]), DenseVector([91.0]), DenseVector([-177.0]), DenseVector([-21.0])]),
#  Row(hashes=[DenseVector([-92.0]), DenseVector([97.0]), DenseVector([-49.0]), DenseVector([-116.0]), DenseVector([-44.0])]),
#  Row(hashes=[DenseVector([-34.0]), DenseVector([84.0]), DenseVector([-38.0]), DenseVector([-94.0]), DenseVector([3.0])]),
#  Row(hashes=[DenseVector([-71.0]), DenseVector([64.0]), DenseVector([-32.0]), DenseVector([-101.0]), DenseVector([-26.0])]),
#  Row(hashes=[DenseVector([-20.0]), DenseVector([101.0]), DenseVector([-19.0]), DenseVector([-73.0]), DenseVector([18.0])]),
#  Row(hashes=[DenseVector([-25.0]), DenseVector([79.0]), DenseVector([26.0]), DenseVector([-130.0]), DenseVector([-15.0])]),
#  Row(hashes=[DenseVector([-20.0]), DenseVector([-4.0]), DenseVector([-21.0]), DenseVector([-2.0]), DenseVector([25.0])]),
#  Row(hashes=[DenseVector([-42.0]), DenseVector([76.0]), DenseVector([-3.0]), DenseVector([-34.0]), DenseVector([-72.0])]),
#  Row(hashes=[DenseVector([-49.0]), DenseVector([21.0]), DenseVector([-1.0]), DenseVector([-109.0]), DenseVector([0.0])]),
#  Row(hashes=[DenseVector([-38.0]), DenseVector([68.0]), DenseVector([-12.0]), DenseVector([-111.0]), DenseVector([21.0])]),
#  Row(hashes=[DenseVector([13.0]), DenseVector([-1.0]), DenseVector([7.0]), DenseVector([-162.0]), DenseVector([-25.0])]),
#  Row(hashes=[DenseVector([-88.0]), DenseVector([37.0]), DenseVector([84.0]), DenseVector([-131.0]), DenseVector([1.0])]),
#  Row(hashes=[DenseVector([-6.0]), DenseVector([58.0]), DenseVector([14.0]), DenseVector([-88.0]), DenseVector([46.0])]),
#  Row(hashes=[DenseVector([-28.0]), DenseVector([52.0]), DenseVector([20.0]), DenseVector([-129.0]), DenseVector([9.0])]),
#  Row(hashes=[DenseVector([-51.0]), DenseVector([101.0]), DenseVector([-11.0]), DenseVector([-111.0]), DenseVector([-20.0])]),
#  Row(hashes=[DenseVector([-22.0]), DenseVector([80.0]), DenseVector([-7.0]), DenseVector([8.0]), DenseVector([31.0])]),
#  Row(hashes=[DenseVector([-56.0]), DenseVector([72.0]), DenseVector([0.0]), DenseVector([-140.0]), DenseVector([-9.0])]),
#  Row(hashes=[DenseVector([-63.0]), DenseVector([46.0]), DenseVector([-24.0]), DenseVector([-194.0]), DenseVector([-37.0])]),
#  Row(hashes=[DenseVector([-159.0]), DenseVector([16.0]), DenseVector([-36.0]), DenseVector([-111.0]), DenseVector([89.0])]),
#  Row(hashes=[DenseVector([-70.0]), DenseVector([53.0]), DenseVector([-2.0]), DenseVector([-123.0]), DenseVector([41.0])]),
#  Row(hashes=[DenseVector([-6.0]), DenseVector([91.0]), DenseVector([64.0]), DenseVector([-88.0]), DenseVector([-21.0])]),
#  Row(hashes=[DenseVector([-20.0]), DenseVector([95.0]), DenseVector([-27.0]), DenseVector([-110.0]), DenseVector([44.0])]),
#  Row(hashes=[DenseVector([-63.0]), DenseVector([77.0]), DenseVector([-15.0]), DenseVector([-114.0]), DenseVector([-14.0])]),
#  Row(hashes=[DenseVector([-59.0]), DenseVector([72.0]), DenseVector([-29.0]), DenseVector([-127.0]), DenseVector([-6.0])]),
#  Row(hashes=[DenseVector([-140.0]), DenseVector([39.0]), DenseVector([43.0]), DenseVector([-138.0]), DenseVector([16.0])]),
#  Row(hashes=[DenseVector([-44.0]), DenseVector([64.0]), DenseVector([5.0]), DenseVector([-127.0]), DenseVector([75.0])]),
#  Row(hashes=[DenseVector([-66.0]), DenseVector([66.0]), DenseVector([-37.0]), DenseVector([-64.0]), DenseVector([13.0])]),
#  Row(hashes=[DenseVector([-168.0]), DenseVector([43.0]), DenseVector([-27.0]), DenseVector([-157.0]), DenseVector([14.0])]),
#  Row(hashes=[DenseVector([-47.0]), DenseVector([93.0]), DenseVector([-16.0]), DenseVector([-93.0]), DenseVector([24.0])]),
#  Row(hashes=[DenseVector([-113.0]), DenseVector([73.0]), DenseVector([3.0]), DenseVector([-123.0]), DenseVector([22.0])]),
#  Row(hashes=[DenseVector([-119.0]), DenseVector([40.0]), DenseVector([-8.0]), DenseVector([-129.0]), DenseVector([20.0])]),
#  Row(hashes=[DenseVector([-97.0]), DenseVector([70.0]), DenseVector([29.0]), DenseVector([-145.0]), DenseVector([1.0])]),
#  Row(hashes=[DenseVector([-66.0]), DenseVector([14.0]), DenseVector([3.0]), DenseVector([-199.0]), DenseVector([3.0])]),
#  Row(hashes=[DenseVector([-89.0]), DenseVector([46.0]), DenseVector([-8.0]), DenseVector([-39.0]), DenseVector([7.0])]),
#  Row(hashes=[DenseVector([-143.0]), DenseVector([13.0]), DenseVector([42.0]), DenseVector([-134.0]), DenseVector([115.0])]),
#  Row(hashes=[DenseVector([-17.0]), DenseVector([23.0]), DenseVector([72.0]), DenseVector([-125.0]), DenseVector([-42.0])]),
#  Row(hashes=[DenseVector([-63.0]), DenseVector([97.0]), DenseVector([29.0]), DenseVector([-124.0]), DenseVector([-59.0])]),
#  Row(hashes=[DenseVector([-99.0]), DenseVector([68.0]), DenseVector([-34.0]), DenseVector([-50.0]), DenseVector([50.0])]),
#  Row(hashes=[DenseVector([-86.0]), DenseVector([92.0]), DenseVector([97.0]), DenseVector([-187.0]), DenseVector([3.0])]),
#  Row(hashes=[DenseVector([-24.0]), DenseVector([61.0]), DenseVector([15.0]), DenseVector([-86.0]), DenseVector([-43.0])]),
#  Row(hashes=[DenseVector([-102.0]), DenseVector([84.0]), DenseVector([-3.0]), DenseVector([-106.0]), DenseVector([23.0])]),
#  Row(hashes=[DenseVector([-66.0]), DenseVector([70.0]), DenseVector([60.0]), DenseVector([-129.0]), DenseVector([11.0])]),
#  Row(hashes=[DenseVector([15.0]), DenseVector([45.0]), DenseVector([52.0]), DenseVector([-113.0]), DenseVector([-38.0])]),
#  Row(hashes=[DenseVector([-26.0]), DenseVector([64.0]), DenseVector([-3.0]), DenseVector([-138.0]), DenseVector([19.0])]),
#  Row(hashes=[DenseVector([1.0]), DenseVector([93.0]), DenseVector([76.0]), DenseVector([-87.0]), DenseVector([0.0])]),
#  Row(hashes=[DenseVector([-57.0]), DenseVector([55.0]), DenseVector([9.0]), DenseVector([-134.0]), DenseVector([-1.0])]),
#  Row(hashes=[DenseVector([-38.0]), DenseVector([70.0]), DenseVector([22.0]), DenseVector([-84.0]), DenseVector([-74.0])]),
#  Row(hashes=[DenseVector([-1.0]), DenseVector([54.0]), DenseVector([85.0]), DenseVector([-183.0]), DenseVector([42.0])]),
#  Row(hashes=[DenseVector([-86.0]), DenseVector([-11.0]), DenseVector([-21.0]), DenseVector([-233.0]), DenseVector([15.0])]),
#  Row(hashes=[DenseVector([-36.0]), DenseVector([55.0]), DenseVector([7.0]), DenseVector([22.0]), DenseVector([-122.0])]),
#  Row(hashes=[DenseVector([-74.0]), DenseVector([34.0]), DenseVector([-4.0]), DenseVector([-69.0]), DenseVector([-61.0])]),
#  Row(hashes=[DenseVector([-75.0]), DenseVector([55.0]), DenseVector([-61.0]), DenseVector([-71.0]), DenseVector([57.0])]),
#  Row(hashes=[DenseVector([-93.0]), DenseVector([8.0]), DenseVector([-54.0]), DenseVector([-101.0]), DenseVector([67.0])]),
#  Row(hashes=[DenseVector([-65.0]), DenseVector([11.0]), DenseVector([2.0]), DenseVector([-107.0]), DenseVector([-9.0])]),
#  Row(hashes=[DenseVector([-76.0]), DenseVector([83.0]), DenseVector([47.0]), DenseVector([-145.0]), DenseVector([-34.0])]),
#  Row(hashes=[DenseVector([-29.0]), DenseVector([76.0]), DenseVector([-14.0]), DenseVector([-59.0]), DenseVector([0.0])]),
#  Row(hashes=[DenseVector([-59.0]), DenseVector([-32.0]), DenseVector([7.0]), DenseVector([-110.0]), DenseVector([-114.0])]),
#  Row(hashes=[DenseVector([-23.0]), DenseVector([80.0]), DenseVector([-5.0]), DenseVector([-118.0]), DenseVector([40.0])]),
#  Row(hashes=[DenseVector([-50.0]), DenseVector([62.0]), DenseVector([46.0]), DenseVector([-77.0]), DenseVector([42.0])]),
#  Row(hashes=[DenseVector([-61.0]), DenseVector([44.0]), DenseVector([-28.0]), DenseVector([-105.0]), DenseVector([-83.0])]),
#  Row(hashes=[DenseVector([-14.0]), DenseVector([67.0]), DenseVector([-51.0]), DenseVector([-141.0]), DenseVector([-13.0])]),
#  Row(hashes=[DenseVector([-9.0]), DenseVector([95.0]), DenseVector([35.0]), DenseVector([-177.0]), DenseVector([-4.0])]),
#  Row(hashes=[DenseVector([-53.0]), DenseVector([49.0]), DenseVector([-13.0]), DenseVector([-128.0]), DenseVector([-11.0])]),
#  Row(hashes=[DenseVector([24.0]), DenseVector([85.0]), DenseVector([43.0]), DenseVector([-84.0]), DenseVector([79.0])]),
#  Row(hashes=[DenseVector([-36.0]), DenseVector([110.0]), DenseVector([-10.0]), DenseVector([-42.0]), DenseVector([21.0])]),
#  Row(hashes=[DenseVector([-106.0]), DenseVector([120.0]), DenseVector([11.0]), DenseVector([-153.0]), DenseVector([-15.0])]),
#  Row(hashes=[DenseVector([-104.0]), DenseVector([49.0]), DenseVector([62.0]), DenseVector([-91.0]), DenseVector([-17.0])]),
#  Row(hashes=[DenseVector([28.0]), DenseVector([29.0]), DenseVector([-18.0]), DenseVector([-81.0]), DenseVector([39.0])]),
#  Row(hashes=[DenseVector([-62.0]), DenseVector([78.0]), DenseVector([-150.0]), DenseVector([-11.0]), DenseVector([80.0])]),
#  Row(hashes=[DenseVector([-74.0]), DenseVector([44.0]), DenseVector([1.0]), DenseVector([-190.0]), DenseVector([-15.0])]),
#  Row(hashes=[DenseVector([-113.0]), DenseVector([53.0]), DenseVector([-21.0]), DenseVector([-125.0]), DenseVector([-23.0])]),
#  Row(hashes=[DenseVector([-56.0]), DenseVector([29.0]), DenseVector([79.0]), DenseVector([-161.0]), DenseVector([20.0])]),
#  Row(hashes=[DenseVector([-82.0]), DenseVector([101.0]), DenseVector([145.0]), DenseVector([-103.0]), DenseVector([-1.0])]),
#  Row(hashes=[DenseVector([-70.0]), DenseVector([52.0]), DenseVector([-24.0]), DenseVector([-81.0]), DenseVector([-9.0])]),
#  Row(hashes=[DenseVector([-18.0]), DenseVector([35.0]), DenseVector([-1.0]), DenseVector([-61.0]), DenseVector([52.0])]),
#  Row(hashes=[DenseVector([-30.0]), DenseVector([29.0]), DenseVector([-44.0]), DenseVector([0.0]), DenseVector([-58.0])]),
#  Row(hashes=[DenseVector([57.0]), DenseVector([121.0]), DenseVector([89.0]), DenseVector([-156.0]), DenseVector([-60.0])]),
#  Row(hashes=[DenseVector([-97.0]), DenseVector([43.0]), DenseVector([-20.0]), DenseVector([-92.0]), DenseVector([-14.0])]),
#  Row(hashes=[DenseVector([-79.0]), DenseVector([-9.0]), DenseVector([-83.0]), DenseVector([-53.0]), DenseVector([80.0])]),
#  Row(hashes=[DenseVector([-29.0]), DenseVector([58.0]), DenseVector([-5.0]), DenseVector([-145.0]), DenseVector([18.0])]),
#  Row(hashes=[DenseVector([39.0]), DenseVector([84.0]), DenseVector([-28.0]), DenseVector([-78.0]), DenseVector([41.0])]),
#  Row(hashes=[DenseVector([21.0]), DenseVector([66.0]), DenseVector([-29.0]), DenseVector([-121.0]), DenseVector([22.0])]),
#  Row(hashes=[DenseVector([-50.0]), DenseVector([82.0]), DenseVector([35.0]), DenseVector([-146.0]), DenseVector([-71.0])]),
#  Row(hashes=[DenseVector([-79.0]), DenseVector([10.0]), DenseVector([23.0]), DenseVector([-107.0]), DenseVector([-70.0])]),
#  Row(hashes=[DenseVector([-107.0]), DenseVector([91.0]), DenseVector([101.0]), DenseVector([-95.0]), DenseVector([106.0])]),
#  Row(hashes=[DenseVector([-28.0]), DenseVector([-5.0]), DenseVector([10.0]), DenseVector([-68.0]), DenseVector([-26.0])]),
#  Row(hashes=[DenseVector([-50.0]), DenseVector([84.0]), DenseVector([-51.0]), DenseVector([-82.0]), DenseVector([-23.0])]),
#  Row(hashes=[DenseVector([-27.0]), DenseVector([51.0]), DenseVector([34.0]), DenseVector([-165.0]), DenseVector([22.0])]),
#  Row(hashes=[DenseVector([-133.0]), DenseVector([-43.0]), DenseVector([-60.0]), DenseVector([39.0]), DenseVector([25.0])]),
#  Row(hashes=[DenseVector([-14.0]), DenseVector([54.0]), DenseVector([65.0]), DenseVector([-147.0]), DenseVector([-18.0])]),
#  Row(hashes=[DenseVector([-71.0]), DenseVector([40.0]), DenseVector([32.0]), DenseVector([-156.0]), DenseVector([72.0])]),
#  Row(hashes=[DenseVector([-81.0]), DenseVector([92.0]), DenseVector([-150.0]), DenseVector([37.0]), DenseVector([39.0])]),
#  Row(hashes=[DenseVector([-72.0]), DenseVector([61.0]), DenseVector([11.0]), DenseVector([-145.0]), DenseVector([20.0])]),
#  Row(hashes=[DenseVector([61.0]), DenseVector([75.0]), DenseVector([43.0]), DenseVector([-155.0]), DenseVector([35.0])]),
#  Row(hashes=[DenseVector([-60.0]), DenseVector([37.0]), DenseVector([27.0]), DenseVector([-113.0]), DenseVector([15.0])]),
#  Row(hashes=[DenseVector([-109.0]), DenseVector([87.0]), DenseVector([45.0]), DenseVector([-115.0]), DenseVector([33.0])]),
#  Row(hashes=[DenseVector([-67.0]), DenseVector([100.0]), DenseVector([51.0]), DenseVector([-145.0]), DenseVector([3.0])]),
#  Row(hashes=[DenseVector([-60.0]), DenseVector([126.0]), DenseVector([-6.0]), DenseVector([-79.0]), DenseVector([-86.0])]),
#  Row(hashes=[DenseVector([54.0]), DenseVector([42.0]), DenseVector([58.0]), DenseVector([-61.0]), DenseVector([-47.0])]),
#  Row(hashes=[DenseVector([17.0]), DenseVector([33.0]), DenseVector([21.0]), DenseVector([-152.0]), DenseVector([-42.0])]),
#  Row(hashes=[DenseVector([-21.0]), DenseVector([30.0]), DenseVector([-10.0]), DenseVector([-100.0]), DenseVector([40.0])]),
#  Row(hashes=[DenseVector([-55.0]), DenseVector([46.0]), DenseVector([29.0]), DenseVector([-130.0]), DenseVector([27.0])]),
#  Row(hashes=[DenseVector([-143.0]), DenseVector([17.0]), DenseVector([-28.0]), DenseVector([-137.0]), DenseVector([-11.0])]),
#  Row(hashes=[DenseVector([-41.0]), DenseVector([39.0]), DenseVector([62.0]), DenseVector([-170.0]), DenseVector([-30.0])]),
#  Row(hashes=[DenseVector([-63.0]), DenseVector([80.0]), DenseVector([17.0]), DenseVector([-185.0]), DenseVector([-21.0])]),
#  Row(hashes=[DenseVector([-139.0]), DenseVector([2.0]), DenseVector([9.0]), DenseVector([-125.0]), DenseVector([13.0])]),
#  Row(hashes=[DenseVector([-90.0]), DenseVector([56.0]), DenseVector([-28.0]), DenseVector([-109.0]), DenseVector([2.0])]),
#  Row(hashes=[DenseVector([-1.0]), DenseVector([110.0]), DenseVector([16.0]), DenseVector([-102.0]), DenseVector([12.0])]),
#  Row(hashes=[DenseVector([-73.0]), DenseVector([17.0]), DenseVector([59.0]), DenseVector([-206.0]), DenseVector([-62.0])]),
#  Row(hashes=[DenseVector([-82.0]), DenseVector([105.0]), DenseVector([44.0]), DenseVector([-129.0]), DenseVector([32.0])]),
#  Row(hashes=[DenseVector([-36.0]), DenseVector([55.0]), DenseVector([7.0]), DenseVector([22.0]), DenseVector([-122.0])]),
#  Row(hashes=[DenseVector([-60.0]), DenseVector([2.0]), DenseVector([-12.0]), DenseVector([-105.0]), DenseVector([-41.0])]),
#  Row(hashes=[DenseVector([-123.0]), DenseVector([46.0]), DenseVector([24.0]), DenseVector([-132.0]), DenseVector([-26.0])]),
#  Row(hashes=[DenseVector([-10.0]), DenseVector([4.0]), DenseVector([-73.0]), DenseVector([-75.0]), DenseVector([-138.0])]),
#  Row(hashes=[DenseVector([126.0]), DenseVector([24.0]), DenseVector([18.0]), DenseVector([-89.0]), DenseVector([-10.0])]),
#  Row(hashes=[DenseVector([-88.0]), DenseVector([76.0]), DenseVector([115.0]), DenseVector([-98.0]), DenseVector([55.0])]),
#  Row(hashes=[DenseVector([-7.0]), DenseVector([90.0]), DenseVector([10.0]), DenseVector([-115.0]), DenseVector([0.0])]),
#  Row(hashes=[DenseVector([-76.0]), DenseVector([47.0]), DenseVector([87.0]), DenseVector([-139.0]), DenseVector([24.0])]),
#  Row(hashes=[DenseVector([-48.0]), DenseVector([61.0]), DenseVector([1.0]), DenseVector([-127.0]), DenseVector([30.0])]),
#  Row(hashes=[DenseVector([-96.0]), DenseVector([51.0]), DenseVector([13.0]), DenseVector([-127.0]), DenseVector([69.0])]),
#  Row(hashes=[DenseVector([-120.0]), DenseVector([105.0]), DenseVector([44.0]), DenseVector([-200.0]), DenseVector([-36.0])]),
#  Row(hashes=[DenseVector([40.0]), DenseVector([75.0]), DenseVector([29.0]), DenseVector([-61.0]), DenseVector([29.0])]),
#  Row(hashes=[DenseVector([-159.0]), DenseVector([75.0]), DenseVector([86.0]), DenseVector([-205.0]), DenseVector([-38.0])]),
#  Row(hashes=[DenseVector([-120.0]), DenseVector([64.0]), DenseVector([13.0]), DenseVector([-163.0]), DenseVector([-47.0])]),
#  Row(hashes=[DenseVector([-32.0]), DenseVector([42.0]), DenseVector([9.0]), DenseVector([-91.0]), DenseVector([15.0])]),
#  Row(hashes=[DenseVector([-11.0]), DenseVector([58.0]), DenseVector([32.0]), DenseVector([-200.0]), DenseVector([2.0])]),
#  Row(hashes=[DenseVector([-69.0]), DenseVector([72.0]), DenseVector([63.0]), DenseVector([-136.0]), DenseVector([-41.0])]),
#  Row(hashes=[DenseVector([15.0]), DenseVector([90.0]), DenseVector([42.0]), DenseVector([-67.0]), DenseVector([52.0])]),
#  Row(hashes=[DenseVector([-26.0]), DenseVector([102.0]), DenseVector([-3.0]), DenseVector([-126.0]), DenseVector([-1.0])]),
#  Row(hashes=[DenseVector([-61.0]), DenseVector([65.0]), DenseVector([12.0]), DenseVector([-69.0]), DenseVector([16.0])]),
#  Row(hashes=[DenseVector([-19.0]), DenseVector([86.0]), DenseVector([74.0]), DenseVector([-108.0]), DenseVector([-4.0])]),
#  Row(hashes=[DenseVector([-66.0]), DenseVector([51.0]), DenseVector([-16.0]), DenseVector([-111.0]), DenseVector([-56.0])]),
#  Row(hashes=[DenseVector([10.0]), DenseVector([77.0]), DenseVector([-18.0]), DenseVector([-21.0]), DenseVector([15.0])]),
#  Row(hashes=[DenseVector([44.0]), DenseVector([51.0]), DenseVector([-43.0]), DenseVector([-51.0]), DenseVector([62.0])]),
#  Row(hashes=[DenseVector([4.0]), DenseVector([53.0]), DenseVector([18.0]), DenseVector([-69.0]), DenseVector([22.0])]),
#  Row(hashes=[DenseVector([16.0]), DenseVector([148.0]), DenseVector([81.0]), DenseVector([-108.0]), DenseVector([37.0])]),
#  Row(hashes=[DenseVector([-98.0]), DenseVector([-14.0]), DenseVector([4.0]), DenseVector([-13.0]), DenseVector([20.0])]),
#  Row(hashes=[DenseVector([-22.0]), DenseVector([45.0]), DenseVector([17.0]), DenseVector([-99.0]), DenseVector([-42.0])]),
#  Row(hashes=[DenseVector([21.0]), DenseVector([77.0]), DenseVector([34.0]), DenseVector([-171.0]), DenseVector([0.0])]),
#  Row(hashes=[DenseVector([-11.0]), DenseVector([45.0]), DenseVector([5.0]), DenseVector([-107.0]), DenseVector([10.0])]),
#  Row(hashes=[DenseVector([-18.0]), DenseVector([80.0]), DenseVector([0.0]), DenseVector([-81.0]), DenseVector([0.0])]),
#  Row(hashes=[DenseVector([-39.0]), DenseVector([80.0]), DenseVector([-30.0]), DenseVector([-109.0]), DenseVector([-68.0])]),
#  Row(hashes=[DenseVector([-34.0]), DenseVector([34.0]), DenseVector([-20.0]), DenseVector([-80.0]), DenseVector([16.0])]),
#  Row(hashes=[DenseVector([26.0]), DenseVector([66.0]), DenseVector([136.0]), DenseVector([-77.0]), DenseVector([-15.0])]),
#  Row(hashes=[DenseVector([42.0]), DenseVector([159.0]), DenseVector([61.0]), DenseVector([-108.0]), DenseVector([-27.0])]),
#  Row(hashes=[DenseVector([-31.0]), DenseVector([36.0]), DenseVector([46.0]), DenseVector([-130.0]), DenseVector([-40.0])]),
#  Row(hashes=[DenseVector([-80.0]), DenseVector([73.0]), DenseVector([72.0]), DenseVector([-192.0]), DenseVector([-47.0])]),
#  Row(hashes=[DenseVector([-70.0]), DenseVector([83.0]), DenseVector([-17.0]), DenseVector([-164.0]), DenseVector([24.0])]),
#  Row(hashes=[DenseVector([32.0]), DenseVector([13.0]), DenseVector([-4.0]), DenseVector([-120.0]), DenseVector([-129.0])]),
#  Row(hashes=[DenseVector([-188.0]), DenseVector([56.0]), DenseVector([-10.0]), DenseVector([-84.0]), DenseVector([-27.0])]),
#  Row(hashes=[DenseVector([-71.0]), DenseVector([46.0]), DenseVector([31.0]), DenseVector([-197.0]), DenseVector([-53.0])]),
#  Row(hashes=[DenseVector([41.0]), DenseVector([22.0]), DenseVector([-17.0]), DenseVector([-52.0]), DenseVector([13.0])]),
#  Row(hashes=[DenseVector([33.0]), DenseVector([9.0]), DenseVector([35.0]), DenseVector([-98.0]), DenseVector([-35.0])]),
#  Row(hashes=[DenseVector([16.0]), DenseVector([63.0]), DenseVector([-4.0]), DenseVector([-83.0]), DenseVector([32.0])]),
#  Row(hashes=[DenseVector([-50.0]), DenseVector([4.0]), DenseVector([-40.0]), DenseVector([-106.0]), DenseVector([4.0])]),
#  Row(hashes=[DenseVector([16.0]), DenseVector([78.0]), DenseVector([67.0]), DenseVector([-138.0]), DenseVector([26.0])]),
#  Row(hashes=[DenseVector([-24.0]), DenseVector([65.0]), DenseVector([-19.0]), DenseVector([-164.0]), DenseVector([5.0])]),
#  Row(hashes=[DenseVector([-47.0]), DenseVector([90.0]), DenseVector([-11.0]), DenseVector([-187.0]), DenseVector([32.0])]),
#  Row(hashes=[DenseVector([-137.0]), DenseVector([32.0]), DenseVector([37.0]), DenseVector([-120.0]), DenseVector([-47.0])]),
#  Row(hashes=[DenseVector([14.0]), DenseVector([31.0]), DenseVector([-21.0]), DenseVector([-98.0]), DenseVector([33.0])]),
#  Row(hashes=[DenseVector([-17.0]), DenseVector([60.0]), DenseVector([47.0]), DenseVector([-155.0]), DenseVector([-2.0])]),
#  Row(hashes=[DenseVector([42.0]), DenseVector([77.0]), DenseVector([0.0]), DenseVector([-123.0]), DenseVector([-29.0])]),
#  Row(hashes=[DenseVector([-96.0]), DenseVector([38.0]), DenseVector([-18.0]), DenseVector([-132.0]), DenseVector([9.0])]),
#  Row(hashes=[DenseVector([-96.0]), DenseVector([69.0]), DenseVector([-16.0]), DenseVector([-130.0]), DenseVector([0.0])]),
#  Row(hashes=[DenseVector([-23.0]), DenseVector([36.0]), DenseVector([14.0]), DenseVector([-101.0]), DenseVector([5.0])]),
#  Row(hashes=[DenseVector([-13.0]), DenseVector([119.0]), DenseVector([127.0]), DenseVector([-169.0]), DenseVector([12.0])]),
#  Row(hashes=[DenseVector([-20.0]), DenseVector([43.0]), DenseVector([-13.0]), DenseVector([-96.0]), DenseVector([9.0])]),
#  Row(hashes=[DenseVector([-34.0]), DenseVector([112.0]), DenseVector([35.0]), DenseVector([-112.0]), DenseVector([-63.0])]),
#  Row(hashes=[DenseVector([-45.0]), DenseVector([54.0]), DenseVector([-40.0]), DenseVector([-160.0]), DenseVector([-58.0])]),
#  Row(hashes=[DenseVector([-62.0]), DenseVector([92.0]), DenseVector([45.0]), DenseVector([-163.0]), DenseVector([-10.0])]),
#  Row(hashes=[DenseVector([-84.0]), DenseVector([95.0]), DenseVector([25.0]), DenseVector([-140.0]), DenseVector([7.0])]),
#  Row(hashes=[DenseVector([50.0]), DenseVector([23.0]), DenseVector([7.0]), DenseVector([-129.0]), DenseVector([-34.0])]),
#  Row(hashes=[DenseVector([-48.0]), DenseVector([45.0]), DenseVector([4.0]), DenseVector([-101.0]), DenseVector([-1.0])]),
#  Row(hashes=[DenseVector([-83.0]), DenseVector([53.0]), DenseVector([21.0]), DenseVector([-135.0]), DenseVector([-110.0])]),
#  Row(hashes=[DenseVector([-56.0]), DenseVector([41.0]), DenseVector([46.0]), DenseVector([-91.0]), DenseVector([-3.0])]),
#  Row(hashes=[DenseVector([-116.0]), DenseVector([59.0]), DenseVector([10.0]), DenseVector([-133.0]), DenseVector([-44.0])]),
#  Row(hashes=[DenseVector([-103.0]), DenseVector([113.0]), DenseVector([6.0]), DenseVector([-111.0]), DenseVector([22.0])]),
#  Row(hashes=[DenseVector([-115.0]), DenseVector([98.0]), DenseVector([81.0]), DenseVector([-148.0]), DenseVector([-80.0])]),
#  Row(hashes=[DenseVector([-123.0]), DenseVector([34.0]), DenseVector([29.0]), DenseVector([-187.0]), DenseVector([-5.0])]),
#  Row(hashes=[DenseVector([-128.0]), DenseVector([75.0]), DenseVector([-27.0]), DenseVector([-190.0]), DenseVector([-6.0])]),
#  Row(hashes=[DenseVector([-25.0]), DenseVector([0.0]), DenseVector([-11.0]), DenseVector([-51.0]), DenseVector([-22.0])]),
#  Row(hashes=[DenseVector([-145.0]), DenseVector([115.0]), DenseVector([55.0]), DenseVector([-150.0]), DenseVector([-43.0])]),
#  Row(hashes=[DenseVector([-82.0]), DenseVector([85.0]), DenseVector([-33.0]), DenseVector([-112.0]), DenseVector([93.0])]),
#  Row(hashes=[DenseVector([-9.0]), DenseVector([110.0]), DenseVector([17.0]), DenseVector([-146.0]), DenseVector([25.0])]),
#  Row(hashes=[DenseVector([-42.0]), DenseVector([58.0]), DenseVector([-9.0]), DenseVector([-108.0]), DenseVector([48.0])]),
#  Row(hashes=[DenseVector([-139.0]), DenseVector([53.0]), DenseVector([-12.0]), DenseVector([-23.0]), DenseVector([-44.0])]),
#  Row(hashes=[DenseVector([-207.0]), DenseVector([53.0]), DenseVector([16.0]), DenseVector([-110.0]), DenseVector([-79.0])]),
#  Row(hashes=[DenseVector([62.0]), DenseVector([87.0]), DenseVector([4.0]), DenseVector([-82.0]), DenseVector([-97.0])]),
#  Row(hashes=[DenseVector([-74.0]), DenseVector([-34.0]), DenseVector([63.0]), DenseVector([-19.0]), DenseVector([44.0])]),
#  Row(hashes=[DenseVector([-72.0]), DenseVector([83.0]), DenseVector([20.0]), DenseVector([-130.0]), DenseVector([7.0])]),
#  Row(hashes=[DenseVector([-78.0]), DenseVector([40.0]), DenseVector([-22.0]), DenseVector([-107.0]), DenseVector([-40.0])]),
#  Row(hashes=[DenseVector([-21.0]), DenseVector([91.0]), DenseVector([4.0]), DenseVector([-119.0]), DenseVector([-39.0])]),
#  Row(hashes=[DenseVector([9.0]), DenseVector([43.0]), DenseVector([3.0]), DenseVector([-8.0]), DenseVector([40.0])]),
#  Row(hashes=[DenseVector([-105.0]), DenseVector([92.0]), DenseVector([27.0]), DenseVector([-122.0]), DenseVector([-76.0])]),
#  Row(hashes=[DenseVector([-83.0]), DenseVector([59.0]), DenseVector([-36.0]), DenseVector([-70.0]), DenseVector([-13.0])]),
#  Row(hashes=[DenseVector([-2.0]), DenseVector([47.0]), DenseVector([7.0]), DenseVector([-98.0]), DenseVector([-13.0])]),
#  Row(hashes=[DenseVector([-93.0]), DenseVector([97.0]), DenseVector([-46.0]), DenseVector([-4.0]), DenseVector([98.0])]),
#  Row(hashes=[DenseVector([-103.0]), DenseVector([35.0]), DenseVector([13.0]), DenseVector([-60.0]), DenseVector([53.0])]),
#  Row(hashes=[DenseVector([-65.0]), DenseVector([55.0]), DenseVector([-30.0]), DenseVector([-126.0]), DenseVector([13.0])]),
#  Row(hashes=[DenseVector([-122.0]), DenseVector([23.0]), DenseVector([-31.0]), DenseVector([-209.0]), DenseVector([94.0])]),
#  Row(hashes=[DenseVector([-67.0]), DenseVector([72.0]), DenseVector([-18.0]), DenseVector([-66.0]), DenseVector([-4.0])]),
#  Row(hashes=[DenseVector([-61.0]), DenseVector([79.0]), DenseVector([-11.0]), DenseVector([-123.0]), DenseVector([-19.0])]),
#  Row(hashes=[DenseVector([-86.0]), DenseVector([35.0]), DenseVector([40.0]), DenseVector([-140.0]), DenseVector([-2.0])]),
#  Row(hashes=[DenseVector([-26.0]), DenseVector([84.0]), DenseVector([-27.0]), DenseVector([-111.0]), DenseVector([37.0])]),
#  Row(hashes=[DenseVector([37.0]), DenseVector([77.0]), DenseVector([21.0]), DenseVector([-46.0]), DenseVector([25.0])]),
#  Row(hashes=[DenseVector([-29.0]), DenseVector([39.0]), DenseVector([22.0]), DenseVector([-148.0]), DenseVector([13.0])]),
#  Row(hashes=[DenseVector([-9.0]), DenseVector([37.0]), DenseVector([-26.0]), DenseVector([-199.0]), DenseVector([-66.0])]),
#  Row(hashes=[DenseVector([-62.0]), DenseVector([-12.0]), DenseVector([-8.0]), DenseVector([-157.0]), DenseVector([-14.0])]),
#  Row(hashes=[DenseVector([-142.0]), DenseVector([18.0]), DenseVector([-3.0]), DenseVector([-121.0]), DenseVector([17.0])]),
#  Row(hashes=[DenseVector([-100.0]), DenseVector([77.0]), DenseVector([-30.0]), DenseVector([-136.0]), DenseVector([-34.0])]),
#  Row(hashes=[DenseVector([16.0]), DenseVector([73.0]), DenseVector([-5.0]), DenseVector([-56.0]), DenseVector([-66.0])]),
#  Row(hashes=[DenseVector([-60.0]), DenseVector([86.0]), DenseVector([53.0]), DenseVector([-184.0]), DenseVector([35.0])]),
#  Row(hashes=[DenseVector([-42.0]), DenseVector([54.0]), DenseVector([-17.0]), DenseVector([-104.0]), DenseVector([-2.0])]),
#  Row(hashes=[DenseVector([-61.0]), DenseVector([30.0]), DenseVector([-7.0]), DenseVector([-97.0]), DenseVector([-14.0])]),
#  Row(hashes=[DenseVector([-127.0]), DenseVector([85.0]), DenseVector([44.0]), DenseVector([-149.0]), DenseVector([13.0])]),
#  Row(hashes=[DenseVector([-59.0]), DenseVector([73.0]), DenseVector([32.0]), DenseVector([-64.0]), DenseVector([41.0])]),
#  Row(hashes=[DenseVector([-59.0]), DenseVector([72.0]), DenseVector([-11.0]), DenseVector([-122.0]), DenseVector([-24.0])]),
#  Row(hashes=[DenseVector([-41.0]), DenseVector([74.0]), DenseVector([-3.0]), DenseVector([-84.0]), DenseVector([0.0])]),
#  Row(hashes=[DenseVector([-30.0]), DenseVector([62.0]), DenseVector([39.0]), DenseVector([-89.0]), DenseVector([19.0])]),
#  Row(hashes=[DenseVector([-121.0]), DenseVector([64.0]), DenseVector([-37.0]), DenseVector([-148.0]), DenseVector([9.0])]),
#  Row(hashes=[DenseVector([-96.0]), DenseVector([72.0]), DenseVector([41.0]), DenseVector([-144.0]), DenseVector([-37.0])]),
#  Row(hashes=[DenseVector([-10.0]), DenseVector([62.0]), DenseVector([42.0]), DenseVector([-109.0]), DenseVector([-53.0])]),
#  Row(hashes=[DenseVector([-71.0]), DenseVector([61.0]), DenseVector([73.0]), DenseVector([-144.0]), DenseVector([18.0])]),
#  Row(hashes=[DenseVector([-144.0]), DenseVector([55.0]), DenseVector([-36.0]), DenseVector([-91.0]), DenseVector([70.0])]),
#  Row(hashes=[DenseVector([-4.0]), DenseVector([124.0]), DenseVector([10.0]), DenseVector([-93.0]), DenseVector([16.0])]),
#  Row(hashes=[DenseVector([-50.0]), DenseVector([151.0]), DenseVector([-113.0]), DenseVector([-122.0]), DenseVector([0.0])]),
#  Row(hashes=[DenseVector([-60.0]), DenseVector([-59.0]), DenseVector([54.0]), DenseVector([-96.0]), DenseVector([110.0])]),
#  Row(hashes=[DenseVector([13.0]), DenseVector([49.0]), DenseVector([45.0]), DenseVector([-102.0]), DenseVector([-9.0])]),
#  Row(hashes=[DenseVector([-32.0]), DenseVector([123.0]), DenseVector([33.0]), DenseVector([-57.0]), DenseVector([10.0])]),
#  Row(hashes=[DenseVector([43.0]), DenseVector([-19.0]), DenseVector([25.0]), DenseVector([-91.0]), DenseVector([38.0])]),
#  Row(hashes=[DenseVector([-101.0]), DenseVector([98.0]), DenseVector([-1.0]), DenseVector([-182.0]), DenseVector([59.0])]),
#  Row(hashes=[DenseVector([-81.0]), DenseVector([153.0]), DenseVector([-5.0]), DenseVector([-58.0]), DenseVector([56.0])]),
#  Row(hashes=[DenseVector([-35.0]), DenseVector([81.0]), DenseVector([80.0]), DenseVector([-145.0]), DenseVector([-43.0])]),
#  Row(hashes=[DenseVector([-12.0]), DenseVector([64.0]), DenseVector([-17.0]), DenseVector([-93.0]), DenseVector([30.0])]),
#  Row(hashes=[DenseVector([-5.0]), DenseVector([32.0]), DenseVector([44.0]), DenseVector([-128.0]), DenseVector([8.0])]),
#  Row(hashes=[DenseVector([-108.0]), DenseVector([103.0]), DenseVector([73.0]), DenseVector([-159.0]), DenseVector([-50.0])]),
#  Row(hashes=[DenseVector([-38.0]), DenseVector([59.0]), DenseVector([26.0]), DenseVector([-157.0]), DenseVector([12.0])]),
#  Row(hashes=[DenseVector([-23.0]), DenseVector([48.0]), DenseVector([53.0]), DenseVector([-98.0]), DenseVector([44.0])]),
#  Row(hashes=[DenseVector([-113.0]), DenseVector([81.0]), DenseVector([39.0]), DenseVector([-138.0]), DenseVector([41.0])]),
#  Row(hashes=[DenseVector([-38.0]), DenseVector([61.0]), DenseVector([35.0]), DenseVector([-116.0]), DenseVector([-17.0])]),
#  Row(hashes=[DenseVector([-121.0]), DenseVector([27.0]), DenseVector([4.0]), DenseVector([-105.0]), DenseVector([62.0])]),
#  Row(hashes=[DenseVector([-33.0]), DenseVector([87.0]), DenseVector([39.0]), DenseVector([-93.0]), DenseVector([71.0])]),
#  Row(hashes=[DenseVector([-39.0]), DenseVector([64.0]), DenseVector([41.0]), DenseVector([-179.0]), DenseVector([-47.0])]),
#  Row(hashes=[DenseVector([-74.0]), DenseVector([96.0]), DenseVector([-16.0]), DenseVector([-148.0]), DenseVector([-28.0])]),
#  Row(hashes=[DenseVector([-49.0]), DenseVector([117.0]), DenseVector([39.0]), DenseVector([-205.0]), DenseVector([-5.0])]),
#  Row(hashes=[DenseVector([-30.0]), DenseVector([58.0]), DenseVector([-6.0]), DenseVector([-80.0]), DenseVector([21.0])]),
#  Row(hashes=[DenseVector([-15.0]), DenseVector([64.0]), DenseVector([-32.0]), DenseVector([-113.0]), DenseVector([17.0])]),
#  Row(hashes=[DenseVector([-56.0]), DenseVector([14.0]), DenseVector([-64.0]), DenseVector([-165.0]), DenseVector([-99.0])]),
#  Row(hashes=[DenseVector([-138.0]), DenseVector([-5.0]), DenseVector([31.0]), DenseVector([-151.0]), DenseVector([-66.0])]),
#  Row(hashes=[DenseVector([-146.0]), DenseVector([43.0]), DenseVector([-46.0]), DenseVector([-94.0]), DenseVector([-29.0])]),
#  Row(hashes=[DenseVector([-75.0]), DenseVector([3.0]), DenseVector([66.0]), DenseVector([-154.0]), DenseVector([-36.0])]),
#  Row(hashes=[DenseVector([-56.0]), DenseVector([76.0]), DenseVector([-33.0]), DenseVector([-105.0]), DenseVector([-30.0])]),
#  Row(hashes=[DenseVector([-65.0]), DenseVector([99.0]), DenseVector([95.0]), DenseVector([-175.0]), DenseVector([-23.0])]),
#  Row(hashes=[DenseVector([-29.0]), DenseVector([73.0]), DenseVector([-8.0]), DenseVector([-125.0]), DenseVector([4.0])]),
#  Row(hashes=[DenseVector([-60.0]), DenseVector([111.0]), DenseVector([-4.0]), DenseVector([-70.0]), DenseVector([4.0])]),
#  Row(hashes=[DenseVector([-95.0]), DenseVector([52.0]), DenseVector([13.0]), DenseVector([-156.0]), DenseVector([12.0])]),
#  Row(hashes=[DenseVector([-15.0]), DenseVector([72.0]), DenseVector([-13.0]), DenseVector([-30.0]), DenseVector([26.0])]),
#  Row(hashes=[DenseVector([-72.0]), DenseVector([58.0]), DenseVector([3.0]), DenseVector([-110.0]), DenseVector([-9.0])]),
#  Row(hashes=[DenseVector([-102.0]), DenseVector([48.0]), DenseVector([66.0]), DenseVector([-102.0]), DenseVector([64.0])]),
#  Row(hashes=[DenseVector([-32.0]), DenseVector([31.0]), DenseVector([21.0]), DenseVector([-116.0]), DenseVector([33.0])]),
#  Row(hashes=[DenseVector([-72.0]), DenseVector([79.0]), DenseVector([88.0]), DenseVector([-137.0]), DenseVector([26.0])]),
#  Row(hashes=[DenseVector([-110.0]), DenseVector([20.0]), DenseVector([33.0]), DenseVector([-86.0]), DenseVector([15.0])]),
#  Row(hashes=[DenseVector([-38.0]), DenseVector([100.0]), DenseVector([-22.0]), DenseVector([-118.0]), DenseVector([-13.0])]),
#  Row(hashes=[DenseVector([85.0]), DenseVector([46.0]), DenseVector([32.0]), DenseVector([-77.0]), DenseVector([-14.0])]),
#  Row(hashes=[DenseVector([-55.0]), DenseVector([124.0]), DenseVector([23.0]), DenseVector([-92.0]), DenseVector([4.0])]),
#  Row(hashes=[DenseVector([-97.0]), DenseVector([53.0]), DenseVector([-58.0]), DenseVector([-86.0]), DenseVector([49.0])]),
#  Row(hashes=[DenseVector([-114.0]), DenseVector([-55.0]), DenseVector([38.0]), DenseVector([-143.0]), DenseVector([-47.0])]),
#  Row(hashes=[DenseVector([-87.0]), DenseVector([91.0]), DenseVector([52.0]), DenseVector([-187.0]), DenseVector([17.0])]),
#  Row(hashes=[DenseVector([-55.0]), DenseVector([60.0]), DenseVector([2.0]), DenseVector([-150.0]), DenseVector([63.0])]),
#  Row(hashes=[DenseVector([-33.0]), DenseVector([31.0]), DenseVector([17.0]), DenseVector([-95.0]), DenseVector([-58.0])]),
#  Row(hashes=[DenseVector([11.0]), DenseVector([26.0]), DenseVector([-19.0]), DenseVector([-54.0]), DenseVector([32.0])]),
#  Row(hashes=[DenseVector([-86.0]), DenseVector([98.0]), DenseVector([2.0]), DenseVector([-74.0]), DenseVector([26.0])]),
#  Row(hashes=[DenseVector([-121.0]), DenseVector([114.0]), DenseVector([34.0]), DenseVector([-57.0]), DenseVector([-2.0])]),
#  Row(hashes=[DenseVector([-146.0]), DenseVector([73.0]), DenseVector([5.0]), DenseVector([-95.0]), DenseVector([3.0])]),
#  Row(hashes=[DenseVector([-59.0]), DenseVector([62.0]), DenseVector([38.0]), DenseVector([-140.0]), DenseVector([-27.0])]),
#  Row(hashes=[DenseVector([-41.0]), DenseVector([52.0]), DenseVector([34.0]), DenseVector([-148.0]), DenseVector([-35.0])]),
#  Row(hashes=[DenseVector([-47.0]), DenseVector([86.0]), DenseVector([-46.0]), DenseVector([-46.0]), DenseVector([14.0])]),
#  Row(hashes=[DenseVector([-57.0]), DenseVector([38.0]), DenseVector([-3.0]), DenseVector([-132.0]), DenseVector([-102.0])]),
#  Row(hashes=[DenseVector([-38.0]), DenseVector([71.0]), DenseVector([1.0]), DenseVector([-124.0]), DenseVector([-24.0])]),
#  Row(hashes=[DenseVector([22.0]), DenseVector([129.0]), DenseVector([18.0]), DenseVector([-147.0]), DenseVector([9.0])]),
#  Row(hashes=[DenseVector([-106.0]), DenseVector([58.0]), DenseVector([72.0]), DenseVector([-113.0]), DenseVector([-4.0])]),
#  Row(hashes=[DenseVector([-33.0]), DenseVector([137.0]), DenseVector([-72.0]), DenseVector([-11.0]), DenseVector([8.0])]),
#  Row(hashes=[DenseVector([-63.0]), DenseVector([43.0]), DenseVector([-33.0]), DenseVector([-114.0]), DenseVector([-5.0])]),
#  Row(hashes=[DenseVector([-70.0]), DenseVector([68.0]), DenseVector([31.0]), DenseVector([-120.0]), DenseVector([8.0])]),
#  Row(hashes=[DenseVector([-14.0]), DenseVector([90.0]), DenseVector([45.0]), DenseVector([-183.0]), DenseVector([-12.0])]),
#  Row(hashes=[DenseVector([-107.0]), DenseVector([22.0]), DenseVector([67.0]), DenseVector([-84.0]), DenseVector([-110.0])]),
#  Row(hashes=[DenseVector([-94.0]), DenseVector([18.0]), DenseVector([-2.0]), DenseVector([-86.0]), DenseVector([-24.0])]),
#  Row(hashes=[DenseVector([-41.0]), DenseVector([95.0]), DenseVector([28.0]), DenseVector([-64.0]), DenseVector([17.0])]),
#  Row(hashes=[DenseVector([-65.0]), DenseVector([-1.0]), DenseVector([14.0]), DenseVector([-154.0]), DenseVector([14.0])]),
#  Row(hashes=[DenseVector([-4.0]), DenseVector([72.0]), DenseVector([62.0]), DenseVector([-134.0]), DenseVector([-81.0])]),
#  Row(hashes=[DenseVector([-8.0]), DenseVector([57.0]), DenseVector([4.0]), DenseVector([-159.0]), DenseVector([-44.0])]),
#  Row(hashes=[DenseVector([-27.0]), DenseVector([104.0]), DenseVector([35.0]), DenseVector([-166.0]), DenseVector([14.0])]),
#  Row(hashes=[DenseVector([14.0]), DenseVector([62.0]), DenseVector([-15.0]), DenseVector([-68.0]), DenseVector([46.0])]),
#  Row(hashes=[DenseVector([-99.0]), DenseVector([37.0]), DenseVector([-38.0]), DenseVector([-160.0]), DenseVector([-1.0])]),
#  Row(hashes=[DenseVector([-14.0]), DenseVector([1.0]), DenseVector([-50.0]), DenseVector([-16.0]), DenseVector([66.0])]),
#  Row(hashes=[DenseVector([-65.0]), DenseVector([41.0]), DenseVector([-12.0]), DenseVector([-82.0]), DenseVector([42.0])]),
#  Row(hashes=[DenseVector([-38.0]), DenseVector([103.0]), DenseVector([-6.0]), DenseVector([-79.0]), DenseVector([-8.0])]),
#  Row(hashes=[DenseVector([-141.0]), DenseVector([36.0]), DenseVector([-1.0]), DenseVector([-178.0]), DenseVector([-35.0])]),
#  Row(hashes=[DenseVector([30.0]), DenseVector([70.0]), DenseVector([40.0]), DenseVector([-140.0]), DenseVector([-32.0])]),
#  Row(hashes=[DenseVector([-81.0]), DenseVector([52.0]), DenseVector([46.0]), DenseVector([-155.0]), DenseVector([0.0])]),
#  Row(hashes=[DenseVector([-61.0]), DenseVector([82.0]), DenseVector([-12.0]), DenseVector([-155.0]), DenseVector([-61.0])]),
#  Row(hashes=[DenseVector([-110.0]), DenseVector([46.0]), DenseVector([63.0]), DenseVector([-130.0]), DenseVector([15.0])]),
#  Row(hashes=[DenseVector([-41.0]), DenseVector([49.0]), DenseVector([-32.0]), DenseVector([-4.0]), DenseVector([-34.0])]),
#  Row(hashes=[DenseVector([-1.0]), DenseVector([29.0]), DenseVector([100.0]), DenseVector([-114.0]), DenseVector([2.0])]),
#  Row(hashes=[DenseVector([-25.0]), DenseVector([91.0]), DenseVector([-16.0]), DenseVector([-91.0]), DenseVector([-25.0])]),
#  Row(hashes=[DenseVector([-10.0]), DenseVector([12.0]), DenseVector([8.0]), DenseVector([-65.0]), DenseVector([26.0])]),
#  Row(hashes=[DenseVector([-91.0]), DenseVector([110.0]), DenseVector([-58.0]), DenseVector([30.0]), DenseVector([-43.0])]),
#  Row(hashes=[DenseVector([-73.0]), DenseVector([64.0]), DenseVector([-33.0]), DenseVector([-121.0]), DenseVector([46.0])]),
#  Row(hashes=[DenseVector([-131.0]), DenseVector([147.0]), DenseVector([76.0]), DenseVector([-219.0]), DenseVector([32.0])]),
#  Row(hashes=[DenseVector([-40.0]), DenseVector([78.0]), DenseVector([46.0]), DenseVector([-152.0]), DenseVector([-2.0])]),
#  Row(hashes=[DenseVector([-49.0]), DenseVector([109.0]), DenseVector([-31.0]), DenseVector([-54.0]), DenseVector([-46.0])]),
#  Row(hashes=[DenseVector([-32.0]), DenseVector([48.0]), DenseVector([1.0]), DenseVector([-64.0]), DenseVector([-4.0])]),
#  Row(hashes=[DenseVector([-36.0]), DenseVector([70.0]), DenseVector([-5.0]), DenseVector([-96.0]), DenseVector([4.0])]),
#  Row(hashes=[DenseVector([2.0]), DenseVector([44.0]), DenseVector([6.0]), DenseVector([-137.0]), DenseVector([-37.0])]),
#  Row(hashes=[DenseVector([-53.0]), DenseVector([83.0]), DenseVector([-6.0]), DenseVector([-98.0]), DenseVector([-76.0])]),
#  Row(hashes=[DenseVector([-13.0]), DenseVector([5.0]), DenseVector([30.0]), DenseVector([-113.0]), DenseVector([11.0])]),
#  Row(hashes=[DenseVector([-52.0]), DenseVector([140.0]), DenseVector([2.0]), DenseVector([-128.0]), DenseVector([-62.0])]),
#  Row(hashes=[DenseVector([-35.0]), DenseVector([51.0]), DenseVector([5.0]), DenseVector([-95.0]), DenseVector([17.0])]),
#  Row(hashes=[DenseVector([-96.0]), DenseVector([141.0]), DenseVector([18.0]), DenseVector([-128.0]), DenseVector([108.0])]),
#  Row(hashes=[DenseVector([-127.0]), DenseVector([44.0]), DenseVector([-14.0]), DenseVector([-85.0]), DenseVector([2.0])]),
#  Row(hashes=[DenseVector([25.0]), DenseVector([75.0]), DenseVector([0.0]), DenseVector([-42.0]), DenseVector([-12.0])]),
#  Row(hashes=[DenseVector([-45.0]), DenseVector([35.0]), DenseVector([22.0]), DenseVector([-127.0]), DenseVector([49.0])]),
#  Row(hashes=[DenseVector([-99.0]), DenseVector([91.0]), DenseVector([2.0]), DenseVector([-149.0]), DenseVector([19.0])]),
#  Row(hashes=[DenseVector([-68.0]), DenseVector([53.0]), DenseVector([-36.0]), DenseVector([-82.0]), DenseVector([-13.0])]),
#  Row(hashes=[DenseVector([-61.0]), DenseVector([60.0]), DenseVector([54.0]), DenseVector([-140.0]), DenseVector([-3.0])]),
#  Row(hashes=[DenseVector([-64.0]), DenseVector([48.0]), DenseVector([31.0]), DenseVector([-110.0]), DenseVector([-1.0])]),
#  Row(hashes=[DenseVector([-175.0]), DenseVector([77.0]), DenseVector([-75.0]), DenseVector([0.0]), DenseVector([-18.0])]),
#  Row(hashes=[DenseVector([-49.0]), DenseVector([128.0]), DenseVector([40.0]), DenseVector([-80.0]), DenseVector([16.0])]),
#  Row(hashes=[DenseVector([-10.0]), DenseVector([37.0]), DenseVector([-33.0]), DenseVector([-42.0]), DenseVector([46.0])]),
#  Row(hashes=[DenseVector([-30.0]), DenseVector([31.0]), DenseVector([18.0]), DenseVector([-113.0]), DenseVector([17.0])]),
#  Row(hashes=[DenseVector([86.0]), DenseVector([55.0]), DenseVector([-3.0]), DenseVector([-80.0]), DenseVector([-151.0])]),
#  Row(hashes=[DenseVector([-54.0]), DenseVector([69.0]), DenseVector([1.0]), DenseVector([-93.0]), DenseVector([2.0])]),
#  Row(hashes=[DenseVector([-59.0]), DenseVector([2.0]), DenseVector([-72.0]), DenseVector([-87.0]), DenseVector([-19.0])]),
#  Row(hashes=[DenseVector([33.0]), DenseVector([93.0]), DenseVector([13.0]), DenseVector([-71.0]), DenseVector([58.0])]),
#  Row(hashes=[DenseVector([24.0]), DenseVector([86.0]), DenseVector([110.0]), DenseVector([-79.0]), DenseVector([2.0])]),
#  Row(hashes=[DenseVector([-85.0]), DenseVector([74.0]), DenseVector([-1.0]), DenseVector([-133.0]), DenseVector([-30.0])]),
#  Row(hashes=[DenseVector([-82.0]), DenseVector([91.0]), DenseVector([-70.0]), DenseVector([-146.0]), DenseVector([24.0])]),
#  Row(hashes=[DenseVector([-3.0]), DenseVector([86.0]), DenseVector([68.0]), DenseVector([-130.0]), DenseVector([4.0])]),
#  Row(hashes=[DenseVector([-48.0]), DenseVector([45.0]), DenseVector([50.0]), DenseVector([-115.0]), DenseVector([-10.0])]),
#  Row(hashes=[DenseVector([-11.0]), DenseVector([97.0]), DenseVector([100.0]), DenseVector([-173.0]), DenseVector([49.0])]),
#  Row(hashes=[DenseVector([-129.0]), DenseVector([62.0]), DenseVector([32.0]), DenseVector([-84.0]), DenseVector([-45.0])]),
#  Row(hashes=[DenseVector([-120.0]), DenseVector([70.0]), DenseVector([-33.0]), DenseVector([-138.0]), DenseVector([-12.0])]),
#  Row(hashes=[DenseVector([-90.0]), DenseVector([46.0]), DenseVector([-5.0]), DenseVector([-151.0]), DenseVector([1.0])]),
#  Row(hashes=[DenseVector([-72.0]), DenseVector([61.0]), DenseVector([32.0]), DenseVector([-110.0]), DenseVector([6.0])]),
#  Row(hashes=[DenseVector([-19.0]), DenseVector([75.0]), DenseVector([51.0]), DenseVector([-118.0]), DenseVector([-6.0])]),
#  Row(hashes=[DenseVector([-57.0]), DenseVector([72.0]), DenseVector([35.0]), DenseVector([-110.0]), DenseVector([-24.0])]),
#  Row(hashes=[DenseVector([-61.0]), DenseVector([77.0]), DenseVector([46.0]), DenseVector([-161.0]), DenseVector([69.0])]),
#  Row(hashes=[DenseVector([-72.0]), DenseVector([61.0]), DenseVector([-59.0]), DenseVector([-88.0]), DenseVector([-2.0])]),
#  Row(hashes=[DenseVector([-70.0]), DenseVector([63.0]), DenseVector([-7.0]), DenseVector([-63.0]), DenseVector([-39.0])]),
#  Row(hashes=[DenseVector([-45.0]), DenseVector([80.0]), DenseVector([40.0]), DenseVector([-123.0]), DenseVector([-27.0])]),
#  Row(hashes=[DenseVector([-50.0]), DenseVector([36.0]), DenseVector([-16.0]), DenseVector([-48.0]), DenseVector([-33.0])]),
#  Row(hashes=[DenseVector([-134.0]), DenseVector([-35.0]), DenseVector([-73.0]), DenseVector([24.0]), DenseVector([42.0])]),
#  Row(hashes=[DenseVector([-111.0]), DenseVector([170.0]), DenseVector([-41.0]), DenseVector([-150.0]), DenseVector([-9.0])]),
#  Row(hashes=[DenseVector([10.0]), DenseVector([53.0]), DenseVector([27.0]), DenseVector([-103.0]), DenseVector([-6.0])]),
#  Row(hashes=[DenseVector([-47.0]), DenseVector([93.0]), DenseVector([24.0]), DenseVector([-129.0]), DenseVector([65.0])]),
#  Row(hashes=[DenseVector([-64.0]), DenseVector([93.0]), DenseVector([-30.0]), DenseVector([-151.0]), DenseVector([-32.0])]),
#  Row(hashes=[DenseVector([-91.0]), DenseVector([99.0]), DenseVector([-80.0]), DenseVector([-107.0]), DenseVector([36.0])]),
# ...
#  Row(hashes=[DenseVector([-46.0]), DenseVector([97.0]), DenseVector([-21.0]), DenseVector([-96.0]), DenseVector([80.0])]),
#  Row(hashes=[DenseVector([-102.0]), DenseVector([80.0]), DenseVector([-34.0]), DenseVector([-227.0]), DenseVector([40.0])]),
#  Row(hashes=[DenseVector([-38.0]), DenseVector([95.0]), DenseVector([20.0]), DenseVector([-139.0]), DenseVector([-140.0])]),
#  Row(hashes=[DenseVector([-80.0]), DenseVector([33.0]), DenseVector([12.0]), DenseVector([-129.0]), DenseVector([10.0])]),
#  Row(hashes=[DenseVector([22.0]), DenseVector([48.0]), DenseVector([-20.0]), DenseVector([-109.0]), DenseVector([-42.0])]),
#  Row(hashes=[DenseVector([-106.0]), DenseVector([23.0]), DenseVector([-61.0]), DenseVector([-122.0]), DenseVector([-24.0])]),
#  Row(hashes=[DenseVector([-66.0]), DenseVector([64.0]), DenseVector([-15.0]), DenseVector([-78.0]), DenseVector([8.0])]),
#  Row(hashes=[DenseVector([5.0]), DenseVector([-39.0]), DenseVector([25.0]), DenseVector([-75.0]), DenseVector([12.0])]),
#  Row(hashes=[DenseVector([-101.0]), DenseVector([56.0]), DenseVector([87.0]), DenseVector([-172.0]), DenseVector([-72.0])]),
#  Row(hashes=[DenseVector([9.0]), DenseVector([82.0]), DenseVector([47.0]), DenseVector([-130.0]), DenseVector([18.0])]),
#  Row(hashes=[DenseVector([-29.0]), DenseVector([130.0]), DenseVector([66.0]), DenseVector([-76.0]), DenseVector([-4.0])]),
#  Row(hashes=[DenseVector([-34.0]), DenseVector([60.0]), DenseVector([6.0]), DenseVector([-96.0]), DenseVector([-38.0])]),
#  Row(hashes=[DenseVector([-5.0]), DenseVector([50.0]), DenseVector([27.0]), DenseVector([-120.0]), DenseVector([-12.0])]),
#  Row(hashes=[DenseVector([30.0]), DenseVector([67.0]), DenseVector([29.0]), DenseVector([-79.0]), DenseVector([24.0])]),
#  Row(hashes=[DenseVector([-81.0]), DenseVector([73.0]), DenseVector([-33.0]), DenseVector([-128.0]), DenseVector([-47.0])]),
#  Row(hashes=[DenseVector([-56.0]), DenseVector([21.0]), DenseVector([23.0]), DenseVector([-128.0]), DenseVector([-19.0])]),
#  Row(hashes=[DenseVector([-83.0]), DenseVector([61.0]), DenseVector([27.0]), DenseVector([-144.0]), DenseVector([-17.0])]),
#  Row(hashes=[DenseVector([-58.0]), DenseVector([103.0]), DenseVector([88.0]), DenseVector([-192.0]), DenseVector([36.0])]),
#  Row(hashes=[DenseVector([-93.0]), DenseVector([66.0]), DenseVector([-20.0]), DenseVector([-116.0]), DenseVector([-68.0])]),
#  Row(hashes=[DenseVector([-136.0]), DenseVector([92.0]), DenseVector([52.0]), DenseVector([-129.0]), DenseVector([53.0])]),
#  Row(hashes=[DenseVector([-74.0]), DenseVector([29.0]), DenseVector([41.0]), DenseVector([-84.0]), DenseVector([-13.0])]),
#  Row(hashes=[DenseVector([15.0]), DenseVector([87.0]), DenseVector([27.0]), DenseVector([-188.0]), DenseVector([29.0])]),
#  Row(hashes=[DenseVector([20.0]), DenseVector([96.0]), DenseVector([-28.0]), DenseVector([-152.0]), DenseVector([-57.0])]),
#  Row(hashes=[DenseVector([-66.0]), DenseVector([50.0]), DenseVector([-50.0]), DenseVector([-110.0]), DenseVector([39.0])]),
#  Row(hashes=[DenseVector([-126.0]), DenseVector([107.0]), DenseVector([36.0]), DenseVector([-172.0]), DenseVector([-73.0])]),
#  Row(hashes=[DenseVector([31.0]), DenseVector([11.0]), DenseVector([27.0]), DenseVector([-25.0]), DenseVector([77.0])]),
#  Row(hashes=[DenseVector([-112.0]), DenseVector([46.0]), DenseVector([22.0]), DenseVector([-62.0]), DenseVector([33.0])]),
#  Row(hashes=[DenseVector([2.0]), DenseVector([63.0]), DenseVector([-47.0]), DenseVector([-70.0]), DenseVector([-15.0])]),
#  Row(hashes=[DenseVector([-64.0]), DenseVector([64.0]), DenseVector([26.0]), DenseVector([-145.0]), DenseVector([19.0])]),
#  Row(hashes=[DenseVector([-48.0]), DenseVector([39.0]), DenseVector([4.0]), DenseVector([-100.0]), DenseVector([-28.0])]),
#  Row(hashes=[DenseVector([-148.0]), DenseVector([3.0]), DenseVector([98.0]), DenseVector([-154.0]), DenseVector([-13.0])]),
#  Row(hashes=[DenseVector([-62.0]), DenseVector([20.0]), DenseVector([28.0]), DenseVector([-139.0]), DenseVector([15.0])]),
#  Row(hashes=[DenseVector([-21.0]), DenseVector([53.0]), DenseVector([-5.0]), DenseVector([-91.0]), DenseVector([24.0])]),
#  Row(hashes=[DenseVector([-49.0]), DenseVector([62.0]), DenseVector([-14.0]), DenseVector([-135.0]), DenseVector([-49.0])]),
#  Row(hashes=[DenseVector([-25.0]), DenseVector([58.0]), DenseVector([5.0]), DenseVector([-123.0]), DenseVector([10.0])]),
#  Row(hashes=[DenseVector([-33.0]), DenseVector([15.0]), DenseVector([19.0]), DenseVector([-169.0]), DenseVector([-38.0])]),
#  Row(hashes=[DenseVector([-52.0]), DenseVector([20.0]), DenseVector([42.0]), DenseVector([-119.0]), DenseVector([-29.0])]),
#  Row(hashes=[DenseVector([-79.0]), DenseVector([50.0]), DenseVector([0.0]), DenseVector([-55.0]), DenseVector([29.0])]),
#  Row(hashes=[DenseVector([52.0]), DenseVector([-3.0]), DenseVector([18.0]), DenseVector([-61.0]), DenseVector([8.0])]),
#  Row(hashes=[DenseVector([-82.0]), DenseVector([44.0]), DenseVector([75.0]), DenseVector([-225.0]), DenseVector([-69.0])]),
#  Row(hashes=[DenseVector([-33.0]), DenseVector([74.0]), DenseVector([51.0]), DenseVector([-143.0]), DenseVector([-42.0])]),
#  Row(hashes=[DenseVector([-66.0]), DenseVector([55.0]), DenseVector([7.0]), DenseVector([-92.0]), DenseVector([-64.0])]),
#  Row(hashes=[DenseVector([14.0]), DenseVector([38.0]), DenseVector([1.0]), DenseVector([-62.0]), DenseVector([51.0])]),
#  Row(hashes=[DenseVector([44.0]), DenseVector([100.0]), DenseVector([30.0]), DenseVector([-63.0]), DenseVector([-9.0])]),
#  Row(hashes=[DenseVector([-47.0]), DenseVector([28.0]), DenseVector([22.0]), DenseVector([-74.0]), DenseVector([59.0])]),
#  Row(hashes=[DenseVector([-57.0]), DenseVector([28.0]), DenseVector([28.0]), DenseVector([-97.0]), DenseVector([-2.0])]),
#  Row(hashes=[DenseVector([-17.0]), DenseVector([69.0]), DenseVector([-13.0]), DenseVector([-1.0]), DenseVector([25.0])]),
#  Row(hashes=[DenseVector([-80.0]), DenseVector([88.0]), DenseVector([4.0]), DenseVector([-86.0]), DenseVector([-37.0])]),
#  Row(hashes=[DenseVector([-33.0]), DenseVector([83.0]), DenseVector([18.0]), DenseVector([-109.0]), DenseVector([6.0])]),
#  Row(hashes=[DenseVector([9.0]), DenseVector([76.0]), DenseVector([-1.0]), DenseVector([-108.0]), DenseVector([-16.0])]),
#  Row(hashes=[DenseVector([39.0]), DenseVector([69.0]), DenseVector([44.0]), DenseVector([-149.0]), DenseVector([-63.0])]),
#  Row(hashes=[DenseVector([-171.0]), DenseVector([-10.0]), DenseVector([69.0]), DenseVector([-154.0]), DenseVector([51.0])]),
#  Row(hashes=[DenseVector([-57.0]), DenseVector([132.0]), DenseVector([3.0]), DenseVector([-40.0]), DenseVector([-2.0])]),
#  Row(hashes=[DenseVector([-62.0]), DenseVector([27.0]), DenseVector([1.0]), DenseVector([-118.0]), DenseVector([41.0])]),
#  Row(hashes=[DenseVector([-29.0]), DenseVector([124.0]), DenseVector([43.0]), DenseVector([-76.0]), DenseVector([9.0])]),
#  Row(hashes=[DenseVector([-38.0]), DenseVector([58.0]), DenseVector([23.0]), DenseVector([-178.0]), DenseVector([-11.0])]),
#  Row(hashes=[DenseVector([-40.0]), DenseVector([59.0]), DenseVector([-23.0]), DenseVector([-100.0]), DenseVector([37.0])]),
#  Row(hashes=[DenseVector([-115.0]), DenseVector([-22.0]), DenseVector([89.0]), DenseVector([-197.0]), DenseVector([-20.0])]),
#  Row(hashes=[DenseVector([-89.0]), DenseVector([4.0]), DenseVector([57.0]), DenseVector([-123.0]), DenseVector([-100.0])]),
#  Row(hashes=[DenseVector([-66.0]), DenseVector([125.0]), DenseVector([-34.0]), DenseVector([-31.0]), DenseVector([10.0])]),
#  Row(hashes=[DenseVector([-46.0]), DenseVector([118.0]), DenseVector([-44.0]), DenseVector([24.0]), DenseVector([0.0])]),
#  Row(hashes=[DenseVector([50.0]), DenseVector([83.0]), DenseVector([-1.0]), DenseVector([-125.0]), DenseVector([-54.0])]),
#  Row(hashes=[DenseVector([-96.0]), DenseVector([54.0]), DenseVector([10.0]), DenseVector([-118.0]), DenseVector([12.0])]),
#  Row(hashes=[DenseVector([-141.0]), DenseVector([88.0]), DenseVector([22.0]), DenseVector([-64.0]), DenseVector([50.0])]),
#  Row(hashes=[DenseVector([-21.0]), DenseVector([9.0]), DenseVector([18.0]), DenseVector([-60.0]), DenseVector([10.0])]),
#  Row(hashes=[DenseVector([-31.0]), DenseVector([34.0]), DenseVector([73.0]), DenseVector([-136.0]), DenseVector([73.0])]),
#  Row(hashes=[DenseVector([-79.0]), DenseVector([65.0]), DenseVector([-34.0]), DenseVector([-91.0]), DenseVector([-50.0])]),
#  Row(hashes=[DenseVector([-31.0]), DenseVector([52.0]), DenseVector([88.0]), DenseVector([-109.0]), DenseVector([-74.0])]),
#  Row(hashes=[DenseVector([-84.0]), DenseVector([70.0]), DenseVector([11.0]), DenseVector([-137.0]), DenseVector([-46.0])]),
#  Row(hashes=[DenseVector([-54.0]), DenseVector([46.0]), DenseVector([12.0]), DenseVector([-130.0]), DenseVector([10.0])]),
#  Row(hashes=[DenseVector([-88.0]), DenseVector([78.0]), DenseVector([58.0]), DenseVector([-148.0]), DenseVector([16.0])]),
#  Row(hashes=[DenseVector([-132.0]), DenseVector([40.0]), DenseVector([-42.0]), DenseVector([-58.0]), DenseVector([-7.0])]),
#  Row(hashes=[DenseVector([-40.0]), DenseVector([43.0]), DenseVector([64.0]), DenseVector([-144.0]), DenseVector([-7.0])]),
#  Row(hashes=[DenseVector([-19.0]), DenseVector([17.0]), DenseVector([1.0]), DenseVector([-40.0]), DenseVector([65.0])]),
#  Row(hashes=[DenseVector([26.0]), DenseVector([-27.0]), DenseVector([-64.0]), DenseVector([-36.0]), DenseVector([-6.0])]),
#  Row(hashes=[DenseVector([-66.0]), DenseVector([29.0]), DenseVector([46.0]), DenseVector([-129.0]), DenseVector([55.0])]),
#  Row(hashes=[DenseVector([-72.0]), DenseVector([22.0]), DenseVector([44.0]), DenseVector([-117.0]), DenseVector([26.0])]),
#  Row(hashes=[DenseVector([34.0]), DenseVector([22.0]), DenseVector([5.0]), DenseVector([-91.0]), DenseVector([9.0])]),
#  Row(hashes=[DenseVector([11.0]), DenseVector([47.0]), DenseVector([-17.0]), DenseVector([-52.0]), DenseVector([2.0])]),
#  Row(hashes=[DenseVector([13.0]), DenseVector([53.0]), DenseVector([3.0]), DenseVector([-88.0]), DenseVector([42.0])]),
#  Row(hashes=[DenseVector([-82.0]), DenseVector([68.0]), DenseVector([-26.0]), DenseVector([-69.0]), DenseVector([35.0])]),
#  Row(hashes=[DenseVector([-40.0]), DenseVector([37.0]), DenseVector([34.0]), DenseVector([-187.0]), DenseVector([-35.0])]),
#  Row(hashes=[DenseVector([49.0]), DenseVector([85.0]), DenseVector([-17.0]), DenseVector([-118.0]), DenseVector([-34.0])]),
#  Row(hashes=[DenseVector([44.0]), DenseVector([54.0]), DenseVector([46.0]), DenseVector([-137.0]), DenseVector([97.0])]),
#  Row(hashes=[DenseVector([-37.0]), DenseVector([57.0]), DenseVector([18.0]), DenseVector([-80.0]), DenseVector([-46.0])]),
#  Row(hashes=[DenseVector([25.0]), DenseVector([92.0]), DenseVector([-20.0]), DenseVector([-123.0]), DenseVector([-63.0])]),
#  Row(hashes=[DenseVector([73.0]), DenseVector([185.0]), DenseVector([88.0]), DenseVector([-103.0]), DenseVector([-55.0])]),
#  Row(hashes=[DenseVector([-128.0]), DenseVector([51.0]), DenseVector([-16.0]), DenseVector([43.0]), DenseVector([-77.0])]),
#  Row(hashes=[DenseVector([-104.0]), DenseVector([100.0]), DenseVector([-25.0]), DenseVector([-196.0]), DenseVector([12.0])]),
#  Row(hashes=[DenseVector([-49.0]), DenseVector([65.0]), DenseVector([-33.0]), DenseVector([-52.0]), DenseVector([29.0])]),
#  Row(hashes=[DenseVector([-60.0]), DenseVector([81.0]), DenseVector([33.0]), DenseVector([-145.0]), DenseVector([35.0])]),
#  Row(hashes=[DenseVector([-35.0]), DenseVector([89.0]), DenseVector([40.0]), DenseVector([-123.0]), DenseVector([11.0])]),
#  Row(hashes=[DenseVector([-18.0]), DenseVector([91.0]), DenseVector([-44.0]), DenseVector([-106.0]), DenseVector([-17.0])]),
#  Row(hashes=[DenseVector([-46.0]), DenseVector([90.0]), DenseVector([36.0]), DenseVector([-156.0]), DenseVector([33.0])]),
#  Row(hashes=[DenseVector([-105.0]), DenseVector([25.0]), DenseVector([-22.0]), DenseVector([-95.0]), DenseVector([16.0])]),
#  Row(hashes=[DenseVector([-98.0]), DenseVector([74.0]), DenseVector([62.0]), DenseVector([-125.0]), DenseVector([-28.0])]),
#  Row(hashes=[DenseVector([-132.0]), DenseVector([94.0]), DenseVector([-16.0]), DenseVector([-126.0]), DenseVector([-43.0])]),
#  Row(hashes=[DenseVector([-97.0]), DenseVector([61.0]), DenseVector([24.0]), DenseVector([-165.0]), DenseVector([-32.0])]),
#  Row(hashes=[DenseVector([-43.0]), DenseVector([25.0]), DenseVector([39.0]), DenseVector([-142.0]), DenseVector([15.0])]),
#  Row(hashes=[DenseVector([-40.0]), DenseVector([139.0]), DenseVector([29.0]), DenseVector([-77.0]), DenseVector([49.0])]),
#  Row(hashes=[DenseVector([-41.0]), DenseVector([37.0]), DenseVector([43.0]), DenseVector([-98.0]), DenseVector([-31.0])]),
#  Row(hashes=[DenseVector([-65.0]), DenseVector([52.0]), DenseVector([-9.0]), DenseVector([-97.0]), DenseVector([35.0])]),
#  Row(hashes=[DenseVector([-30.0]), DenseVector([11.0]), DenseVector([61.0]), DenseVector([-115.0]), DenseVector([-21.0])]),
#  Row(hashes=[DenseVector([11.0]), DenseVector([25.0]), DenseVector([66.0]), DenseVector([-166.0]), DenseVector([31.0])]),
#  Row(hashes=[DenseVector([-36.0]), DenseVector([73.0]), DenseVector([-5.0]), DenseVector([-67.0]), DenseVector([61.0])]),
#  Row(hashes=[DenseVector([-88.0]), DenseVector([129.0]), DenseVector([4.0]), DenseVector([-163.0]), DenseVector([6.0])]),
#  Row(hashes=[DenseVector([2.0]), DenseVector([36.0]), DenseVector([-34.0]), DenseVector([-88.0]), DenseVector([-15.0])]),
#  Row(hashes=[DenseVector([-106.0]), DenseVector([128.0]), DenseVector([21.0]), DenseVector([-170.0]), DenseVector([-16.0])]),
#  Row(hashes=[DenseVector([-127.0]), DenseVector([21.0]), DenseVector([45.0]), DenseVector([-86.0]), DenseVector([-81.0])]),
#  Row(hashes=[DenseVector([-114.0]), DenseVector([56.0]), DenseVector([41.0]), DenseVector([-129.0]), DenseVector([-22.0])]),
#  Row(hashes=[DenseVector([-98.0]), DenseVector([123.0]), DenseVector([20.0]), DenseVector([-102.0]), DenseVector([-91.0])]),
#  Row(hashes=[DenseVector([-58.0]), DenseVector([88.0]), DenseVector([104.0]), DenseVector([-153.0]), DenseVector([-18.0])]),
#  Row(hashes=[DenseVector([-139.0]), DenseVector([73.0]), DenseVector([21.0]), DenseVector([-81.0]), DenseVector([-28.0])]),
#  Row(hashes=[DenseVector([-92.0]), DenseVector([84.0]), DenseVector([6.0]), DenseVector([-137.0]), DenseVector([-14.0])]),
#  Row(hashes=[DenseVector([-61.0]), DenseVector([65.0]), DenseVector([11.0]), DenseVector([-80.0]), DenseVector([-50.0])]),
#  Row(hashes=[DenseVector([-45.0]), DenseVector([33.0]), DenseVector([53.0]), DenseVector([-163.0]), DenseVector([-18.0])]),
#  Row(hashes=[DenseVector([-132.0]), DenseVector([67.0]), DenseVector([-7.0]), DenseVector([-90.0]), DenseVector([15.0])]),
#  Row(hashes=[DenseVector([-44.0]), DenseVector([50.0]), DenseVector([64.0]), DenseVector([-156.0]), DenseVector([-14.0])]),
#  Row(hashes=[DenseVector([-88.0]), DenseVector([50.0]), DenseVector([12.0]), DenseVector([-97.0]), DenseVector([-2.0])]),
#  Row(hashes=[DenseVector([-76.0]), DenseVector([30.0]), DenseVector([39.0]), DenseVector([-116.0]), DenseVector([4.0])]),
#  Row(hashes=[DenseVector([-38.0]), DenseVector([119.0]), DenseVector([-5.0]), DenseVector([-195.0]), DenseVector([-31.0])]),
#  Row(hashes=[DenseVector([-76.0]), DenseVector([22.0]), DenseVector([-5.0]), DenseVector([-129.0]), DenseVector([-61.0])]),
#  Row(hashes=[DenseVector([-137.0]), DenseVector([27.0]), DenseVector([76.0]), DenseVector([-222.0]), DenseVector([15.0])]),
#  Row(hashes=[DenseVector([-75.0]), DenseVector([29.0]), DenseVector([12.0]), DenseVector([-108.0]), DenseVector([-8.0])]),
#  Row(hashes=[DenseVector([-128.0]), DenseVector([4.0]), DenseVector([-5.0]), DenseVector([0.0]), DenseVector([-3.0])]),
#  Row(hashes=[DenseVector([-105.0]), DenseVector([66.0]), DenseVector([0.0]), DenseVector([-146.0]), DenseVector([-47.0])]),
#  Row(hashes=[DenseVector([-105.0]), DenseVector([49.0]), DenseVector([-37.0]), DenseVector([-69.0]), DenseVector([-14.0])]),
#  Row(hashes=[DenseVector([-57.0]), DenseVector([65.0]), DenseVector([28.0]), DenseVector([-122.0]), DenseVector([-39.0])]),
#  Row(hashes=[DenseVector([-8.0]), DenseVector([53.0]), DenseVector([-15.0]), DenseVector([-82.0]), DenseVector([9.0])]),
#  ...]

# %% [markdown]
# ## Query the fist image from test dataset to see how well the LSH works

# %%
key = Vectors.dense(X_test[0][0:-2])
result = model.approxNearestNeighbors(Train_df, key, 10000, distCol="EuclideanDistance")

# %%
resultList = result.select("label").rdd.flatMap(lambda x: x).collect()
targetLabel = Vectors.dense(X_test[0][-2])
print("targetLabel:")
print(targetLabel)
print("The top 10 neighbours:")
resultList[:10]
# Out:
# targetLabel:
# [6.0]
# The top 10 neighbours:
# [85, 91, 36, 70, 65, 91, 91, 35, 95, 97]

# %% [markdown]
# ## Check the size of returned neighbours
# we have total 6000 images in training dataset.
# if the size of resultList is large, it means that we probably hashed more images into the same bucket than we expected. Function BucketedRandomProjectionLSH paramters:  bucketLength, numHashTables need to be changed.

# %%
len(resultList)
# Out:
# 169

# %% [markdown]
# ## To run all the testdata with LSH and evaluate the result

# %%
def getBestPerformance(numOfTest, bucketLength,numHashTables,numOfNeighbor):
 
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
#     Train = map(lambda x: (int(x[-1]),int(x[-2]),Vectors.dense(x[:-2])), X_train)
#     Train_df = spark.createDataFrame(Train,schema=['id','label',"features"])
#     Test = map(lambda x: (int(x[-1]),int(x[-2]),Vectors.dense(x[:-2])), X_test)
#     Test_df = spark.createDataFrame(Test,schema=['id','label',"features"])

    brp = BucketedRandomProjectionLSH(inputCol="features", outputCol="hashes", 
                                      bucketLength=bucketLength,numHashTables=numHashTables)
    model = brp.fit(Train_df)
    transformedDF = model.transform(Train_df)
  
    nnToMajorityAccMap = {}
    nnToWeightedAccMap = {}
    with progressbar.ProgressBar(max_value = numOfTest) as bar:
        for i in range(0, numOfTest):
            Catg = X_test[i][-2]
            key = Vectors.dense(X_test[i][0:-2])
            # Choose the Last one of numOfNeighbor, the biggest one 
            result = model.approxNearestNeighbors(transformedDF, key, numOfNeighbor[-1], distCol="EuclideanDistance")
            # Convert pySpark framework colunm to python list
            labelList = result.select("label").rdd.flatMap(lambda x: x).collect()
            # Build a distance dataframe for the distance between query and result
            result1 = result.select('label', 'EuclideanDistance').collect()
            df_weighted = pd.DataFrame()
            df_weighted['Label'] = [int(row['label']) for row in result1]
            df_weighted['EuclideanDistance'] = [float(row['EuclideanDistance']) for row in result1]
            df_weighted['Weight'] = 1 / df_weighted['EuclideanDistance'] # query 和 result的Ed越大，权重越低
            # slice LabelList into different length subLists 
            nnList = []
            for numberNN in numOfNeighbor:
                slicedList = labelList[0:numberNN]
                nnList.append(slicedList)
                
            for index in range(0, len(nnList)):
                majority_vote = Counter(nnList[index]).most_common(1)[0][0]
                if  Catg == majority_vote:
                    key = "M" + str(numOfNeighbor[index])
                    if key in nnToMajorityAccMap:
                        nnToMajorityAccMap[key] = nnToMajorityAccMap.get(key) + 1
                    else:
                        nnToMajorityAccMap[key] = 1
                        
            for n in numOfNeighbor:
                weighted_result = df_weighted.head(n).groupby('Label')['Weight'].sum()
                df_weighted_result = pd.DataFrame(weighted_result)
                df_weighted_result = df_weighted_result.reset_index()
                df_weighted_result.sort_values(by='Weight',inplace=True,ascending=False)
                weighted_vote = df_weighted_result.iloc[0]['Label'].astype('int')
                if  Catg == weighted_vote:
                    key = "W" + str(n)
                    if key in nnToWeightedAccMap:
                        nnToWeightedAccMap[key] = nnToWeightedAccMap.get(key) + 1
                    else:
                        nnToWeightedAccMap[key] = 1
                        
            bar.update(i)
        
        # calculate accuracy base on Majority Vote
        for key in nnToMajorityAccMap:
            nnToMajorityAccMap[key] = nnToMajorityAccMap.get(key) / numOfTest
        # calculate accuracy base on Weighted Vote
        for key in nnToWeightedAccMap:
            nnToWeightedAccMap[key] = nnToWeightedAccMap.get(key) / numOfTest    
    return nnToMajorityAccMap, nnToWeightedAccMap

# %%
#set Param 
bucketLengthList = np.arange(0.008, 0.010,0.002)
numHashTablesList = np.arange(18, 20, 1)
numHashTablesList[0] = 3
#make sure the last element of numOfNeighborList is the largest
numOfNeighborList = [3];
numOfTest = 1000
print("Checking bucketLength Param:")
print(bucketLengthList)
print("Checking numHashTablesList Param:")
print(numHashTablesList)
# Out:
# Checking bucketLength Param:
# [0.008]
# Checking numHashTablesList Param:
# [ 3 19]

# %%
# %%time
bucketLengthList_para=[]
numHashTablesList_para=[]
resultMList = []
resultWList = []
for i in bucketLengthList:
    for j in numHashTablesList:
            resultM, resultW = getBestPerformance(numOfTest ,i, j, numOfNeighborList)
            print( "bucketLen:" + str(i) + "  #Hashtable:" + str(j) +  "  Majority Vote Acc: " + str(resultM))
            print( "bucketLen:" + str(i) + "  #Hashtable:" + str(j) +  "  Weighted Vote Acc: " + str(resultW))
            bucketLengthList_para.append(i)
            numHashTablesList_para.append(j)
            resultMList.append(resultM)
            resultWList.append(resultW)
# Out:
# 100% (1000 of 1000) |####################| Elapsed Time: 0:32:35 Time:  0:32:35
# bucketLen:0.008  #Hashtable:3  Majority Vote Acc: {'M3': 0.374}
# bucketLen:0.008  #Hashtable:3  Weighted Vote Acc: {'W3': 0.375}
# 100% (1000 of 1000) |####################| Elapsed Time: 0:40:57 Time:  0:40:57
# bucketLen:0.008  #Hashtable:19  Majority Vote Acc: {'M3': 0.47}
# bucketLen:0.008  #Hashtable:19  Weighted Vote Acc: {'W3': 0.473}
# CPU times: user 58.9 s, sys: 14.8 s, total: 1min 13s
# Wall time: 1h 13min 41s

# %%
df_result = pd.DataFrame()
df_result['BucketLength'] = bucketLengthList_para
df_result['NumHashTables'] = numHashTablesList_para
# conver List of map to panda dataframework
df_result_map =  pd.DataFrame(resultMList)
df_result_map2 = pd.DataFrame(resultWList)
df_result = pd.concat([df_result, df_result_map], axis=1, join='inner')
df_result = pd.concat([df_result, df_result_map2], axis=1, join='inner')
#save the result to a csv file
df_result.to_csv('./result3.csv')

# %%
df_result
# Out:
#     BucketLength  NumHashTables     M3     W3
# 0          0.002              3  0.330  0.330
# 1          0.002             11  0.410  0.415
# 2          0.002             19  0.415  0.415
# 3          0.004              3  0.370  0.370
# 4          0.004             11  0.470  0.470
# 5          0.004             19  0.470  0.470
# 6          0.006              3  0.405  0.405
# 7          0.006             11  0.480  0.485
# 8          0.006             19  0.485  0.485
# 9          0.008              3  0.385  0.385
# 10         0.008             11  0.480  0.480
# 11         0.008             19  0.490  0.490
