# %% [markdown]
# # Lecture 4: Min-Hashing
#
# ## Overview
#
# 1. Using PyMinHash to find matches of strings.
# 2. A more detailed example to show the implementation of Min-Hashing

# %% [markdown]
# This example shows how to use PyMinHash to find matches of strings.

# %% [markdown]
# First, import Pandas and fix some settings.

# %%
# %config Completer.use_jedi = False

import pandas as pd

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_row', 500)
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# PyMinHash comes with a toy dataset containing various name and address combinations of Stoxx50 companies.

# %%
from pyminhash.datasets import load_data
df = load_data()
df.head()
# Out:
#                                                            name
# 0                 adidas ag adi dassler strasse 1 91074 germany
# 1          adidas ag adi dassler strasse 1 91074 herzogenaurach
# 2  adidas ag adi dassler strasse 1 91074 herzogenaurach germany
# 3                          airbus se 2333 cs leiden netherlands
# 4                                 airbus se 2333 cs netherlands

# %% [markdown]
# We're going to match various representations that belong to the same company. For this, we import create a `MinHash` object and tell it to use 10 hash tables. More hash tables means more accurate Jaccard similarity calculation but also requires more time and memory.

# %%
from pyminhash.pyminhash import MinHash
myHasher = MinHash(n_hash_tables=10)

# %% [markdown]
# The `fit_predict` method needs the dataframe and the name of the column to which minhashing should be applied. The result is a dataframe containing all pairs that have a non-zero Jaccard similarity:

# %%
result = myHasher.fit_predict(df, 'name')
result.head()
# Out:
#      row_number_1  row_number_2  \
# 0               0             1
# 296            32            33
# 1               0             2
# 588            24            25
# 593            12            13
#
#                                                                       name_1  \
# 0                              adidas ag adi dassler strasse 1 91074 germany
# 296  bayerische motoren werke aktiengesellschaft petuelring 130 80788 munich
# 1                              adidas ag adi dassler strasse 1 91074 germany
# 588                                       banco santander  s a  28660 madrid
# 593                           anheuser busch inbev sa nv 3000 leuven belgium
#
#                                                                         name_2  \
# 0                         adidas ag adi dassler strasse 1 91074 herzogenaurach
# 296  bayerische motoren werke aktiengesellschaft petuelring 130 munich germany
# 1                 adidas ag adi dassler strasse 1 91074 herzogenaurach germany
# 588                                   banco santander  s a  28660 madrid spain
# 593            anheuser busch inbev sa nv brouwerijplein 1 3000 leuven belgium
#
#      jaccard_sim
# 0            1.0
# 296          1.0
# 1            1.0
# 588          1.0
# 593          1.0

# %% [markdown]
# As one can see below, for a Jaccard similarity of 1.0, all words in the shortest string appear in the longest string. For lower Jaccard similarity values, the match is less than perfect. Note that Jaccard similarity has granularity of 1/n_hash_tables, in this example 0.1.

# %%
result.groupby('jaccard_sim').head(2)
# Out:
#      row_number_1  row_number_2  \
# 0               0             1
# 296            32            33
# 351            55            56
# 78             62            64
# 581            23            24
# 783            83            84
# 306            92            93
# 808            90            91
# 159             4             5
# 23             39            41
# 755            44            61
# 192            69            70
# 217            80            81
# 424            75            99
# 688           100           103
# 320             8           113
# 494            68           127
# 26              1            51
# 804            18            91
# 849            74           104
#
#                                                                                    name_1  \
# 0                                           adidas ag adi dassler strasse 1 91074 germany
# 296               bayerische motoren werke aktiengesellschaft petuelring 130 80788 munich
# 351                                engie sa 1  place samuel de champlain 92400 courbevoie
# 78   fresenius se   co  kgaa else kroner strasse 1 61352 bad homburg vor der hohe germany
# 581                                                           banco santander  s a  28660
# 783                                                 l air liquide s a  75007 paris france
# 306        munchener ruckversicherungs gesellschaft aktiengesellschaft koniginstrasse 107
# 808     lvmh moet hennessy   louis vuitton  societe europeenne 22  avenue montaigne paris
# 159                                                         airbus se 2333 cs netherlands
# 23                                                     daimler ag 70372 stuttgart germany
# 755                                                               danone s a  75439 paris
# 192                                     ing groep n v  bijlmerplein 888 1102 mg amsterdam
# 217                              koninklijke philips n v  amstelplein 2 1096 bc amsterdam
# 424                                         kering sa 40 rue de sevres 75007 paris france
# 688                                                                     orange s a  paris
# 320                                                             allianz se munich germany
# 494  industria de diseno textil  s a  avenida de la diputacion s n arteixo a coruna spain
# 26                                   adidas ag adi dassler strasse 1 91074 herzogenaurach
# 804                                                                    axa sa 75008 paris
# 849                                                kering sa 40 rue de sevres 75007 paris
#
#                                                                                           name_2  \
# 0                                           adidas ag adi dassler strasse 1 91074 herzogenaurach
# 296                    bayerische motoren werke aktiengesellschaft petuelring 130 munich germany
# 351                                           engie sa 1  place samuel de champlain 92400 france
# 78                fresenius se   co  kgaa else kroner strasse 1 bad homburg vor der hohe germany
# 581                                                           banco santander  s a  28660 madrid
# 783                                                              l air liquide s a  paris france
# 306  munchener ruckversicherungs gesellschaft aktiengesellschaft koniginstrasse 107 80802 munich
# 808                          lvmh moet hennessy   louis vuitton  societe europeenne 75008 france
# 159                                                                 airbus se leiden netherlands
# 23                                        daimler ag mercedesstrasse 120 70372 stuttgart germany
# 755                                           essilorluxottica 1 6 rue paul cezanne paris france
# 192                                          ing groep n v  bijlmerplein 888 1102 mg netherlands
# 217                                   koninklijke philips n v  amstelplein 2 1096 bc netherlands
# 424                                     orange s a  78  rue olivier de serres 75015 paris france
# 688                                                                       safran sa paris france
# 320                                                    siemens aktiengesellschaft munich germany
# 494                                                vinci sa 1  cours ferdinand de lesseps france
# 26                                                        deutsche telekom ag 53113 bonn germany
# 804                          lvmh moet hennessy   louis vuitton  societe europeenne 75008 france
# 849                                                        sanofi 54  rue la boetie 75008 france
#
#      jaccard_sim
# 0            1.0
# 296          1.0
# 351          0.9
# 78           0.9
# 581          0.8
# 783          0.8
# 306          0.7
# 808          0.7
# 159          0.6
# 23           0.6
# 755          0.5
# 192          0.5
# 217          0.4
# 424          0.4
# 688          0.3
# 320          0.3
# 494          0.2
# 26           0.2
# 804          0.1
# 849          0.1
