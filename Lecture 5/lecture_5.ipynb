# %% [markdown]
# # Lecture 5: Locality-Sensitive Hashing

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import heapq
from scipy import spatial
from scipy.spatial import distance
from tqdm.notebook import tqdm, trange
import copy
import random
import cv2

# %% [markdown]
# # Table of Contents
#
# 1. Import Dataset
# 2. Vizualise CIFAR
# 3. Dimensionality Reduction on Image Feature Vectors
# 4. Data Structure Class Definitions
# 5. Populate Each Data Structure with CIFAR10 Data
# 6. Test Search Query Performance
# 7. Plotting and Batch Testing
# 8. Visual Examples

# %% [markdown]
# # 1. Import CIFAR10 Dataset

# %% [markdown]
# Note: Each row of the "images" array produced below stores one of the 60,000 32x32 color images. The first 1024 entries contain the red channel values, the next 1024 the green, and the final 1024 the blue. The image is stored in row-major order, so that the first 32 entries of the array are the red channel values of the first row of the image.

# %%
# function for unpickling the CIFAR10 dataset
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

DATA_ROOT = "CIFAR10/cifar-10-batches-py/"

# import CIFAR10 image batches
batch1 = unpickle(DATA_ROOT + "data_batch_1")
batch2 = unpickle(DATA_ROOT + "data_batch_2")
batch3 = unpickle(DATA_ROOT + "data_batch_3")
batch4 = unpickle(DATA_ROOT + "data_batch_4")
batch5 = unpickle(DATA_ROOT + "data_batch_5")
test_batch = unpickle(DATA_ROOT + "test_batch")

images = np.concatenate([batch1[b'data'], batch2[b'data'], batch3[b'data'], batch4[b'data'], batch5[b'data'], test_batch[b'data']])

# convert image bytes to imgs
images_rgb = np.zeros((len(images), 32, 32, 3))
for i in range(len(images)):
  im = images[i]
  im_r = im[0:1024].reshape(32, 32)
  im_g = im[1024:2048].reshape(32, 32)
  im_b = im[2048:].reshape(32, 32)
  im_rgb = np.dstack((im_r, im_g, im_b)) / 255.0
  images_rgb[i,:,:,:] = im_rgb
  
images = images_rgb

# confirm correct size of data array
print("Data dimensions: ", np.shape(images))
# Out:
# Data dimensions:  (60000, 32, 32, 3)

# %% [markdown]
# # 2. Visualize CIFAR

# %%
## functions for displaying cifar images

def cifar10_plot_single(data, im_idx=0):
    img = data[im_idx]    
    plt.imshow(img) 

def cifar10_plot_examples(data):
  
  for i in range(9):
    img = data[i]
    # define subplot
    plt.subplot(330 + 1 + i)
    # plot 
    plt.imshow(img)

# %%
cifar10_plot_examples(images)

# %%
cifar10_plot_single(images, im_idx=4)

# %% [markdown]
# # 3. Perform Dimensionality Reduction on Image Feature Vectors

# %%
#Functions for PCA

# returns image feature vectors reduced to PCA component count in n_components
# also returns 'recovered' images for comparison, transformed from the reduced set back to original 32x32 space
def pca_reduce(images, n_components):
  pca = PCA(n_components = n_components)

  flat_grays = np.zeros((len(images), 1024))
  for i in range(len(images)):
    img = (images[i]*255).astype('uint8')
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    flat_grays[i] = gray.flatten()

  print(flat_grays.shape)
  images_reduced = pca.fit_transform(flat_grays)
  images_recovered = pca.inverse_transform(images_reduced)
  
  print("Image data reduced from: {} to {}".format(images.shape, images_reduced.shape))
  print()
  print("Explained variance ratio of each component: ")
  print(pca.explained_variance_ratio_)
  plt.plot(pca.explained_variance_ratio_)
  plt.show()
  plt.grid()
  plt.plot(np.cumsum(pca.explained_variance_ratio_ * 100))
  plt.xlabel('Number of components')
  plt.ylabel('Explained variance')
  plt.show()
  
  return pca, images_reduced, images_recovered

# to inspect the PCA predicted images
def plot_pca_image(images, images_recovered, idx = 1):
    plt.subplot(1, 2, 1)
    cifar10_plot_single(images, im_idx= idx)
    plt.subplot(1, 2, 2)
    cifar10_plot_single(images_recovered.astype(int), im_idx = idx)
    plt.show()

# %%
# change "dimensions" value to specify the number of features you would like to reduce each image to
dimensions = 100 
pca, images_reduced, images_recovered = pca_reduce(images, dimensions)
# Out:
# (60000, 1024)
# Image data reduced from: (60000, 32, 32, 3) to (60000, 100)
#
# Explained variance ratio of each component:
# [0.30495241 0.12407202 0.07349322 0.0409553  0.03129289 0.03023718
#  0.0240765  0.02290549 0.01621097 0.01450675 0.01194305 0.01176234
#  0.0112038  0.01029701 0.00911463 0.00793329 0.00724078 0.00662753
#  0.00658542 0.00554687 0.0055229  0.0052274  0.0050645  0.00501015
#  0.0044929  0.00445881 0.0040972  0.00377078 0.00362951 0.00348264
#  0.00343243 0.00326535 0.0029279  0.00291042 0.00284955 0.00278554
#  0.00272804 0.00257789 0.00255832 0.00248114 0.00236725 0.0023116
#  0.00216338 0.00213573 0.00205927 0.00203253 0.00195406 0.00192038
#  0.00181764 0.00178561 0.00175051 0.00174004 0.00168514 0.00164485
#  0.00160209 0.00158818 0.00153893 0.00150936 0.00149354 0.00144647
#  0.00139332 0.00136225 0.00135795 0.00127635 0.00126533 0.00125596
#  0.00124303 0.00117571 0.00116303 0.00114228 0.00112229 0.00111339
#  0.00109966 0.00108831 0.00104836 0.00104016 0.0010152  0.00099656
#  0.00098749 0.00097455 0.00094998 0.00094048 0.00092665 0.00090985
#  0.00089121 0.0008826  0.0008379  0.00083692 0.00083073 0.0008133
#  0.00080056 0.0007924  0.00077402 0.00075931 0.00075675 0.00074982
#  0.00074829 0.00072321 0.00070839 0.00069807]

# %% [markdown]
# # 4. Data Structure Class Definitions

# %% [markdown]
# ## kd-Tree

# %%
class kdNode:
  """
  Nodes used to store data in the kd-tree.

  data_idx: the row index of the image represented by the node in the tree's dataset
  discriminator: the feature dimension used to split the kd-tree at the node's level
  """
  def __init__(self, data_idx, discriminator, lchild=None, rchild=None):
    self.data_idx = data_idx
    self.discriminator = discriminator
    self.lchild = lchild
    self.rchild = rchild
    
  def __repr__(self):
    return f"Node with Index {self.data_idx}"


class knnHeapNode:
  """
  Object used to keep track of kNNs during kdTree.find_kNN()
  """
  def __init__(self, kdnode, L2Dist):
    self.node = kdnode
    self.L2Dist = L2Dist

  # override the less-than operator to change heapq from min heap to max heap when made of knnHeapNodes
  def __lt__(self, other):
    return self.L2Dist > other.L2Dist

  def __repr__(self):
    return f"(Node Index: {self.node.data_idx}, L2 Distance: {self.L2Dist})"


class kdTree:
  
  def __init__(self):
    self.root = None
    self.data = None

  def builder(self, data, discriminator=0):
    """
    Called by the build_tree function to construct the kd-tree
    """

    num_samples = len(data)
    kdim = len(data[0][1])
    median_idx = num_samples // 2
    
    # sort data according to feature column indexed by discriminator
    data = sorted(data, key=lambda x: x[1][discriminator])

    # find first occurrence of median value for discriminator dimension
    median = data[median_idx][1][discriminator]

    while median_idx > 0 and median == data[median_idx-1][1][discriminator]:
      median_idx = median_idx-1

    # create root node for tree
    node = kdNode(data_idx=data[median_idx][0], discriminator=discriminator)

    # calculate discriminator index for next level
    next_discriminator = (discriminator + 1) % kdim

    # add left subtree containing vectors[discriminator] < median and right subtree containing vectors[discriminator] >= median to root
    if median_idx > 0:
      node.lchild = self.builder(data[:median_idx], next_discriminator)
    if num_samples - (median_idx + 1) > 0:
      node.rchild = self.builder(data[median_idx+1:], next_discriminator)

    return node

  def build_tree(self, data):
    """
    Called by the user to initialize the kd-tree using the provided dataset
    """
    self.data = copy.deepcopy(data)
    self.root = self.builder(data)

  def find_kNN(self, k, query_vec, node=None, kNN=None):
    """
    Find and return a list of the query_vec's k nearest neighbors in the tree's dataset
    
    NOTE: kNN is returned as a max heap of knnHeapNodes, so in order to get the 
    final list in increasing order of L2 dist, the final output must be reverse-sorted 
    using sorted(kNN, reverse=True)
    """
    
    if node == None:
      node = self.root
    
    # create max heap for tracking node values and associated L2 distances of k nearest neighbors
    if kNN == None:
      kNN = []
      heapq.heapify(kNN)

    # extract feature vector from tuple in reference data
    feat_vec = self.data[node.data_idx][1]

    # calculate L2 distance between query_vec and the current node
    dist = distance.euclidean(query_vec, feat_vec)

    if len(kNN) < k:
      heapq.heappush(kNN, knnHeapNode(node, dist))
    else:
      if dist < kNN[0].L2Dist:
        heapq.heapreplace(kNN, knnHeapNode(node, dist))

    # determine best direction to traverse tree
    discriminator = node.discriminator

    if query_vec[discriminator] < feat_vec[discriminator]:
      good_side = node.lchild
      bad_side = node.rchild
    else:
      good_side = node.rchild
      bad_side = node.lchild

    # traverse good side
    if good_side != None:
      kNN = self.find_kNN(k, query_vec, node=good_side, kNN=kNN)

    # determine if the bad side is worth exploring by checking the possibility of a shorter distance to the query on the bad side
    if bad_side != None and abs(query_vec[discriminator] - feat_vec[discriminator]) < kNN[0].L2Dist:
      kNN = self.find_kNN(k, query_vec, node=bad_side, kNN=kNN)

    # return max heap of k closest nodes
    return kNN

# %% [markdown]
# ## Locality hashing
#
# For our locality hashing we used for reference the following github repository (also cited in report):
# https://github.com/kayzhu/LSHash/blob/master/lshash/lshash.py

# %%
class LocalityHash:

  def __init__(self, hash_size, input_dim, num_tables = 1):
      
      """
        arg input_dim: the expected dimension of the data to be hashed
        arg hash_size: number of random hyperplanes that divide the space into hash buckets
        
        Info: What we are realy storing for hyperplanes is the norm of the planes, initialized randomly with standard normal distribution. 
        Points whose dot product with the norm have the same sign are on the same side of the plane.
      """
      self.hash_size = hash_size
      self.input_dim = input_dim
      self.num_tables = num_tables

      self.planes = [np.random.randn(self.hash_size, self.input_dim) for _ in range(self.num_tables)]
      self.hash_tables = [{} for _ in range(self.num_tables)]

      print("LSH initialized")
      print("Number of hash tables: {}".format(self.num_tables))
      print("Number of hyperplanes per table: {}".format(self.hash_size))
      print("Number of buckets per table: {}".format(2**(self.hash_size)))
  
  def get_hashkey(self, plane, input_point):

    """ 
      arg input point dimension = 1* input_dim

      Takes an input point and generates a hash key based on its location relative to the hyperplanes (In which bucket)
      Returns a binary string map of length self.hash_size (number of hyperplanes) where 1 = "above" hyperplane i and 0 = "below" hyperplane i
      looks like: "101010100"

    """
    location_projections = np.dot(plane, np.array(input_point))
        
    #if dot product of input point and hyper plane is positive, it's 'above' in n-d space, if negative or 0, below
    hash_key = "".join(['1' if i > 0 else '0' for i in location_projections])

    return hash_key


  def insert_point(self, input_point, original_index):

    """
      arg input_point dimension = 1* input_dim
      arg original_index = reference to the index of the full size image for retrieval
    """

    info = (tuple(input_point), original_index)  #save point as tuple to save memory
    
    for i, hash_table in enumerate(self.hash_tables):
      key = self.get_hashkey(self.planes[i], input_point)

      if key in hash_table:
          hash_table[key].append(info)
      else:
          hash_table[key] = [info]

  
  def initialize(self, input_data, verbose = False):
    if len(input_data[0][1]) != self.input_dim:
        print("Input points should have dimension: 1 x {}".format(self.input_dim))
        return

    print("Initializing LSH from data...")

    for data in input_data:
      index, point = data
      self.insert_point(point, index)

    if verbose:
      count_str = "\nInserted:\n"
      for i, hash_table in enumerate(self.hash_tables):
        for bucket, item in hash_table.items():
            count_str += "{} items into bucket {} in hash table {}".format(str(len(item)), bucket, str(i+1))
            count_str += "\n"
        count_str += "\n"

      print(count_str)


  def get_knns(self, query_point, k, remove_first = False):
      
      candidates = set()
      start = time.time()
      for i, table in enumerate(self.hash_tables):
          key = self.get_hashkey(self.planes[i], query_point)
          if key in table:
            candidates.update(table[key])
      end = time.time()

      if len(candidates) <= 1:  #if query returns nothing or just the query point itself, return
        if len(candidates) == 0 or (tuple(candidates[0][0]) == tuple(query_point.tolist())):
          print("No neighbors found")
          return
  
      start = time.time()
      candidates_aug = []
      #add euclidean
      for i, (point, index) in enumerate(candidates):
          dist = distance.euclidean(query_point, point)
          candidates_aug.append((point, index, dist))
      end = time.time()
      print("Time spent in calculating distances: ", end-start)

      #sort on euclidean
      candidates_aug.sort(key=lambda x: x[2])

      ##trim if duplicates/remove same value:
      if remove_first:
        smallest_dist = candidates_aug[0][2]
        i = 0
        while i < len(candidates_aug) and smallest_dist == 0:
          candidates_aug = candidates_aug[i+1:]
          smallest_dist = candidates_aug[0][2]

      if len(candidates_aug) <= k:
        return candidates_aug
      else:
        return candidates_aug[:k]

# %% [markdown]
# # 5. Populate Each Data Structure with CIFAR10 Data

# %%
# format data for input into kd tree
ids = np.arange(images_reduced.shape[0])
images_reduced_ids = list(zip(list(ids), list(images_reduced)))

# %%
#original data for lsh
images_flat = np.concatenate([batch1[b'data'], batch2[b'data'], batch3[b'data'], batch4[b'data'], batch5[b'data'], test_batch[b'data']])
images_rgb = np.zeros((len(images), 32, 32, 3))
for i in range(len(images_flat)):
  im = images_flat[i]
  im_r = im[0:1024].reshape(32, 32)
  im_g = im[1024:2048].reshape(32, 32)
  im_b = im[2048:].reshape(32, 32)
  im_rgb = np.dstack((im_r, im_g, im_b)) / 255.0
  images_rgb[i,:,:,:] = im_rgb
images_flat = images_rgb
flat_grays = np.zeros((len(images), 1024))
for i in range(len(images)):
    img = (images_flat[i]*255).astype('uint8')
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    flat_grays[i] = gray.flatten()
images_flat = flat_grays
images_tupled = []
for i, img in enumerate(images_flat):
  images_tupled.append((i, img))

# %%
cifar_kdtree = kdTree()
cifar_kdtree.build_tree(images_reduced_ids)

if 'lsh' in globals():
    del lsh
    
#INITIALIZE LSH
hash_size = 14
num_tables = 2
lsh = LocalityHash(hash_size = hash_size , input_dim = images_flat.shape[1], num_tables = num_tables)
lsh.initialize(images_tupled)
# Out:
# LSH initialized
# Number of hash tables: 2
# Number of hyperplanes per table: 14
# Number of buckets per table: 16384
# Initializing LSH from data...

# %% [markdown]
# # 6. Test Search Query Performance

# %% [markdown]
# ## Helper Functions

# %%
def get_ground_truth_nns(query, num_kNN, data):
  """
  Brute force computation of the query's nearest neighbors in data matrix using L2 norm.
  
  Assumes data is a list of tuples of the form [(image_index, [features])].

  Returns list of tuples of the form [(image_index, L2Dist)], with tuples
  ordered from smallest L2 distance to largest L2 distance
  """
  # compute ground truth nn for query image
  true_nns = []
  for i, row in enumerate(data):
    dist = distance.euclidean(query, row)

    if len(true_nns) < num_kNN:
      true_nns.append((i, dist))
    else:
      biggest_dist = max(true_nns, key=lambda x:x[1])
      if dist < biggest_dist[1]:
        max_index = true_nns.index(biggest_dist)
        true_nns[max_index] = (i,dist)

  true_nns.sort(key=lambda x: x[1])
  return true_nns

# %% [markdown]
# ## kd-Tree:

# %%
import time
from operator import eq

sum = 0
sum2 = sum
del sum

#num_neighbors = int(input("How many nearest neighbors for your image query?: "))
num_neighbors = 100

# chose random query image
rand_index = random.randint(0, len(images_flat))
query_image = images_flat[rand_index,:]
reduced_query = images_reduced[rand_index,:]

print("Query image: ")
#cifar10_plot_single(images, rand_index)
#del images

start = time.time()
true_nns = get_ground_truth_nns(query_image, num_neighbors, images_flat)
end = time.time()

print("naive benchmark: {}".format(end - start))

exemplars = []
exemplars_neighbor_list = []
for x in true_nns:
  exemplars.append(int(x[0]))
  exemplars_neighbor_list.append(str(x[0]))

print(exemplars)

'''for neighbor in exemplars:
  print(distance.euclidean(query_image, images_og[neighbor]))'''

start = time.time()
# find kNN for query image using kdTree
knn_kd = cifar_kdtree.find_kNN(k=num_neighbors, query_vec=reduced_query)
knn_kd = sorted(knn_kd, reverse=True)
end = time.time()

# reduced neighbor distances
kd_neighbor_list = []
# true non-reduced distancesretrieving candidates:  0.34514570236206055

for neighbor in knn_kd:
  kd_neighbor_list.append(int(str(neighbor.node).replace("Node with Index ", "")))

print(kd_neighbor_list)
print("kd benchmark: {}".format(end - start))

commons = 0 
for i in range(len(kd_neighbor_list)):
  for j in range(len(exemplars)):
    if kd_neighbor_list[i] == exemplars[j]:
      commons += 1

print("kd accuracy percentage {}%".format(100*commons/num_neighbors))
# Out:
# Query image:
# naive benchmark: 0.8416318893432617
# [2191, 48976, 39143, 11765, 57590, 35821, 1314, 26199, 12858, 57671, 35063, 39836, 26884, 34576, 42345, 30735, 23367, 48841, 8405, 41894, 17967, 44293, 15259, 48009, 39913, 20112, 21229, 8100, 19438, 7625, 1971, 33434, 39496, 34384, 45517, 54101, 6826, 25636, 54610, 36785, 15542, 50655, 44468, 986, 4884, 2115, 2465, 41480, 21366, 10719, 45973, 6205, 10463, 34577, 51728, 17898, 10400, 57256, 56089, 36355, 23159, 7365, 17372, 15864, 32922, 14023, 57171, 22828, 41788, 15050, 11506, 15168, 16746, 42965, 16705, 42255, 9386, 51587, 9255, 21664, 17751, 46509, 4361, 12316, 15191, 5581, 53870, 6996, 24670, 18664, 53593, 36137, 59567, 20778, 52834, 19332, 16056, 37475, 27659, 56682]
# [2191, 48976, 35821, 39143, 57590, 1314, 11765, 12858, 57671, 26199, 39836, 35063, 34576, 26884, 48841, 8405, 25636, 7625, 20112, 21229, 42345, 10463, 10400, 17967, 23367, 44293, 30735, 39913, 54610, 41894, 4884, 15259, 41480, 1971, 8100, 39496, 21366, 33434, 38318, 54101, 17372, 34384, 48009, 45517, 44468, 986, 55049, 44221, 55322, 12219, 2115, 50655, 19438, 36785, 34577, 11506, 51728, 9255, 27872, 51415, 37475, 46509, 22828, 32922, 25185, 54958, 6996, 4361, 15542, 6826, 29541, 10348, 16705, 42965, 15050, 45973, 53593, 17898, 1760, 10719, 23159, 57256, 6205, 42255, 16746, 56089, 2465, 56902, 36355, 15864, 14023, 15168, 5581, 41788, 21292, 56682, 46818, 1580, 21492, 27659]
# kd benchmark: 0.4364922046661377
# kd accuracy percentage 83.0%

# %% [markdown]
# ## Locality Sensitive Hashing

# %%
import time
from operator import eq

sum = 0
sum2 = sum
del sum

start = time.time()
knn_lsh = lsh.get_knns(query_image, num_neighbors)
end = time.time()

lsh_neighbor_list = []
# true non-reduced distances
for neighbor in knn_lsh:
  #print(distance.euclidean(query_image, images_flat[int(neighbor[1])]))
  lsh_neighbor_list.append(int(neighbor[1]))

# neighbor distances
print(exemplars)
print(lsh_neighbor_list)

### DO STUFF
print("lsh benchmark: {}".format(end - start))
commons = 0 
for i in range(len(lsh_neighbor_list)):
  for j in range(len(exemplars)):
    if lsh_neighbor_list[i] == exemplars[j]:
      commons += 1
print("lsh accuracy percentage {}%".format(100*commons/num_neighbors))
# Out:
# Time spent in calculating distances:  0.11716580390930176
# [2191, 48976, 39143, 11765, 57590, 35821, 1314, 26199, 12858, 57671, 35063, 39836, 26884, 34576, 42345, 30735, 23367, 48841, 8405, 41894, 17967, 44293, 15259, 48009, 39913, 20112, 21229, 8100, 19438, 7625, 1971, 33434, 39496, 34384, 45517, 54101, 6826, 25636, 54610, 36785, 15542, 50655, 44468, 986, 4884, 2115, 2465, 41480, 21366, 10719, 45973, 6205, 10463, 34577, 51728, 17898, 10400, 57256, 56089, 36355, 23159, 7365, 17372, 15864, 32922, 14023, 57171, 22828, 41788, 15050, 11506, 15168, 16746, 42965, 16705, 42255, 9386, 51587, 9255, 21664, 17751, 46509, 4361, 12316, 15191, 5581, 53870, 6996, 24670, 18664, 53593, 36137, 59567, 20778, 52834, 19332, 16056, 37475, 27659, 56682]
# [2191, 23367, 39913, 21229, 2115, 10719, 45973, 22828, 19332, 55049, 59827, 26215, 36243, 21259, 52602, 53696, 27476, 16004, 7733, 12219, 15128, 49923, 38074, 47292, 29821, 5180, 43182, 32290, 30467, 46095, 5226, 54299, 42372, 28338, 50587, 16110, 51919, 52383, 34613, 11335, 13392, 26212, 5634, 5535, 55883, 42180, 29896, 28377, 12115, 14174, 8651, 53046, 42813, 57356, 52938, 31492, 42219, 5857, 44894, 32598, 46907, 56768, 34676, 29111, 23209, 57305, 58187, 8820, 35168, 14203, 29816, 14013, 11654, 20810, 42552, 22546, 40054, 49049, 41265, 25272, 738, 19439, 29083, 32583, 21766, 10689, 28794, 658, 9900, 9980, 36652, 40441, 41656, 53624, 32639, 29016, 52883, 18632, 12109, 16547]
# lsh benchmark: 0.1741161346435547
# lsh accuracy percentage 9.0%

# %% [markdown]
# # 7. Plotting and Batch Testing

# %%
import time
from operator import eq

def plot(data_points, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_axes([0.12,0.1,0.8,0.8])
    algos = ['Naive', 'KD-Tree', 'LSH']
    print(algos)
    print(data_points)
    ax.bar(algos, data_points, color=['red', 'green', 'blue'])
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    plt.show()
  
naive_times = []
kd_times = []
lsh_times = []

naive_acc = []
kd_acc = []
lsh_acc = []

trial_count = 0

for i in range(100):
  trial_count += 1
  print(trial_count)
  sum = 0
  sum2 = sum
  del sum

  num_neighbors = 100

  # chose random query image
  rand_index = random.randint(0, len(images_flat))
  query_image = images_flat[rand_index,:]
  reduced_query = images_reduced[rand_index,:]

  start = time.time()
  true_nns = get_ground_truth_nns(query_image, num_neighbors, images_flat)
  end = time.time()
  naive_benchmark = end - start
  naive_times.append(naive_benchmark)
  print("naive benchmark: {}".format(end - start))

  exemplars = []
  exemplars_neighbor_list = []
  for x in true_nns:
    exemplars.append(int(x[0]))
    exemplars_neighbor_list.append(str(x[0]))
  naive_acc.append(100)

  start = time.time()
  # find kNN for query image using kdTree
  knn_kd = cifar_kdtree.find_kNN(k=num_neighbors, query_vec=reduced_query)
  end = time.time()
  knn_kd = sorted(knn_kd, reverse=True)

  # reduced neighbor distances
  kd_neighbor_list = []
  # true non-reduced distancesretrieving candidates:  0.34514570236206055

  for neighbor in knn_kd:
    kd_neighbor_list.append(int(str(neighbor.node).replace("Node with Index ", "")))
  kd_benchmark =  end - start
  print("kd benchmark: {}".format(end - start))
  kd_times.append(kd_benchmark) 

  commons = 0 
  for i in range(len(kd_neighbor_list)):
    for j in range(len(exemplars)):
      if kd_neighbor_list[i] == exemplars[j]:
        commons += 1
  kd_percentage = 100*commons/num_neighbors
  kd_acc.append(kd_percentage)
  print("kd accuracy percentage {}%".format(100*commons/num_neighbors))

  start = time.time()
  knn_lsh = lsh.get_knns(query_image, num_neighbors)
  end = time.time()

  lsh_neighbor_list = []
  # true non-reduced distances
  for neighbor in knn_lsh:
    lsh_neighbor_list.append(int(neighbor[1]))
  lsh_benchmark = end - start
  lsh_times.append(lsh_benchmark)
  print("lsh benchmark: {}".format(end - start))
  
  commons = 0 
  for i in range(len(lsh_neighbor_list)):
    for j in range(len(exemplars)):
      if lsh_neighbor_list[i] == exemplars[j]:
        commons += 1
  lsh_percentage = 100*commons/num_neighbors
  lsh_acc.append(lsh_percentage)
  print("lsh accuracy percentage {}%".format(100*commons/num_neighbors))

average_timings = [sum(naive_times)/len(naive_times), sum(kd_times)/len(kd_times), sum(lsh_times)/len(lsh_times)]
average_accs = [sum(naive_acc)/len(naive_acc), sum(kd_acc)/len(kd_acc), sum(lsh_acc)/len(lsh_acc)]

plot(average_timings, "Timing comparison", "algorithm/structure", "average-time(ms)")
plot(average_accs, "Accuracy comparison", "algorithm/structure", "average accuracy")
# Out:
# 1
# naive benchmark: 0.8458378314971924
# kd benchmark: 0.19875717163085938
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.37103915214538574
# lsh benchmark: 0.5354070663452148
# lsh accuracy percentage 53.0%
# 2
# naive benchmark: 0.8488991260528564
# kd benchmark: 0.40581583976745605
# kd accuracy percentage 76.0%
# Time spent in calculating distances:  0.34654688835144043
# lsh benchmark: 0.4933791160583496
# lsh accuracy percentage 40.0%
# 3
# naive benchmark: 0.8565371036529541
# kd benchmark: 0.4043691158294678
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.11810994148254395
# lsh benchmark: 0.1512279510498047
# lsh accuracy percentage 3.0%
# 4
# naive benchmark: 0.8429861068725586
# kd benchmark: 0.40046215057373047
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.22969698905944824
# lsh benchmark: 0.30937814712524414
# lsh accuracy percentage 21.0%
# 5
# naive benchmark: 0.8538172245025635
# kd benchmark: 0.39362001419067383
# kd accuracy percentage 78.0%
# Time spent in calculating distances:  0.4214060306549072
# lsh benchmark: 0.6415390968322754
# lsh accuracy percentage 19.0%
# 6
# naive benchmark: 0.8978676795959473
# kd benchmark: 0.1946702003479004
# kd accuracy percentage 88.0%
# Time spent in calculating distances:  0.3651540279388428
# lsh benchmark: 0.4600250720977783
# lsh accuracy percentage 47.0%
# 7
# naive benchmark: 0.8443379402160645
# kd benchmark: 0.1999979019165039
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.15652012825012207
# lsh benchmark: 0.2235550880432129
# lsh accuracy percentage 16.0%
# 8
# naive benchmark: 0.8435318470001221
# kd benchmark: 0.38949084281921387
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.10027694702148438
# lsh benchmark: 0.13742899894714355
# lsh accuracy percentage 17.0%
# 9
# naive benchmark: 0.850294828414917
# kd benchmark: 0.39524316787719727
# kd accuracy percentage 87.0%
# Time spent in calculating distances:  0.37743282318115234
# lsh benchmark: 0.4771239757537842
# lsh accuracy percentage 27.0%
# 10
# naive benchmark: 0.8616650104522705
# kd benchmark: 0.40946507453918457
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.0255889892578125
# lsh benchmark: 0.035752058029174805
# lsh accuracy percentage 1.0%
# 11
# naive benchmark: 0.8411588668823242
# kd benchmark: 0.4014718532562256
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.02145099639892578
# lsh benchmark: 0.029252052307128906
# lsh accuracy percentage 2.0%
# 12
# naive benchmark: 0.8485450744628906
# kd benchmark: 0.20406198501586914
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.5375659465789795
# lsh benchmark: 0.7015516757965088
# lsh accuracy percentage 79.0%
# 13
# naive benchmark: 0.8471839427947998
# kd benchmark: 0.20625090599060059
# kd accuracy percentage 88.0%
# Time spent in calculating distances:  0.46275877952575684
# lsh benchmark: 0.5960178375244141
# lsh accuracy percentage 70.0%
# 14
# naive benchmark: 0.8416440486907959
# kd benchmark: 0.39633989334106445
# kd accuracy percentage 83.0%
# Time spent in calculating distances:  0.5429282188415527
# lsh benchmark: 0.6819977760314941
# lsh accuracy percentage 77.0%
# 15
# naive benchmark: 0.842519998550415
# kd benchmark: 0.3938448429107666
# kd accuracy percentage 68.0%
# Time spent in calculating distances:  0.11756300926208496
# lsh benchmark: 0.14716100692749023
# lsh accuracy percentage 8.0%
# 16
# naive benchmark: 0.8346939086914062
# kd benchmark: 0.19476699829101562
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.0015232563018798828
# lsh benchmark: 0.002335071563720703
# lsh accuracy percentage 2.0%
# 17
# naive benchmark: 0.8441689014434814
# kd benchmark: 0.4000890254974365
# kd accuracy percentage 76.0%
# Time spent in calculating distances:  0.5299527645111084
# lsh benchmark: 0.6766612529754639
# lsh accuracy percentage 41.0%
# 18
# naive benchmark: 0.8429841995239258
# kd benchmark: 0.3919191360473633
# kd accuracy percentage 90.0%
# Time spent in calculating distances:  0.42038512229919434
# lsh benchmark: 0.5380489826202393
# lsh accuracy percentage 76.0%
# 19
# naive benchmark: 0.8425889015197754
# kd benchmark: 0.19678926467895508
# kd accuracy percentage 89.0%
# Time spent in calculating distances:  0.4307122230529785
# lsh benchmark: 0.5419988632202148
# lsh accuracy percentage 82.0%
# 20
# naive benchmark: 0.837939977645874
# kd benchmark: 0.39229297637939453
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.4269721508026123
# lsh benchmark: 0.5373058319091797
# lsh accuracy percentage 55.0%
# 21
# naive benchmark: 0.8447737693786621
# kd benchmark: 0.39655613899230957
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.10768985748291016
# lsh benchmark: 0.14280295372009277
# lsh accuracy percentage 6.0%
# 22
# naive benchmark: 0.8409252166748047
# kd benchmark: 0.19654607772827148
# kd accuracy percentage 93.0%
# Time spent in calculating distances:  0.027261018753051758
# lsh benchmark: 0.036827802658081055
# lsh accuracy percentage 3.0%
# 23
# naive benchmark: 0.8425867557525635
# kd benchmark: 0.3919060230255127
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.27074694633483887
# lsh benchmark: 0.3379521369934082
# lsh accuracy percentage 49.0%
# 24
# naive benchmark: 0.8398211002349854
# kd benchmark: 0.3934798240661621
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.04972481727600098
# lsh benchmark: 0.06685423851013184
# lsh accuracy percentage 6.0%
# 25
# naive benchmark: 0.8423569202423096
# kd benchmark: 0.3945491313934326
# kd accuracy percentage 76.0%
# Time spent in calculating distances:  0.04766702651977539
# lsh benchmark: 0.06389117240905762
# lsh accuracy percentage 5.0%
# 26
# naive benchmark: 0.8376860618591309
# kd benchmark: 0.39284610748291016
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.39412784576416016
# lsh benchmark: 0.4917900562286377
# lsh accuracy percentage 54.0%
# 27
# naive benchmark: 0.8399560451507568
# kd benchmark: 0.39209508895874023
# kd accuracy percentage 88.0%
# Time spent in calculating distances:  0.003353118896484375
# lsh benchmark: 0.00462794303894043
# lsh accuracy percentage 3.0%
# 28
# naive benchmark: 0.8411159515380859
# kd benchmark: 0.19854998588562012
# kd accuracy percentage 83.0%
# Time spent in calculating distances:  0.41546201705932617
# lsh benchmark: 0.5232100486755371
# lsh accuracy percentage 71.0%
# 29
# naive benchmark: 0.838414192199707
# kd benchmark: 0.39461398124694824
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.1995530128479004
# lsh benchmark: 0.25153684616088867
# lsh accuracy percentage 35.0%
# 30
# naive benchmark: 0.8360638618469238
# kd benchmark: 0.3973379135131836
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.037281036376953125
# lsh benchmark: 0.05011606216430664
# lsh accuracy percentage 9.0%
# 31
# naive benchmark: 0.837634801864624
# kd benchmark: 0.393718957901001
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.5354678630828857
# lsh benchmark: 0.6833810806274414
# lsh accuracy percentage 72.0%
# 32
# naive benchmark: 0.8424749374389648
# kd benchmark: 0.19643306732177734
# kd accuracy percentage 83.0%
# Time spent in calculating distances:  0.5295500755310059
# lsh benchmark: 0.6779909133911133
# lsh accuracy percentage 90.0%
# 33
# naive benchmark: 0.8396859169006348
# kd benchmark: 0.39240598678588867
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.3412742614746094
# lsh benchmark: 0.42511606216430664
# lsh accuracy percentage 33.0%
# 34
# naive benchmark: 0.8360488414764404
# kd benchmark: 0.19686603546142578
# kd accuracy percentage 79.0%
# Time spent in calculating distances:  0.0606381893157959
# lsh benchmark: 0.07558202743530273
# lsh accuracy percentage 4.0%
# 35
# naive benchmark: 0.8403618335723877
# kd benchmark: 0.39343690872192383
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.42523884773254395
# lsh benchmark: 0.5316038131713867
# lsh accuracy percentage 58.0%
# 36
# naive benchmark: 0.8405671119689941
# kd benchmark: 0.39514708518981934
# kd accuracy percentage 79.0%
# Time spent in calculating distances:  0.5020081996917725
# lsh benchmark: 0.6248159408569336
# lsh accuracy percentage 33.0%
# 37
# naive benchmark: 0.8404839038848877
# kd benchmark: 0.3912367820739746
# kd accuracy percentage 88.0%
# Time spent in calculating distances:  0.42560672760009766
# lsh benchmark: 0.5329210758209229
# lsh accuracy percentage 48.0%
# 38
# naive benchmark: 0.8378911018371582
# kd benchmark: 0.39217519760131836
# kd accuracy percentage 78.0%
# Time spent in calculating distances:  0.05289411544799805
# lsh benchmark: 0.07055997848510742
# lsh accuracy percentage 4.0%
# 39
# naive benchmark: 0.8406178951263428
# kd benchmark: 0.39248108863830566
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.008787155151367188
# lsh benchmark: 0.012074947357177734
# lsh accuracy percentage 13.0%
# 40
# naive benchmark: 0.8420519828796387
# kd benchmark: 0.39205312728881836
# kd accuracy percentage 90.0%
# Time spent in calculating distances:  0.10895085334777832
# lsh benchmark: 0.14472293853759766
# lsh accuracy percentage 10.0%
# 41
# naive benchmark: 0.8388121128082275
# kd benchmark: 0.3924269676208496
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.13802695274353027
# lsh benchmark: 0.17318511009216309
# lsh accuracy percentage 18.0%
# 42
# naive benchmark: 0.8437786102294922
# kd benchmark: 0.39657092094421387
# kd accuracy percentage 73.0%
# Time spent in calculating distances:  0.4858071804046631
# lsh benchmark: 0.6103200912475586
# lsh accuracy percentage 61.0%
# 43
# naive benchmark: 0.8410589694976807
# kd benchmark: 0.196699857711792
# kd accuracy percentage 87.0%
# Time spent in calculating distances:  0.0332798957824707
# lsh benchmark: 0.043830156326293945
# lsh accuracy percentage 6.0%
# 44
# naive benchmark: 0.8372642993927002
# kd benchmark: 0.39252305030822754
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.3842649459838867
# lsh benchmark: 0.4804391860961914
# lsh accuracy percentage 60.0%
# 45
# naive benchmark: 0.8413169384002686
# kd benchmark: 0.19694995880126953
# kd accuracy percentage 89.0%
# Time spent in calculating distances:  0.32526516914367676
# lsh benchmark: 0.4085228443145752
# lsh accuracy percentage 38.0%
# 46
# naive benchmark: 0.8449859619140625
# kd benchmark: 0.3933720588684082
# kd accuracy percentage 75.0%
# Time spent in calculating distances:  0.2624630928039551
# lsh benchmark: 0.32594871520996094
# lsh accuracy percentage 45.0%
# 47
# naive benchmark: 0.8394858837127686
# kd benchmark: 0.1968841552734375
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.03450489044189453
# lsh benchmark: 0.0429539680480957
# lsh accuracy percentage 2.0%
# 48
# naive benchmark: 0.8414967060089111
# kd benchmark: 0.3949620723724365
# kd accuracy percentage 87.0%
# Time spent in calculating distances:  0.12516117095947266
# lsh benchmark: 0.15706896781921387
# lsh accuracy percentage 41.0%
# 49
# naive benchmark: 0.8407728672027588
# kd benchmark: 0.19733977317810059
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.5015609264373779
# lsh benchmark: 0.6260600090026855
# lsh accuracy percentage 73.0%
# 50
# naive benchmark: 0.8414959907531738
# kd benchmark: 0.3920938968658447
# kd accuracy percentage 75.0%
# Time spent in calculating distances:  0.3984701633453369
# lsh benchmark: 0.5047831535339355
# lsh accuracy percentage 40.0%
# 51
# naive benchmark: 0.8385758399963379
# kd benchmark: 0.3949899673461914
# kd accuracy percentage 69.0%
# Time spent in calculating distances:  0.1613481044769287
# lsh benchmark: 0.2032909393310547
# lsh accuracy percentage 8.0%
# 52
# naive benchmark: 0.8399760723114014
# kd benchmark: 0.3950369358062744
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.029330968856811523
# lsh benchmark: 0.03717994689941406
# lsh accuracy percentage 15.0%
# 53
# naive benchmark: 0.839885950088501
# kd benchmark: 0.19649100303649902
# kd accuracy percentage 91.0%
# Time spent in calculating distances:  0.010762929916381836
# lsh benchmark: 0.014192342758178711
# lsh accuracy percentage 5.0%
# 54
# naive benchmark: 0.8424451351165771
# kd benchmark: 0.19778203964233398
# kd accuracy percentage 88.0%
# Time spent in calculating distances:  0.5122339725494385
# lsh benchmark: 0.6507000923156738
# lsh accuracy percentage 79.0%
# 55
# naive benchmark: 0.8440151214599609
# kd benchmark: 0.39199280738830566
# kd accuracy percentage 76.0%
# Time spent in calculating distances:  0.0911262035369873
# lsh benchmark: 0.11480307579040527
# lsh accuracy percentage 7.0%
# 56
# naive benchmark: 0.8405740261077881
# kd benchmark: 0.39243006706237793
# kd accuracy percentage 88.0%
# Time spent in calculating distances:  0.10148882865905762
# lsh benchmark: 0.12749600410461426
# lsh accuracy percentage 16.0%
# 57
# naive benchmark: 0.8414230346679688
# kd benchmark: 0.196821928024292
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.33978700637817383
# lsh benchmark: 0.42600107192993164
# lsh accuracy percentage 73.0%
# 58
# naive benchmark: 0.8380019664764404
# kd benchmark: 0.19636988639831543
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.03566694259643555
# lsh benchmark: 0.04498696327209473
# lsh accuracy percentage 3.0%
# 59
# naive benchmark: 0.8412270545959473
# kd benchmark: 0.1964559555053711
# kd accuracy percentage 91.0%
# Time spent in calculating distances:  0.04451799392700195
# lsh benchmark: 0.05595278739929199
# lsh accuracy percentage 21.0%
# 60
# naive benchmark: 0.8436651229858398
# kd benchmark: 0.3944387435913086
# kd accuracy percentage 79.0%
# Time spent in calculating distances:  0.21691584587097168
# lsh benchmark: 0.27144789695739746
# lsh accuracy percentage 20.0%
# 61
# naive benchmark: 0.8466477394104004
# kd benchmark: 0.3929879665374756
# kd accuracy percentage 90.0%
# Time spent in calculating distances:  0.002187013626098633
# lsh benchmark: 0.0032911300659179688
# lsh accuracy percentage 1.0%
# 62
# naive benchmark: 0.8412559032440186
# kd benchmark: 0.3999512195587158
# kd accuracy percentage 83.0%
# Time spent in calculating distances:  0.13385987281799316
# lsh benchmark: 0.1707320213317871
# lsh accuracy percentage 29.0%
# 63
# naive benchmark: 0.8387460708618164
# kd benchmark: 0.19804692268371582
# kd accuracy percentage 76.0%
# Time spent in calculating distances:  0.06977009773254395
# lsh benchmark: 0.09006023406982422
# lsh accuracy percentage 2.0%
# 64
# naive benchmark: 0.8503158092498779
# kd benchmark: 0.39362502098083496
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.12978529930114746
# lsh benchmark: 0.16408133506774902
# lsh accuracy percentage 34.0%
# 65
# naive benchmark: 0.8393659591674805
# kd benchmark: 0.3955099582672119
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.08781790733337402
# lsh benchmark: 0.11039996147155762
# lsh accuracy percentage 1.0%
# 66
# naive benchmark: 0.8389050960540771
# kd benchmark: 0.3944261074066162
# kd accuracy percentage 83.0%
# Time spent in calculating distances:  0.056680917739868164
# lsh benchmark: 0.07203316688537598
# lsh accuracy percentage 2.0%
# 67
# naive benchmark: 0.8396520614624023
# kd benchmark: 0.19676995277404785
# kd accuracy percentage 91.0%
# Time spent in calculating distances:  0.11144614219665527
# lsh benchmark: 0.13878130912780762
# lsh accuracy percentage 19.0%
# 68
# naive benchmark: 0.8496229648590088
# kd benchmark: 0.19678902626037598
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.40224695205688477
# lsh benchmark: 0.5052869319915771
# lsh accuracy percentage 62.0%
# 69
# naive benchmark: 0.8405888080596924
# kd benchmark: 0.3929939270019531
# kd accuracy percentage 79.0%
# Time spent in calculating distances:  0.13879179954528809
# lsh benchmark: 0.17370271682739258
# lsh accuracy percentage 12.0%
# 70
# naive benchmark: 0.8390369415283203
# kd benchmark: 0.3929319381713867
# kd accuracy percentage 73.0%
# Time spent in calculating distances:  0.032212018966674805
# lsh benchmark: 0.040796756744384766
# lsh accuracy percentage 2.0%
# 71
# naive benchmark: 0.8368399143218994
# kd benchmark: 0.3951900005340576
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.5389578342437744
# lsh benchmark: 0.6892828941345215
# lsh accuracy percentage 91.0%
# 72
# naive benchmark: 0.8460719585418701
# kd benchmark: 0.1976318359375
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.2852909564971924
# lsh benchmark: 0.357637882232666
# lsh accuracy percentage 32.0%
# 73
# naive benchmark: 0.8381028175354004
# kd benchmark: 0.3928651809692383
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.018011093139648438
# lsh benchmark: 0.02294611930847168
# lsh accuracy percentage 4.0%
# 74
# naive benchmark: 0.8450911045074463
# kd benchmark: 0.09896612167358398
# kd accuracy percentage 90.0%
# Time spent in calculating distances:  0.08974814414978027
# lsh benchmark: 0.11283302307128906
# lsh accuracy percentage 5.0%
# 75
# naive benchmark: 0.8443901538848877
# kd benchmark: 0.40232014656066895
# kd accuracy percentage 78.0%
# Time spent in calculating distances:  0.38712406158447266
# lsh benchmark: 0.48534512519836426
# lsh accuracy percentage 31.0%
# 76
# naive benchmark: 0.8428082466125488
# kd benchmark: 0.3930060863494873
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.40657997131347656
# lsh benchmark: 0.5124142169952393
# lsh accuracy percentage 55.0%
# 77
# naive benchmark: 0.8439700603485107
# kd benchmark: 0.39420509338378906
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.4622011184692383
# lsh benchmark: 0.578383207321167
# lsh accuracy percentage 65.0%
# 78
# naive benchmark: 0.8491790294647217
# kd benchmark: 0.39486193656921387
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.06492781639099121
# lsh benchmark: 0.08167076110839844
# lsh accuracy percentage 4.0%
# 79
# naive benchmark: 0.8444881439208984
# kd benchmark: 0.3933730125427246
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.09431314468383789
# lsh benchmark: 0.11834192276000977
# lsh accuracy percentage 19.0%
# 80
# naive benchmark: 0.8373291492462158
# kd benchmark: 0.1974961757659912
# kd accuracy percentage 88.0%
# Time spent in calculating distances:  0.3940598964691162
# lsh benchmark: 0.49245405197143555
# lsh accuracy percentage 82.0%
# 81
# naive benchmark: 0.8425590991973877
# kd benchmark: 0.19629311561584473
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.46358299255371094
# lsh benchmark: 0.579338788986206
# lsh accuracy percentage 41.0%
# 82
# naive benchmark: 0.8473138809204102
# kd benchmark: 0.19620299339294434
# kd accuracy percentage 91.0%
# Time spent in calculating distances:  0.04572272300720215
# lsh benchmark: 0.05915713310241699
# lsh accuracy percentage 12.0%
# 83
# naive benchmark: 0.8407909870147705
# kd benchmark: 0.3939499855041504
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.4968290328979492
# lsh benchmark: 0.6217942237854004
# lsh accuracy percentage 63.0%
# 84
# naive benchmark: 0.8398778438568115
# kd benchmark: 0.19711685180664062
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.12419676780700684
# lsh benchmark: 0.15530705451965332
# lsh accuracy percentage 18.0%
# 85
# naive benchmark: 0.8398020267486572
# kd benchmark: 0.40184497833251953
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.45313096046447754
# lsh benchmark: 0.5647439956665039
# lsh accuracy percentage 59.0%
# 86
# naive benchmark: 0.866095781326294
# kd benchmark: 0.2030332088470459
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.008668899536132812
# lsh benchmark: 0.011098146438598633
# lsh accuracy percentage 1.0%
# 87
# naive benchmark: 0.8377561569213867
# kd benchmark: 0.39473724365234375
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.044341087341308594
# lsh benchmark: 0.056962013244628906
# lsh accuracy percentage 20.0%
# 88
# naive benchmark: 0.8402738571166992
# kd benchmark: 0.4120638370513916
# kd accuracy percentage 76.0%
# Time spent in calculating distances:  0.03741312026977539
# lsh benchmark: 0.0475311279296875
# lsh accuracy percentage 6.0%
# 89
# naive benchmark: 0.8403210639953613
# kd benchmark: 0.1993846893310547
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.40524911880493164
# lsh benchmark: 0.5085113048553467
# lsh accuracy percentage 79.0%
# 90
# naive benchmark: 0.8395340442657471
# kd benchmark: 0.39409303665161133
# kd accuracy percentage 72.0%
# Time spent in calculating distances:  0.06962704658508301
# lsh benchmark: 0.08738112449645996
# lsh accuracy percentage 2.0%
# 91
# naive benchmark: 0.8408730030059814
# kd benchmark: 0.3930962085723877
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.3652677536010742
# lsh benchmark: 0.4579808712005615
# lsh accuracy percentage 46.0%
# 92
# naive benchmark: 0.8380739688873291
# kd benchmark: 0.40216612815856934
# kd accuracy percentage 78.0%
# Time spent in calculating distances:  0.09980607032775879
# lsh benchmark: 0.12453508377075195
# lsh accuracy percentage 16.0%
# 93
# naive benchmark: 0.848196268081665
# kd benchmark: 0.4087989330291748
# kd accuracy percentage 87.0%
# Time spent in calculating distances:  0.49673986434936523
# lsh benchmark: 0.6224110126495361
# lsh accuracy percentage 78.0%
# 94
# naive benchmark: 0.8386199474334717
# kd benchmark: 0.39243292808532715
# kd accuracy percentage 71.0%
# Time spent in calculating distances:  0.440673828125
# lsh benchmark: 0.55584716796875
# lsh accuracy percentage 48.0%
# 95
# naive benchmark: 0.848351001739502
# kd benchmark: 0.39293599128723145
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.06732487678527832
# lsh benchmark: 0.0879509449005127
# lsh accuracy percentage 5.0%
# 96
# naive benchmark: 0.840703010559082
# kd benchmark: 0.39221763610839844
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.02406001091003418
# lsh benchmark: 0.03142499923706055
# lsh accuracy percentage 4.0%
# 97
# naive benchmark: 0.8404080867767334
# kd benchmark: 0.39540624618530273
# kd accuracy percentage 78.0%
# Time spent in calculating distances:  0.018266916275024414
# lsh benchmark: 0.02382802963256836
# lsh accuracy percentage 1.0%
# 98
# naive benchmark: 0.8376591205596924
# kd benchmark: 0.39530324935913086
# kd accuracy percentage 83.0%
# Time spent in calculating distances:  0.4880959987640381
# lsh benchmark: 0.6136910915374756
# lsh accuracy percentage 53.0%
# 99
# naive benchmark: 0.8432950973510742
# kd benchmark: 0.39709019660949707
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.1707620620727539
# lsh benchmark: 0.21354079246520996
# lsh accuracy percentage 14.0%
# 100
# naive benchmark: 0.8414950370788574
# kd benchmark: 0.39368200302124023
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.07751822471618652
# lsh benchmark: 0.10048103332519531
# lsh accuracy percentage 6.0%
# ['Naive', 'KD-Tree', 'LSH']
# [0.8429538559913635, 0.33322582006454465, 0.294286789894104]
# ['Naive', 'KD-Tree', 'LSH']
# [100.0, 82.24, 30.97]

# %% [markdown]
# # 9. Visual Examples of Results

# %%
def plot_knn_examples(neighbor_list, images):
  
  for i in range(9):
    index = neighbor_list[i]
    img = images[index]
    
    # define subplot
    plt.subplot(330 + 1 + i)
    # plot 
    plt.imshow(img)
    if i == 0:
      plt.title("Original image")
    else:
      plt.title('{}.'.format(i))
    
  plt.tight_layout()

# %%
print()
print("True nearest neighbors")
print()
plot_knn_examples(exemplars, images)
# Out:
# True nearest neighbors

# %%
print()
print("Nearest neighbors returned by kd tree")
print()
plot_knn_examples(kd_neighbor_list, images)
# Out:
# Nearest neighbors returned by kd tree

# %%
print()
print("Nearest neighbors neturned by lsh")
print()
plot_knn_examples(lsh_neighbor_list, images)
# Out:
# Nearest neighbors neturned by lsh
