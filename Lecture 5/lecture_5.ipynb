# %% [markdown]
# # Lecture 5: Locality-Sensitive Hashing
#
# ## Overview
#
# One of the standard problems in information retrieval is the nearest-neighbor problem: given an object and a database, quickly retrieve the k-most similar objects to the query from the database. A naive implementation would require one to linearly scan through the entire database, which is typically too costly for online applications. Two common approaches that have been suggested for this problem are locality-sensitive hashing and k-d-trees. Both may be viewed as data structures / algorithms for finding an approximate nearest neighbor to a query.
#
# 1. Import Dataset
# 2. Vizualise CIFAR
# 3. Dimensionality Reduction on Image Feature Vectors
# 4. Data Structure Class Definitions
# 5. Populate Each Data Structure with CIFAR10 Data
# 6. Test Search Query Performance
# 7. Plotting and Batch Testing
# 8. Visual Examples

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import heapq
from scipy import spatial
from scipy.spatial import distance
from tqdm.notebook import tqdm, trange
import copy
import random
import cv2

# %% [markdown]
# # 1. Import CIFAR10 Dataset

# %% [markdown]
# Note: Each row of the "images" array produced below stores one of the 60,000 32x32 color images. The first 1024 entries contain the red channel values, the next 1024 the green, and the final 1024 the blue. The image is stored in row-major order, so that the first 32 entries of the array are the red channel values of the first row of the image.

# %%
# function for unpickling the CIFAR10 dataset
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

DATA_ROOT = "CIFAR10/cifar-10-batches-py/"

# import CIFAR10 image batches
batch1 = unpickle(DATA_ROOT + "data_batch_1")
batch2 = unpickle(DATA_ROOT + "data_batch_2")
batch3 = unpickle(DATA_ROOT + "data_batch_3")
batch4 = unpickle(DATA_ROOT + "data_batch_4")
batch5 = unpickle(DATA_ROOT + "data_batch_5")
test_batch = unpickle(DATA_ROOT + "test_batch")

images = np.concatenate([batch1[b'data'], batch2[b'data'], batch3[b'data'], batch4[b'data'], batch5[b'data'], test_batch[b'data']])

# convert image bytes to imgs
images_rgb = np.zeros((len(images), 32, 32, 3))
for i in range(len(images)):
  im = images[i]
  im_r = im[0:1024].reshape(32, 32)
  im_g = im[1024:2048].reshape(32, 32)
  im_b = im[2048:].reshape(32, 32)
  im_rgb = np.dstack((im_r, im_g, im_b)) / 255.0
  images_rgb[i,:,:,:] = im_rgb
  
images = images_rgb

# confirm correct size of data array
print("Data dimensions: ", np.shape(images))
# Out:
# Data dimensions:  (60000, 32, 32, 3)

# %% [markdown]
# # 2. Visualize CIFAR

# %%
## functions for displaying cifar images

def cifar10_plot_single(data, im_idx=0):
    img = data[im_idx]    
    plt.imshow(img) 

def cifar10_plot_examples(data):
  
  for i in range(9):
    img = data[i]
    # define subplot
    plt.subplot(330 + 1 + i)
    # plot 
    plt.imshow(img)

# %%
cifar10_plot_examples(images)

# %%
cifar10_plot_single(images, im_idx=4)

# %% [markdown]
# # 3. Perform Dimensionality Reduction on Image Feature Vectors

# %%
#Functions for PCA

# returns image feature vectors reduced to PCA component count in n_components
# also returns 'recovered' images for comparison, transformed from the reduced set back to original 32x32 space
def pca_reduce(images, n_components):
  pca = PCA(n_components = n_components)

  flat_grays = np.zeros((len(images), 1024))
  for i in range(len(images)):
    img = (images[i]*255).astype('uint8')
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    flat_grays[i] = gray.flatten()

  print(flat_grays.shape)
  images_reduced = pca.fit_transform(flat_grays)
  images_recovered = pca.inverse_transform(images_reduced)
  
  print("Image data reduced from: {} to {}".format(images.shape, images_reduced.shape))
  print()
  print("Explained variance ratio of each component: ")
  print(pca.explained_variance_ratio_)
  plt.plot(pca.explained_variance_ratio_)
  plt.show()
  plt.grid()
  plt.plot(np.cumsum(pca.explained_variance_ratio_ * 100))
  plt.xlabel('Number of components')
  plt.ylabel('Explained variance')
  plt.show()
  
  return pca, images_reduced, images_recovered

# to inspect the PCA predicted images
def plot_pca_image(images, images_recovered, idx = 1):
    plt.subplot(1, 2, 1)
    cifar10_plot_single(images, im_idx= idx)
    plt.subplot(1, 2, 2)
    cifar10_plot_single(images_recovered.astype(int), im_idx = idx)
    plt.show()
  
# 另一个非常有用的信息是每个主成成分的解释方差比（explained variance ratio），可以通过explained_variance_ratio_ 变量获取。
# 这个比率表示的是数据集的方差沿着每个主成成分上的占比。
# 选择PCA降维维度时 尽量选择包含主要多方差的成分

# %%
# change "dimensions" value to specify the number of features you would like to reduce each image to
dimensions = 100 
pca, images_reduced, images_recovered = pca_reduce(images, dimensions)
# Out:
# (60000, 1024)
# Image data reduced from: (60000, 32, 32, 3) to (60000, 100)
#
# Explained variance ratio of each component:
# [0.30495241 0.12407202 0.07349322 0.0409553  0.03129289 0.03023718
#  0.0240765  0.02290549 0.01621097 0.01450675 0.01194305 0.01176234
#  0.0112038  0.01029701 0.00911463 0.00793329 0.00724078 0.00662753
#  0.00658542 0.00554687 0.0055229  0.0052274  0.0050645  0.00501015
#  0.0044929  0.00445881 0.0040972  0.00377078 0.00362951 0.00348264
#  0.00343243 0.00326535 0.0029279  0.00291042 0.00284955 0.00278554
#  0.00272804 0.00257789 0.00255832 0.00248114 0.00236725 0.0023116
#  0.00216338 0.00213573 0.00205927 0.00203253 0.00195406 0.00192038
#  0.00181764 0.00178561 0.00175051 0.00174004 0.00168514 0.00164485
#  0.00160209 0.00158818 0.00153894 0.00150935 0.00149354 0.00144648
#  0.00139332 0.00136225 0.00135795 0.00127637 0.00126533 0.00125597
#  0.00124303 0.0011757  0.00116302 0.00114231 0.00112229 0.00111331
#  0.00109974 0.00108841 0.00104828 0.00104004 0.00101526 0.00099649
#  0.00098735 0.00097414 0.00095006 0.00094047 0.00092644 0.00091044
#  0.00089065 0.00088242 0.00083834 0.00083793 0.00083005 0.00081266
#  0.00080094 0.00079215 0.00076964 0.00076021 0.00075282 0.00074478
#  0.00074167 0.00072905 0.00071677 0.00069564]

# %% [markdown]
# # 4. Data Structure Class Definitions

# %% [markdown]
# ## kd-Tree

# %%
class kdNode:
  """
  Nodes used to store data in the kd-tree.

  data_idx: the row index of the image represented by the node in the tree's dataset
  discriminator: the feature dimension used to split the kd-tree at the node's level
  """
  def __init__(self, data_idx, discriminator, lchild=None, rchild=None):
    self.data_idx = data_idx
    self.discriminator = discriminator
    self.lchild = lchild
    self.rchild = rchild
    
  def __repr__(self):
    return f"Node with Index {self.data_idx}"


class knnHeapNode:
  """
  Object used to keep track of kNNs during kdTree.find_kNN()
  """
  def __init__(self, kdnode, L2Dist):
    self.node = kdnode
    self.L2Dist = L2Dist

  # override the less-than operator to change heapq from min heap to max heap when made of knnHeapNodes
  def __lt__(self, other):
    return self.L2Dist > other.L2Dist

  def __repr__(self):
    return f"(Node Index: {self.node.data_idx}, L2 Distance: {self.L2Dist})"


class kdTree:
  
  def __init__(self):
    self.root = None
    self.data = None

  def builder(self, data, discriminator=0):
    """
    Called by the build_tree function to construct the kd-tree
    """

    num_samples = len(data)
    kdim = len(data[0][1])
    median_idx = num_samples // 2
    
    # sort data according to feature column indexed by discriminator
    data = sorted(data, key=lambda x: x[1][discriminator])

    # find first occurrence of median value for discriminator dimension
    median = data[median_idx][1][discriminator]

    while median_idx > 0 and median == data[median_idx-1][1][discriminator]:
      median_idx = median_idx-1

    # create root node for tree
    node = kdNode(data_idx=data[median_idx][0], discriminator=discriminator)

    # calculate discriminator index for next level
    next_discriminator = (discriminator + 1) % kdim

    # add left subtree containing vectors[discriminator] < median and right subtree containing vectors[discriminator] >= median to root
    if median_idx > 0:
      node.lchild = self.builder(data[:median_idx], next_discriminator)
    if num_samples - (median_idx + 1) > 0:
      node.rchild = self.builder(data[median_idx+1:], next_discriminator)

    return node

  def build_tree(self, data):
    """
    Called by the user to initialize the kd-tree using the provided dataset
    """
    self.data = copy.deepcopy(data)
    self.root = self.builder(data)

  def find_kNN(self, k, query_vec, node=None, kNN=None):
    """
    Find and return a list of the query_vec's k nearest neighbors in the tree's dataset
    
    NOTE: kNN is returned as a max heap of knnHeapNodes, so in order to get the 
    final list in increasing order of L2 dist, the final output must be reverse-sorted 
    using sorted(kNN, reverse=True)
    """
    
    if node == None:
      node = self.root
    
    # create max heap for tracking node values and associated L2 distances of k nearest neighbors
    if kNN == None:
      kNN = []
      heapq.heapify(kNN)

    # extract feature vector from tuple in reference data
    feat_vec = self.data[node.data_idx][1]

    # calculate L2 distance between query_vec and the current node
    dist = distance.euclidean(query_vec, feat_vec)

    if len(kNN) < k:
      heapq.heappush(kNN, knnHeapNode(node, dist))
    else:
      if dist < kNN[0].L2Dist:
        heapq.heapreplace(kNN, knnHeapNode(node, dist))

    # determine best direction to traverse tree
    discriminator = node.discriminator

    if query_vec[discriminator] < feat_vec[discriminator]:
      good_side = node.lchild
      bad_side = node.rchild
    else:
      good_side = node.rchild
      bad_side = node.lchild

    # traverse good side
    if good_side != None:
      kNN = self.find_kNN(k, query_vec, node=good_side, kNN=kNN)

    # determine if the bad side is worth exploring by checking the possibility of a shorter distance to the query on the bad side
    if bad_side != None and abs(query_vec[discriminator] - feat_vec[discriminator]) < kNN[0].L2Dist:
      kNN = self.find_kNN(k, query_vec, node=bad_side, kNN=kNN)

    # return max heap of k closest nodes
    return kNN

# %% [markdown]
# ## Locality hashing
#
# For our locality hashing we used for reference the following github repository:
# https://github.com/kayzhu/LSHash/blob/master/lshash/lshash.py

# %%
class LocalityHash:

  def __init__(self, hash_size, input_dim, num_tables = 1):
      
      """
        arg input_dim: the expected dimension of the data to be hashed
        arg hash_size: number of random hyperplanes that divide the space into hash buckets
        
        Info: What we are realy storing for hyperplanes is the norm of the planes, initialized randomly with standard normal distribution. 
        Points whose dot product with the norm have the same sign are on the same side of the plane.
      """
      self.hash_size = hash_size
      self.input_dim = input_dim
      self.num_tables = num_tables

      self.planes = [np.random.randn(self.hash_size, self.input_dim) for _ in range(self.num_tables)]
      self.hash_tables = [{} for _ in range(self.num_tables)]

      print("LSH initialized")
      print("Number of hash tables: {}".format(self.num_tables))
      print("Number of hyperplanes per table: {}".format(self.hash_size))
      print("Number of buckets per table: {}".format(2**(self.hash_size)))
  
  def get_hashkey(self, plane, input_point):

    """ 
      arg input point dimension = 1* input_dim

      Takes an input point and generates a hash key based on its location relative to the hyperplanes (In which bucket)
      Returns a binary string map of length self.hash_size (number of hyperplanes) where 1 = "above" hyperplane i and 0 = "below" hyperplane i
      looks like: "101010100"

    """
    location_projections = np.dot(plane, np.array(input_point))
        
    #if dot product of input point and hyper plane is positive, it's 'above' in n-d space, if negative or 0, below
    hash_key = "".join(['1' if i > 0 else '0' for i in location_projections])

    return hash_key


  def insert_point(self, input_point, original_index):

    """
      arg input_point dimension = 1* input_dim
      arg original_index = reference to the index of the full size image for retrieval
    """

    info = (tuple(input_point), original_index)  #save point as tuple to save memory
    
    for i, hash_table in enumerate(self.hash_tables):
      key = self.get_hashkey(self.planes[i], input_point)

      if key in hash_table:
          hash_table[key].append(info)
      else:
          hash_table[key] = [info]

  
  def initialize(self, input_data, verbose = False):
    if len(input_data[0][1]) != self.input_dim:
        print("Input points should have dimension: 1 x {}".format(self.input_dim))
        return

    print("Initializing LSH from data...")

    for data in input_data:
      index, point = data
      self.insert_point(point, index)

    if verbose:
      count_str = "\nInserted:\n"
      for i, hash_table in enumerate(self.hash_tables):
        for bucket, item in hash_table.items():
            count_str += "{} items into bucket {} in hash table {}".format(str(len(item)), bucket, str(i+1))
            count_str += "\n"
        count_str += "\n"

      print(count_str)


  def get_knns(self, query_point, k, remove_first = False):
      
      candidates = set()
      start = time.time()
      for i, table in enumerate(self.hash_tables):
          key = self.get_hashkey(self.planes[i], query_point)
          if key in table:
            candidates.update(table[key])
      end = time.time()

      if len(candidates) <= 1:  #if query returns nothing or just the query point itself, return
        if len(candidates) == 0 or (tuple(candidates[0][0]) == tuple(query_point.tolist())):
          print("No neighbors found")
          return
  
      start = time.time()
      candidates_aug = []
      #add euclidean
      for i, (point, index) in enumerate(candidates):
          dist = distance.euclidean(query_point, point)
          candidates_aug.append((point, index, dist))
      end = time.time()
      print("Time spent in calculating distances: ", end-start)

      #sort on euclidean
      candidates_aug.sort(key=lambda x: x[2])

      ##trim if duplicates/remove same value:
      if remove_first:
        smallest_dist = candidates_aug[0][2]
        i = 0
        while i < len(candidates_aug) and smallest_dist == 0:
          candidates_aug = candidates_aug[i+1:]
          smallest_dist = candidates_aug[0][2]

      if len(candidates_aug) <= k:
        return candidates_aug
      else:
        return candidates_aug[:k]

# %% [markdown]
# # 5. Populate Each Data Structure with CIFAR10 Data

# %%
# format data for input into kd tree
ids = np.arange(images_reduced.shape[0])
images_reduced_ids = list(zip(list(ids), list(images_reduced)))

# %%
#original data for lsh
images_flat = np.concatenate([batch1[b'data'], batch2[b'data'], batch3[b'data'], batch4[b'data'], batch5[b'data'], test_batch[b'data']])
images_rgb = np.zeros((len(images), 32, 32, 3))
for i in range(len(images_flat)):
  im = images_flat[i]
  im_r = im[0:1024].reshape(32, 32)
  im_g = im[1024:2048].reshape(32, 32)
  im_b = im[2048:].reshape(32, 32)
  im_rgb = np.dstack((im_r, im_g, im_b)) / 255.0
  images_rgb[i,:,:,:] = im_rgb
images_flat = images_rgb
flat_grays = np.zeros((len(images), 1024))
for i in range(len(images)):
    img = (images_flat[i]*255).astype('uint8')
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    flat_grays[i] = gray.flatten()
images_flat = flat_grays
images_tupled = []
for i, img in enumerate(images_flat):
  images_tupled.append((i, img))

# %%
cifar_kdtree = kdTree()
cifar_kdtree.build_tree(images_reduced_ids)

if 'lsh' in globals():
    del lsh
    
#INITIALIZE LSH
hash_size = 14
num_tables = 2
lsh = LocalityHash(hash_size = hash_size , input_dim = images_flat.shape[1], num_tables = num_tables)
lsh.initialize(images_tupled)
# Out:
# LSH initialized
# Number of hash tables: 2
# Number of hyperplanes per table: 14
# Number of buckets per table: 16384
# Initializing LSH from data...

# %% [markdown]
# # 6. Test Search Query Performance

# %% [markdown]
# ## Helper Functions

# %%
def get_ground_truth_nns(query, num_kNN, data):
  """
  Brute force computation of the query's nearest neighbors in data matrix using L2 norm.
  
  Assumes data is a list of tuples of the form [(image_index, [features])].

  Returns list of tuples of the form [(image_index, L2Dist)], with tuples
  ordered from smallest L2 distance to largest L2 distance
  """
  # compute ground truth nn for query image
  true_nns = []
  for i, row in enumerate(data):
    dist = distance.euclidean(query, row)

    if len(true_nns) < num_kNN:
      true_nns.append((i, dist))
    else:
      biggest_dist = max(true_nns, key=lambda x:x[1])
      if dist < biggest_dist[1]:
        max_index = true_nns.index(biggest_dist)
        true_nns[max_index] = (i,dist)

  true_nns.sort(key=lambda x: x[1])
  return true_nns

# %% [markdown]
# ## kd-Tree:

# %%
import time
from operator import eq

sum = 0
sum2 = sum
del sum

#num_neighbors = int(input("How many nearest neighbors for your image query?: "))
num_neighbors = 100

# chose random query image
rand_index = random.randint(0, len(images_flat))
query_image = images_flat[rand_index,:]
reduced_query = images_reduced[rand_index,:]

print("Query image: ")
#cifar10_plot_single(images, rand_index)
#del images

start = time.time()
true_nns = get_ground_truth_nns(query_image, num_neighbors, images_flat)
end = time.time()

print("naive benchmark: {}".format(end - start))

exemplars = []
exemplars_neighbor_list = []
for x in true_nns:
  exemplars.append(int(x[0]))
  exemplars_neighbor_list.append(str(x[0]))

print(exemplars)

'''for neighbor in exemplars:
  print(distance.euclidean(query_image, images_og[neighbor]))'''

start = time.time()
# find kNN for query image using kdTree
knn_kd = cifar_kdtree.find_kNN(k=num_neighbors, query_vec=reduced_query)
knn_kd = sorted(knn_kd, reverse=True)
end = time.time()

# reduced neighbor distances
kd_neighbor_list = []
# true non-reduced distancesretrieving candidates:  0.34514570236206055

for neighbor in knn_kd:
  kd_neighbor_list.append(int(str(neighbor.node).replace("Node with Index ", "")))

print(kd_neighbor_list)
print("kd benchmark: {}".format(end - start))

commons = 0 
for i in range(len(kd_neighbor_list)):
  for j in range(len(exemplars)):
    if kd_neighbor_list[i] == exemplars[j]:
      commons += 1

print("kd accuracy percentage {}%".format(100*commons/num_neighbors))
# benchmark表示的是时间
# Out:
# Query image:
# naive benchmark: 0.8328700065612793
# [52949, 27222, 52034, 52029, 15178, 48251, 55443, 6694, 20810, 35375, 6230, 5026, 5719, 34415, 5946, 3549, 11092, 34789, 19407, 52200, 3841, 55559, 25556, 2535, 54203, 33221, 41500, 51326, 43826, 29925, 23479, 13756, 5513, 48230, 24836, 40522, 24397, 10015, 6985, 31932, 57924, 20770, 14275, 47375, 2594, 43808, 29947, 50593, 21167, 48376, 42197, 51140, 24424, 47144, 49364, 58080, 3193, 26540, 34777, 41193, 10890, 32526, 28834, 51125, 19988, 2115, 26849, 35442, 30832, 59473, 6548, 20409, 57651, 20439, 35171, 55208, 59308, 14098, 30751, 44324, 43493, 16434, 5266, 56599, 31377, 3873, 37111, 29849, 18578, 45139, 20450, 9579, 45801, 10877, 41523, 24671, 34011, 13250, 33364, 14726]
# [52949, 27222, 48251, 52029, 24397, 5513, 15178, 52034, 54203, 34415, 20810, 55443, 33364, 35375, 14098, 5026, 11092, 41500, 48230, 51326, 10015, 50593, 6230, 40522, 3841, 6694, 19407, 31932, 23479, 43826, 5719, 29925, 5946, 43808, 50861, 52200, 34789, 14275, 24424, 24836, 24671, 33221, 2535, 25556, 57924, 24464, 57028, 10890, 26849, 15667, 3549, 2594, 55559, 20409, 6548, 56599, 34011, 49364, 41193, 13756, 26540, 51982, 3873, 47375, 47144, 51125, 18578, 3193, 51140, 35442, 2836, 58062, 48376, 43493, 6985, 29736, 36396, 58080, 19988, 24448, 42197, 2115, 336, 20770, 20097, 21167, 29947, 20439, 34777, 728, 16434, 32526, 39452, 14553, 59473, 55208, 14078, 18682, 24989, 41265]
# kd benchmark: 0.4012930393218994
# kd accuracy percentage 81.0%

# %% [markdown]
# ## Locality Sensitive Hashing

# %%
import time
from operator import eq

sum = 0
sum2 = sum
del sum

start = time.time()
knn_lsh = lsh.get_knns(query_image, num_neighbors)
end = time.time()

lsh_neighbor_list = []
# true non-reduced distances
for neighbor in knn_lsh:
  #print(distance.euclidean(query_image, images_flat[int(neighbor[1])]))
  lsh_neighbor_list.append(int(neighbor[1]))

# neighbor distances
print(exemplars)
print(lsh_neighbor_list)

### DO STUFF
print("lsh benchmark: {}".format(end - start))
commons = 0 
for i in range(len(lsh_neighbor_list)):
  for j in range(len(exemplars)):
    if lsh_neighbor_list[i] == exemplars[j]:
      commons += 1
print("lsh accuracy percentage {}%".format(100*commons/num_neighbors))
# Out:
# Time spent in calculating distances:  0.4947957992553711
# [52949, 27222, 52034, 52029, 15178, 48251, 55443, 6694, 20810, 35375, 6230, 5026, 5719, 34415, 5946, 3549, 11092, 34789, 19407, 52200, 3841, 55559, 25556, 2535, 54203, 33221, 41500, 51326, 43826, 29925, 23479, 13756, 5513, 48230, 24836, 40522, 24397, 10015, 6985, 31932, 57924, 20770, 14275, 47375, 2594, 43808, 29947, 50593, 21167, 48376, 42197, 51140, 24424, 47144, 49364, 58080, 3193, 26540, 34777, 41193, 10890, 32526, 28834, 51125, 19988, 2115, 26849, 35442, 30832, 59473, 6548, 20409, 57651, 20439, 35171, 55208, 59308, 14098, 30751, 44324, 43493, 16434, 5266, 56599, 31377, 3873, 37111, 29849, 18578, 45139, 20450, 9579, 45801, 10877, 41523, 24671, 34011, 13250, 33364, 14726]
# [52949, 27222, 52034, 6694, 20810, 6230, 5026, 5719, 3549, 11092, 19407, 52200, 55559, 25556, 54203, 33221, 13756, 5513, 24397, 6985, 57924, 20770, 14275, 47375, 2594, 50593, 48376, 42197, 24424, 26540, 2115, 35442, 6548, 30751, 44324, 5266, 3873, 20450, 9579, 45801, 41523, 33364, 45957, 18734, 18420, 17292, 19462, 46851, 7283, 41283, 25900, 15578, 9900, 1268, 51667, 26226, 3259, 48277, 49940, 728, 40006, 51681, 24337, 41265, 22800, 7247, 24448, 35149, 38776, 48557, 15667, 22205, 58383, 59318, 2842, 3949, 51724, 25931, 14521, 43374, 5166, 11539, 36169, 13467, 18876, 3569, 35455, 39452, 36162, 15612, 57028, 336, 18376, 55252, 13972, 420, 14181, 47954, 16674, 23138]
# lsh benchmark: 0.637153148651123
# lsh accuracy percentage 42.0%

# %% [markdown]
# # 7. Plotting and Batch Testing

# %%
import time
from operator import eq

def plot(data_points, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_axes([0.12,0.1,0.8,0.8])
    algos = ['Naive', 'KD-Tree', 'LSH']
    print(algos)
    print(data_points)
    ax.bar(algos, data_points, color=['red', 'green', 'blue'])
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    plt.show()
  
naive_times = []
kd_times = []
lsh_times = []

naive_acc = []
kd_acc = []
lsh_acc = []

trial_count = 0

for i in range(100):
  trial_count += 1
  print(trial_count)
  sum = 0
  sum2 = sum
  del sum

  num_neighbors = 100

  # chose random query image
  rand_index = random.randint(0, len(images_flat))
  query_image = images_flat[rand_index,:]
  reduced_query = images_reduced[rand_index,:]

  start = time.time()
  true_nns = get_ground_truth_nns(query_image, num_neighbors, images_flat)
  end = time.time()
  naive_benchmark = end - start
  naive_times.append(naive_benchmark)
  print("naive benchmark: {}".format(end - start))

  exemplars = []
  exemplars_neighbor_list = []
  for x in true_nns:
    exemplars.append(int(x[0]))
    exemplars_neighbor_list.append(str(x[0]))
  naive_acc.append(100)

  start = time.time()
  # find kNN for query image using kdTree
  knn_kd = cifar_kdtree.find_kNN(k=num_neighbors, query_vec=reduced_query)
  end = time.time()
  knn_kd = sorted(knn_kd, reverse=True)

  # reduced neighbor distances
  kd_neighbor_list = []
  # true non-reduced distancesretrieving candidates:  0.34514570236206055

  for neighbor in knn_kd:
    kd_neighbor_list.append(int(str(neighbor.node).replace("Node with Index ", "")))
  kd_benchmark =  end - start
  print("kd benchmark: {}".format(end - start))
  kd_times.append(kd_benchmark) 

  commons = 0 
  for i in range(len(kd_neighbor_list)):
    for j in range(len(exemplars)):
      if kd_neighbor_list[i] == exemplars[j]:
        commons += 1
  kd_percentage = 100*commons/num_neighbors
  kd_acc.append(kd_percentage)
  print("kd accuracy percentage {}%".format(100*commons/num_neighbors))

  start = time.time()
  knn_lsh = lsh.get_knns(query_image, num_neighbors)
  end = time.time()

  lsh_neighbor_list = []
  # true non-reduced distances
  for neighbor in knn_lsh:
    lsh_neighbor_list.append(int(neighbor[1]))
  lsh_benchmark = end - start
  lsh_times.append(lsh_benchmark)
  print("lsh benchmark: {}".format(end - start))
  
  commons = 0 
  for i in range(len(lsh_neighbor_list)):
    for j in range(len(exemplars)):
      if lsh_neighbor_list[i] == exemplars[j]:
        commons += 1
  lsh_percentage = 100*commons/num_neighbors
  lsh_acc.append(lsh_percentage)
  print("lsh accuracy percentage {}%".format(100*commons/num_neighbors))

average_timings = [sum(naive_times)/len(naive_times), sum(kd_times)/len(kd_times), sum(lsh_times)/len(lsh_times)]
average_accs = [sum(naive_acc)/len(naive_acc), sum(kd_acc)/len(kd_acc), sum(lsh_acc)/len(lsh_acc)]

plot(average_timings, "Timing comparison", "algorithm/structure", "average-time(ms)")
plot(average_accs, "Accuracy comparison", "algorithm/structure", "average accuracy")
# Out:
# 1
# naive benchmark: 0.8440017700195312
# kd benchmark: 0.4028916358947754
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.10905599594116211
# lsh benchmark: 0.14023494720458984
# lsh accuracy percentage 3.0%
# 2
# naive benchmark: 0.8297159671783447
# kd benchmark: 0.4083681106567383
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.6591670513153076
# lsh benchmark: 0.8407878875732422
# lsh accuracy percentage 52.0%
# 3
# naive benchmark: 0.8682670593261719
# kd benchmark: 0.3936591148376465
# kd accuracy percentage 76.0%
# Time spent in calculating distances:  0.06540608406066895
# lsh benchmark: 0.08467411994934082
# lsh accuracy percentage 10.0%
# 4
# naive benchmark: 0.833158016204834
# kd benchmark: 0.39484524726867676
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.6701900959014893
# lsh benchmark: 0.8521959781646729
# lsh accuracy percentage 78.0%
# 5
# naive benchmark: 0.8425459861755371
# kd benchmark: 0.3955976963043213
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.07010388374328613
# lsh benchmark: 0.09078192710876465
# lsh accuracy percentage 4.0%
# 6
# naive benchmark: 0.8317241668701172
# kd benchmark: 0.20494508743286133
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.5644280910491943
# lsh benchmark: 0.6995630264282227
# lsh accuracy percentage 60.0%
# 7
# naive benchmark: 0.8340811729431152
# kd benchmark: 0.3939650058746338
# kd accuracy percentage 75.0%
# Time spent in calculating distances:  0.138869047164917
# lsh benchmark: 0.17660212516784668
# lsh accuracy percentage 28.0%
# 8
# naive benchmark: 0.8294811248779297
# kd benchmark: 0.3963797092437744
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.02163529396057129
# lsh benchmark: 0.02811288833618164
# lsh accuracy percentage 4.0%
# 9
# naive benchmark: 0.8334510326385498
# kd benchmark: 0.3933219909667969
# kd accuracy percentage 87.0%
# Time spent in calculating distances:  0.1142420768737793
# lsh benchmark: 0.14574623107910156
# lsh accuracy percentage 12.0%
# 10
# naive benchmark: 0.8341078758239746
# kd benchmark: 0.41584300994873047
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.31307172775268555
# lsh benchmark: 0.40056800842285156
# lsh accuracy percentage 37.0%
# 11
# naive benchmark: 0.8677089214324951
# kd benchmark: 0.39302563667297363
# kd accuracy percentage 70.0%
# Time spent in calculating distances:  0.06685686111450195
# lsh benchmark: 0.08420896530151367
# lsh accuracy percentage 4.0%
# 12
# naive benchmark: 0.8377890586853027
# kd benchmark: 0.41840314865112305
# kd accuracy percentage 78.0%
# Time spent in calculating distances:  0.5297462940216064
# lsh benchmark: 0.6538951396942139
# lsh accuracy percentage 64.0%
# 13
# naive benchmark: 0.8490967750549316
# kd benchmark: 0.40543174743652344
# kd accuracy percentage 79.0%
# Time spent in calculating distances:  0.11001300811767578
# lsh benchmark: 0.14043378829956055
# lsh accuracy percentage 8.0%
# 14
# naive benchmark: 0.8300769329071045
# kd benchmark: 0.39777469635009766
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.011306047439575195
# lsh benchmark: 0.014214754104614258
# lsh accuracy percentage 3.0%
# 15
# naive benchmark: 0.8318791389465332
# kd benchmark: 0.39443397521972656
# kd accuracy percentage 87.0%
# Time spent in calculating distances:  0.6835267543792725
# lsh benchmark: 0.8734791278839111
# lsh accuracy percentage 83.0%
# 16
# naive benchmark: 0.8334000110626221
# kd benchmark: 0.3918588161468506
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.0728461742401123
# lsh benchmark: 0.09347820281982422
# lsh accuracy percentage 18.0%
# 17
# naive benchmark: 0.8340699672698975
# kd benchmark: 0.39339590072631836
# kd accuracy percentage 87.0%
# Time spent in calculating distances:  0.5249018669128418
# lsh benchmark: 0.6571929454803467
# lsh accuracy percentage 60.0%
# 18
# naive benchmark: 0.8373122215270996
# kd benchmark: 0.3952467441558838
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.04592108726501465
# lsh benchmark: 0.05848193168640137
# lsh accuracy percentage 14.0%
# 19
# naive benchmark: 0.8329131603240967
# kd benchmark: 0.39226508140563965
# kd accuracy percentage 79.0%
# Time spent in calculating distances:  0.014638185501098633
# lsh benchmark: 0.018979787826538086
# lsh accuracy percentage 6.0%
# 20
# naive benchmark: 0.8352527618408203
# kd benchmark: 0.2034468650817871
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.11493301391601562
# lsh benchmark: 0.1427760124206543
# lsh accuracy percentage 13.0%
# 21
# naive benchmark: 0.8307950496673584
# kd benchmark: 0.3955399990081787
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.4784672260284424
# lsh benchmark: 0.6028430461883545
# lsh accuracy percentage 58.0%
# 22
# naive benchmark: 0.833521842956543
# kd benchmark: 0.3946819305419922
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.6940381526947021
# lsh benchmark: 0.8842880725860596
# lsh accuracy percentage 82.0%
# 23
# naive benchmark: 0.8313958644866943
# kd benchmark: 0.3951890468597412
# kd accuracy percentage 79.0%
# Time spent in calculating distances:  0.023892879486083984
# lsh benchmark: 0.030910968780517578
# lsh accuracy percentage 3.0%
# 24
# naive benchmark: 0.8327081203460693
# kd benchmark: 0.39373207092285156
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.18738579750061035
# lsh benchmark: 0.2371230125427246
# lsh accuracy percentage 18.0%
# 25
# naive benchmark: 0.8261380195617676
# kd benchmark: 0.39830780029296875
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.41009521484375
# lsh benchmark: 0.5123419761657715
# lsh accuracy percentage 47.0%
# 26
# naive benchmark: 0.8351137638092041
# kd benchmark: 0.3947169780731201
# kd accuracy percentage 83.0%
# Time spent in calculating distances:  0.04528522491455078
# lsh benchmark: 0.05746293067932129
# lsh accuracy percentage 4.0%
# 27
# naive benchmark: 0.831798791885376
# kd benchmark: 0.393157958984375
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.02379584312438965
# lsh benchmark: 0.030703067779541016
# lsh accuracy percentage 2.0%
# 28
# naive benchmark: 0.830193042755127
# kd benchmark: 0.3954927921295166
# kd accuracy percentage 74.0%
# Time spent in calculating distances:  0.5202162265777588
# lsh benchmark: 0.6469590663909912
# lsh accuracy percentage 65.0%
# 29
# naive benchmark: 0.833298921585083
# kd benchmark: 0.19805097579956055
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.049504756927490234
# lsh benchmark: 0.06229090690612793
# lsh accuracy percentage 4.0%
# 30
# naive benchmark: 0.8329041004180908
# kd benchmark: 0.39076900482177734
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.20543980598449707
# lsh benchmark: 0.25659990310668945
# lsh accuracy percentage 15.0%
# 31
# naive benchmark: 0.8281936645507812
# kd benchmark: 0.39828920364379883
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.00830078125
# lsh benchmark: 0.010778188705444336
# lsh accuracy percentage 1.0%
# 32
# naive benchmark: 0.833014965057373
# kd benchmark: 0.39534807205200195
# kd accuracy percentage 78.0%
# Time spent in calculating distances:  0.11711478233337402
# lsh benchmark: 0.14861512184143066
# lsh accuracy percentage 13.0%
# 33
# naive benchmark: 0.8365321159362793
# kd benchmark: 0.39666199684143066
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.011059999465942383
# lsh benchmark: 0.014082193374633789
# lsh accuracy percentage 2.0%
# 34
# naive benchmark: 0.8308548927307129
# kd benchmark: 0.39765214920043945
# kd accuracy percentage 89.0%
# Time spent in calculating distances:  0.5407180786132812
# lsh benchmark: 0.6701540946960449
# lsh accuracy percentage 44.0%
# 35
# naive benchmark: 0.8317651748657227
# kd benchmark: 0.4029698371887207
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.015857219696044922
# lsh benchmark: 0.02051401138305664
# lsh accuracy percentage 2.0%
# 36
# naive benchmark: 0.8319578170776367
# kd benchmark: 0.3962218761444092
# kd accuracy percentage 87.0%
# Time spent in calculating distances:  0.02243208885192871
# lsh benchmark: 0.028380155563354492
# lsh accuracy percentage 2.0%
# 37
# naive benchmark: 0.8318819999694824
# kd benchmark: 0.19668197631835938
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.009407997131347656
# lsh benchmark: 0.011972188949584961
# lsh accuracy percentage 18.0%
# 38
# naive benchmark: 0.834197998046875
# kd benchmark: 0.3940770626068115
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.08277702331542969
# lsh benchmark: 0.10490608215332031
# lsh accuracy percentage 31.0%
# 39
# naive benchmark: 0.8305699825286865
# kd benchmark: 0.39235615730285645
# kd accuracy percentage 76.0%
# Time spent in calculating distances:  0.12383198738098145
# lsh benchmark: 0.15521025657653809
# lsh accuracy percentage 9.0%
# 40
# naive benchmark: 0.829984188079834
# kd benchmark: 0.39963531494140625
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.6751589775085449
# lsh benchmark: 0.8645927906036377
# lsh accuracy percentage 77.0%
# 41
# naive benchmark: 0.8376250267028809
# kd benchmark: 0.3994791507720947
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.5255019664764404
# lsh benchmark: 0.6533489227294922
# lsh accuracy percentage 70.0%
# 42
# naive benchmark: 0.8332839012145996
# kd benchmark: 0.397320032119751
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.1475660800933838
# lsh benchmark: 0.1846470832824707
# lsh accuracy percentage 2.0%
# 43
# naive benchmark: 0.8324031829833984
# kd benchmark: 0.19660210609436035
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.6608550548553467
# lsh benchmark: 0.8370058536529541
# lsh accuracy percentage 91.0%
# 44
# naive benchmark: 0.8521990776062012
# kd benchmark: 0.393251895904541
# kd accuracy percentage 83.0%
# Time spent in calculating distances:  0.07966113090515137
# lsh benchmark: 0.10055303573608398
# lsh accuracy percentage 4.0%
# 45
# naive benchmark: 0.8294167518615723
# kd benchmark: 0.3960225582122803
# kd accuracy percentage 87.0%
# Time spent in calculating distances:  0.027390003204345703
# lsh benchmark: 0.03511810302734375
# lsh accuracy percentage 13.0%
# 46
# naive benchmark: 0.8354318141937256
# kd benchmark: 0.3947579860687256
# kd accuracy percentage 79.0%
# Time spent in calculating distances:  0.7002527713775635
# lsh benchmark: 0.8896238803863525
# lsh accuracy percentage 84.0%
# 47
# naive benchmark: 0.8342998027801514
# kd benchmark: 0.3938319683074951
# kd accuracy percentage 87.0%
# Time spent in calculating distances:  0.09460711479187012
# lsh benchmark: 0.1188499927520752
# lsh accuracy percentage 22.0%
# 48
# naive benchmark: 0.8315441608428955
# kd benchmark: 0.19553709030151367
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.7037220001220703
# lsh benchmark: 0.8963630199432373
# lsh accuracy percentage 77.0%
# 49
# naive benchmark: 0.829704761505127
# kd benchmark: 0.20634698867797852
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.2373502254486084
# lsh benchmark: 0.30132198333740234
# lsh accuracy percentage 9.0%
# 50
# naive benchmark: 0.8446540832519531
# kd benchmark: 0.4189770221710205
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.1137080192565918
# lsh benchmark: 0.14482998847961426
# lsh accuracy percentage 6.0%
# 51
# naive benchmark: 0.8343558311462402
# kd benchmark: 0.3959081172943115
# kd accuracy percentage 78.0%
# Time spent in calculating distances:  0.01725006103515625
# lsh benchmark: 0.022089004516601562
# lsh accuracy percentage 2.0%
# 52
# naive benchmark: 0.8415360450744629
# kd benchmark: 0.40024614334106445
# kd accuracy percentage 83.0%
# Time spent in calculating distances:  0.07379317283630371
# lsh benchmark: 0.09298205375671387
# lsh accuracy percentage 10.0%
# 53
# naive benchmark: 0.83992600440979
# kd benchmark: 0.39179277420043945
# kd accuracy percentage 78.0%
# Time spent in calculating distances:  0.205718994140625
# lsh benchmark: 0.25650930404663086
# lsh accuracy percentage 52.0%
# 54
# naive benchmark: 0.83815598487854
# kd benchmark: 0.42125916481018066
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.5351150035858154
# lsh benchmark: 0.6735491752624512
# lsh accuracy percentage 47.0%
# 55
# naive benchmark: 0.8322889804840088
# kd benchmark: 0.389362096786499
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.2855072021484375
# lsh benchmark: 0.35759520530700684
# lsh accuracy percentage 16.0%
# 56
# naive benchmark: 0.833698034286499
# kd benchmark: 0.389617919921875
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.4953117370605469
# lsh benchmark: 0.616534948348999
# lsh accuracy percentage 52.0%
# 57
# naive benchmark: 0.8450262546539307
# kd benchmark: 0.4041903018951416
# kd accuracy percentage 78.0%
# Time spent in calculating distances:  0.5488193035125732
# lsh benchmark: 0.6815061569213867
# lsh accuracy percentage 61.0%
# 58
# naive benchmark: 0.8305168151855469
# kd benchmark: 0.39275288581848145
# kd accuracy percentage 76.0%
# Time spent in calculating distances:  0.11265897750854492
# lsh benchmark: 0.14250612258911133
# lsh accuracy percentage 16.0%
# 59
# naive benchmark: 0.8306620121002197
# kd benchmark: 0.42360591888427734
# kd accuracy percentage 91.0%
# Time spent in calculating distances:  0.03082585334777832
# lsh benchmark: 0.04018092155456543
# lsh accuracy percentage 3.0%
# 60
# naive benchmark: 0.8408007621765137
# kd benchmark: 0.3920750617980957
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.09275698661804199
# lsh benchmark: 0.11699080467224121
# lsh accuracy percentage 11.0%
# 61
# naive benchmark: 0.829265832901001
# kd benchmark: 0.3929870128631592
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.013477325439453125
# lsh benchmark: 0.01737499237060547
# lsh accuracy percentage 14.0%
# 62
# naive benchmark: 0.8523209095001221
# kd benchmark: 0.41760993003845215
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.37320780754089355
# lsh benchmark: 0.46384501457214355
# lsh accuracy percentage 33.0%
# 63
# naive benchmark: 0.8286590576171875
# kd benchmark: 0.3893430233001709
# kd accuracy percentage 69.0%
# Time spent in calculating distances:  0.10938906669616699
# lsh benchmark: 0.13780498504638672
# lsh accuracy percentage 8.0%
# 64
# naive benchmark: 0.8321208953857422
# kd benchmark: 0.3906881809234619
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.1882178783416748
# lsh benchmark: 0.235792875289917
# lsh accuracy percentage 29.0%
# 65
# naive benchmark: 0.8317439556121826
# kd benchmark: 0.3932619094848633
# kd accuracy percentage 92.0%
# Time spent in calculating distances:  0.050662994384765625
# lsh benchmark: 0.06452298164367676
# lsh accuracy percentage 25.0%
# 66
# naive benchmark: 0.8329510688781738
# kd benchmark: 0.19624686241149902
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.09889674186706543
# lsh benchmark: 0.12267208099365234
# lsh accuracy percentage 4.0%
# 67
# naive benchmark: 0.8566937446594238
# kd benchmark: 0.20688724517822266
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.6440200805664062
# lsh benchmark: 0.8200221061706543
# lsh accuracy percentage 86.0%
# 68
# naive benchmark: 0.8530800342559814
# kd benchmark: 0.4131946563720703
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.06085205078125
# lsh benchmark: 0.0773019790649414
# lsh accuracy percentage 15.0%
# 69
# naive benchmark: 0.8282811641693115
# kd benchmark: 0.3960599899291992
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.10989093780517578
# lsh benchmark: 0.13825011253356934
# lsh accuracy percentage 9.0%
# 70
# naive benchmark: 0.830873966217041
# kd benchmark: 0.39139389991760254
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.5144088268280029
# lsh benchmark: 0.6395330429077148
# lsh accuracy percentage 22.0%
# 71
# naive benchmark: 0.8347821235656738
# kd benchmark: 0.39673805236816406
# kd accuracy percentage 74.0%
# Time spent in calculating distances:  0.21315932273864746
# lsh benchmark: 0.26599693298339844
# lsh accuracy percentage 25.0%
# 72
# naive benchmark: 0.8402202129364014
# kd benchmark: 0.4142570495605469
# kd accuracy percentage 76.0%
# Time spent in calculating distances:  0.11967802047729492
# lsh benchmark: 0.15039896965026855
# lsh accuracy percentage 6.0%
# 73
# naive benchmark: 0.8382997512817383
# kd benchmark: 0.40117907524108887
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.4117929935455322
# lsh benchmark: 0.5188090801239014
# lsh accuracy percentage 49.0%
# 74
# naive benchmark: 0.8318397998809814
# kd benchmark: 0.39254093170166016
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.01919078826904297
# lsh benchmark: 0.02480602264404297
# lsh accuracy percentage 2.0%
# 75
# naive benchmark: 0.8308038711547852
# kd benchmark: 0.3922312259674072
# kd accuracy percentage 83.0%
# Time spent in calculating distances:  0.23931503295898438
# lsh benchmark: 0.2979397773742676
# lsh accuracy percentage 25.0%
# 76
# naive benchmark: 0.84014892578125
# kd benchmark: 0.3984959125518799
# kd accuracy percentage 83.0%
# Time spent in calculating distances:  0.07467007637023926
# lsh benchmark: 0.09517908096313477
# lsh accuracy percentage 7.0%
# 77
# naive benchmark: 0.8390576839447021
# kd benchmark: 0.19727587699890137
# kd accuracy percentage 83.0%
# Time spent in calculating distances:  0.04337000846862793
# lsh benchmark: 0.05425906181335449
# lsh accuracy percentage 10.0%
# 78
# naive benchmark: 0.8350532054901123
# kd benchmark: 0.3949289321899414
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.05369687080383301
# lsh benchmark: 0.06759095191955566
# lsh accuracy percentage 9.0%
# 79
# naive benchmark: 0.8317959308624268
# kd benchmark: 0.40111207962036133
# kd accuracy percentage 73.0%
# Time spent in calculating distances:  0.19795870780944824
# lsh benchmark: 0.24687504768371582
# lsh accuracy percentage 16.0%
# 80
# naive benchmark: 0.8388707637786865
# kd benchmark: 0.10294389724731445
# kd accuracy percentage 90.0%
# Time spent in calculating distances:  0.007896900177001953
# lsh benchmark: 0.010179996490478516
# lsh accuracy percentage 2.0%
# 81
# naive benchmark: 0.8356349468231201
# kd benchmark: 0.3928351402282715
# kd accuracy percentage 77.0%
# Time spent in calculating distances:  0.5308108329772949
# lsh benchmark: 0.6586501598358154
# lsh accuracy percentage 31.0%
# 82
# naive benchmark: 0.83925461769104
# kd benchmark: 0.1969001293182373
# kd accuracy percentage 84.0%
# Time spent in calculating distances:  0.5556070804595947
# lsh benchmark: 0.6913578510284424
# lsh accuracy percentage 33.0%
# 83
# naive benchmark: 0.8488941192626953
# kd benchmark: 0.19691205024719238
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.40566182136535645
# lsh benchmark: 0.5126168727874756
# lsh accuracy percentage 54.0%
# 84
# naive benchmark: 0.8322639465332031
# kd benchmark: 0.3925948143005371
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.12045836448669434
# lsh benchmark: 0.15045905113220215
# lsh accuracy percentage 10.0%
# 85
# naive benchmark: 0.8381221294403076
# kd benchmark: 0.4127171039581299
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.4139702320098877
# lsh benchmark: 0.5209250450134277
# lsh accuracy percentage 49.0%
# 86
# naive benchmark: 0.8292081356048584
# kd benchmark: 0.40923309326171875
# kd accuracy percentage 74.0%
# Time spent in calculating distances:  0.2770068645477295
# lsh benchmark: 0.345505952835083
# lsh accuracy percentage 12.0%
# 87
# naive benchmark: 0.8290870189666748
# kd benchmark: 0.39510011672973633
# kd accuracy percentage 75.0%
# Time spent in calculating distances:  0.03693819046020508
# lsh benchmark: 0.04651808738708496
# lsh accuracy percentage 4.0%
# 88
# naive benchmark: 0.8326940536499023
# kd benchmark: 0.19675588607788086
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.10031008720397949
# lsh benchmark: 0.12450003623962402
# lsh accuracy percentage 13.0%
# 89
# naive benchmark: 0.8402328491210938
# kd benchmark: 0.4045138359069824
# kd accuracy percentage 76.0%
# Time spent in calculating distances:  0.6999800205230713
# lsh benchmark: 0.891768217086792
# lsh accuracy percentage 82.0%
# 90
# naive benchmark: 0.8424930572509766
# kd benchmark: 0.1963338851928711
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.09045982360839844
# lsh benchmark: 0.11484694480895996
# lsh accuracy percentage 3.0%
# 91
# naive benchmark: 0.834604024887085
# kd benchmark: 0.20722103118896484
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.08369302749633789
# lsh benchmark: 0.10627889633178711
# lsh accuracy percentage 23.0%
# 92
# naive benchmark: 0.8511631488800049
# kd benchmark: 0.3983159065246582
# kd accuracy percentage 81.0%
# Time spent in calculating distances:  0.5158679485321045
# lsh benchmark: 0.643563985824585
# lsh accuracy percentage 56.0%
# 93
# naive benchmark: 0.8302631378173828
# kd benchmark: 0.3951530456542969
# kd accuracy percentage 86.0%
# Time spent in calculating distances:  0.08927798271179199
# lsh benchmark: 0.1126546859741211
# lsh accuracy percentage 7.0%
# 94
# naive benchmark: 0.8381621837615967
# kd benchmark: 0.21045470237731934
# kd accuracy percentage 91.0%
# Time spent in calculating distances:  0.5515530109405518
# lsh benchmark: 0.6912188529968262
# lsh accuracy percentage 60.0%
# 95
# naive benchmark: 0.8369300365447998
# kd benchmark: 0.40048718452453613
# kd accuracy percentage 85.0%
# Time spent in calculating distances:  0.13467097282409668
# lsh benchmark: 0.16930770874023438
# lsh accuracy percentage 7.0%
# 96
# naive benchmark: 0.845850944519043
# kd benchmark: 0.41835975646972656
# kd accuracy percentage 82.0%
# Time spent in calculating distances:  0.5029771327972412
# lsh benchmark: 0.6267600059509277
# lsh accuracy percentage 54.0%
# 97
# naive benchmark: 0.8333461284637451
# kd benchmark: 0.19846296310424805
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.026971817016601562
# lsh benchmark: 0.03345775604248047
# lsh accuracy percentage 7.0%
# 98
# naive benchmark: 0.8434898853302002
# kd benchmark: 0.397982120513916
# kd accuracy percentage 78.0%
# Time spent in calculating distances:  0.5259509086608887
# lsh benchmark: 0.6542930603027344
# lsh accuracy percentage 58.0%
# 99
# naive benchmark: 0.8375809192657471
# kd benchmark: 0.19791507720947266
# kd accuracy percentage 91.0%
# Time spent in calculating distances:  0.3034238815307617
# lsh benchmark: 0.377730131149292
# lsh accuracy percentage 48.0%
# 100
# naive benchmark: 0.8339731693267822
# kd benchmark: 0.3991529941558838
# kd accuracy percentage 80.0%
# Time spent in calculating distances:  0.6487269401550293
# lsh benchmark: 0.8232150077819824
# lsh accuracy percentage 52.0%
# ['Naive', 'KD-Tree', 'LSH']
# [0.8362449407577515, 0.3599434518814087, 0.3145402479171753]
# ['Naive', 'KD-Tree', 'LSH']
# [100.0, 81.67, 27.65]

# %% [markdown]
# # 9. Visual Examples of Results

# %%
def plot_knn_examples(neighbor_list, images):
  
  for i in range(9):
    index = neighbor_list[i]
    img = images[index]
    
    # define subplot
    plt.subplot(330 + 1 + i)
    # plot 
    plt.imshow(img)
    if i == 0:
      plt.title("Original image")
    else:
      plt.title('{}.'.format(i))
    
  plt.tight_layout()

# %%
print()
print("True nearest neighbors")
print()
plot_knn_examples(exemplars, images)
# Out:
# True nearest neighbors

# %%
print()
print("Nearest neighbors returned by kd tree")
print()
plot_knn_examples(kd_neighbor_list, images)
# Out:
# Nearest neighbors returned by kd tree

# %%
print()
print("Nearest neighbors neturned by lsh")
print()
plot_knn_examples(lsh_neighbor_list, images)
# Out:
# Nearest neighbors neturned by lsh
